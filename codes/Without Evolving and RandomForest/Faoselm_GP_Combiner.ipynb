# %%
# !pip install -q scikit-multiflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.6/450.6 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-multiflow (setup.py) ... done

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from skmultiflow.drift_detection import ADWIN, DDM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from matplotlib.colors import ListedColormap
from multiprocessing.pool import ThreadPool
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle
from contextlib import suppress
from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from random import shuffle
import seaborn as sns
from time import time
import pandas as pd
import numpy as np
import warnings
import scipy.io
import pickle
import sys
import gc
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/data'
code_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Codes/Shared Codes'
results_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Results'
feature_selection_results = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_results'
sys.path.insert(0,code_path)
from oselm import set_use_know
from SharedFunctions import main,generate_oselm_models

# %%
filenames = ['kddcup99_csv.csv','ISCX2012.csv','CSE-CIC2018.csv','CICIDS2017.csv','7recurrentDrift.csv', 'blip.csv', 'incrementalDrift.csv',
             '7gradualDrift.csv', '7suddenDrift.csv']
filenames = list(map(lambda x: os.path.join(data_path, x), filenames))

# %%
data_name = ['kddcup99','ISCX2012','CSE-CIC2018','CICIDS2017','7recurrentDrift', 'blip', 'incrementalDrift','7gradualDrift', '7suddenDrift']

# %%
# # use_know = False
# # set_use_know(use_know)
# # path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
# # os.makedirs(path, exist_ok=True)
# # for f_name,d_name in zip(filenames,data_name):
# #   main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
# #        feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path)

# %%
DATA_NUMBER=0
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : kddcup99_csv.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.9967928159076331, 'precision': 1.0, 'recall': 0.9939246658566221, 'f1-score': 0.9969530773918343, 'auc': 0.996962332928311}
#   0%|          | 0/7832 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.9955328653477984, 'precision': 0.9973992197659298, 'recall': 0.9935233160621761, 'f1-score': 0.9954574951330305, 'auc': 0.995503796395868}
#   0%|          | 0/7836 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.9457908163265306, 'precision': 0.9905913978494624, 'recall': 0.9042944785276074, 'f1-score': 0.9454778704297627, 'auc': 0.9474991648946138}
#   0%|          | 0/7876 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.9765228426395939, 'precision': 0.963985594237695, 'recall': 0.991358024691358, 'f1-score': 0.9774802191113817, 'auc': 0.9760967669148697}
#   0%|          | 0/7854 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.988542329726289, 'precision': 0.988296488946684, 'recall': 0.988296488946684, 'f1-score': 0.988296488946684, 'auc': 0.9885372719047634}
#   0%|          | 0/7916 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.9709595959595959, 'precision': 0.9571788413098237, 'recall': 0.9844559585492227, 'f1-score': 0.9706257982120051, 'auc': 0.9712920186834784}
#   0%|          | 0/7856 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.9872773536895675, 'precision': 0.9869109947643979, 'recall': 0.9869109947643979, 'f1-score': 0.9869109947643979, 'auc': 0.9872673785703178}
#   0%|          | 0/7896 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.9911392405063291, 'precision': 0.9987389659520807, 'recall': 0.9838509316770186, 'f1-score': 0.9912390488110137, 'auc': 0.9912803045481866}
#   0%|          | 0/7892 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.986700443318556, 'precision': 0.9828850855745721, 'recall': 0.9913686806411838, 'f1-score': 0.9871086556169429, 'auc': 0.9865697569872587}
#   0%|          | 0/7790 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.9550706033376123, 'precision': 0.9200477326968973, 'recall': 0.9961240310077519, 'f1-score': 0.9565756823821341, 'auc': 0.9553324236671412}

# %%
DATA_NUMBER=1
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : ISCX2012.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.728402734617775, 'precision': 0.9939759036144579, 'recall': 0.43137254901960786, 'f1-score': 0.601640838650866, 'auc': 0.7145014403865813}
#   0%|          | 0/8018 [00:00<?, ?it/s]
# RandomForest
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2 {'accuracy': 0.48192019950124687, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'auc': 0.5}
#   0%|          | 0/8004 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.6683322923173017, 'precision': 1.0, 'recall': 0.3252858958068615, 'f1-score': 0.49089165867689355, 'auc': 0.6626429479034308}
#   0%|          | 0/8040 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.5851990049751243, 'precision': 0.986013986013986, 'recall': 0.17493796526054592, 'f1-score': 0.29715489989462596, 'auc': 0.5862220998372555}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.5980024968789014, 'precision': 1.0, 'recall': 0.17857142857142858, 'f1-score': 0.30303030303030304, 'auc': 0.5892857142857143}
#   0%|          | 0/8018 [00:00<?, ?it/s]
# RandomForest
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 6 {'accuracy': 0.49875311720698257, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'auc': 0.5}
#   0%|          | 0/8026 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.6046077210460772, 'precision': 0.993421052631579, 'recall': 0.19235668789808918, 'f1-score': 0.3223052294557098, 'auc': 0.5955693305507498}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.5942571785268415, 'precision': 1.0, 'recall': 0.18238993710691823, 'f1-score': 0.30851063829787234, 'auc': 0.5911949685534591}
#   0%|          | 0/8138 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.5853808353808354, 'precision': 1.0, 'recall': 0.17783191230207065, 'f1-score': 0.3019648397104447, 'auc': 0.5889159561510353}
#   0%|          | 0/8122 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.5852307692307692, 'precision': 1.0, 'recall': 0.18401937046004843, 'f1-score': 0.310838445807771, 'auc': 0.5920096852300242}

# %%
DATA_NUMBER=2
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CSE-CIC2018.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 0.5}
#   0%|          | 0/8000 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.999375, 'precision': 0.999375, 'recall': 1.0, 'f1-score': 0.9996874023132228, 'auc': 0.5}
#   0%|          | 0/15972 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.9984350547730829, 'precision': 0.9968553459119497, 'recall': 1.0, 'f1-score': 0.9984251968503937, 'auc': 0.9984472049689441}
#   0%|          | 0/15970 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.8202880400751409, 'precision': 0.9990138067061144, 'recall': 0.6387137452711223, 'f1-score': 0.7792307692307693, 'auc': 0.8190459273619293}
#   0%|          | 0/15964 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.5186345129971813, 'precision': 0.5059466409514626, 'recall': 1.0, 'f1-score': 0.6719316969050161, 'auc': 0.5253242742433601}
#   0%|          | 0/15982 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15984 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15978 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.9540050062578223, 'precision': 1.0, 'recall': 0.9068441064638784, 'f1-score': 0.9511465603190429, 'auc': 0.9534220532319392}
#   0%|          | 0/15962 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.9993736298152208, 'precision': 1.0, 'recall': 0.9987253027405991, 'f1-score': 0.9993622448979592, 'auc': 0.9993626513702996}
#   0%|          | 0/15986 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.9237023139462164, 'precision': 1.0, 'recall': 0.8444869343530912, 'f1-score': 0.9156876295784382, 'auc': 0.9222434671765456}

# %%
DATA_NUMBER=3
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CICIDS2017.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.9911942762795817, 'precision': 0.9885321100917431, 'recall': 0.9930875576036866, 'f1-score': 0.9908045977011494, 'auc': 0.9912750749030025}
#   0%|          | 0/8974 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.9493036211699164, 'precision': 0.9123343527013251, 'recall': 0.9944444444444445, 'f1-score': 0.9516214779372675, 'auc': 0.9491775294847921}
#   0%|          | 0/9012 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.8014420410427066, 'precision': 0.7352206494587843, 'recall': 0.9566630552546046, 'f1-score': 0.8314500941619586, 'auc': 0.7976497094454842}
#   0%|          | 0/9038 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.9756637168141593, 'precision': 0.9517014270032931, 'recall': 1.0, 'f1-score': 0.9752530933633295, 'auc': 0.9766206163655685}
#   0%|          | 0/9240 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.9199134199134199, 'precision': 0.8729388942774006, 'recall': 0.9814612868047983, 'f1-score': 0.9240246406570842, 'auc': 0.9203761858298964}
#   0%|          | 0/8962 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.8555493586168432, 'precision': 0.7811418685121108, 'recall': 0.9933993399339934, 'f1-score': 0.8745762711864408, 'auc': 0.8536001224556846}
#   0%|          | 0/8888 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.9235095613048369, 'precision': 0.8696911196911197, 'recall': 0.9988913525498891, 'f1-score': 0.9298245614035088, 'auc': 0.9223908817543967}
#   0%|          | 0/8910 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.9113355780022446, 'precision': 0.851145038167939, 'recall': 0.9977628635346756, 'f1-score': 0.9186405767250259, 'auc': 0.9110435939295001}
#   0%|          | 0/8874 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.6338028169014085, 'precision': 0.78, 'recall': 0.35697940503432496, 'f1-score': 0.489795918367347, 'auc': 0.6296550743262634}
#   0%|          | 0/8898 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.7623595505617977, 'precision': 0.6907630522088354, 'recall': 0.9576837416481069, 'f1-score': 0.8026131591227251, 'auc': 0.7605879025700851}

# %%
DATA_NUMBER=4
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7recurrentDrift.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.7455108359133127, 'precision': 0.7426900584795322, 'recall': 0.7687651331719129, 'f1-score': 0.7555026769779893, 'auc': 0.744965583062509}
#   0%|          | 0/8120 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.7475369458128078, 'precision': 0.7525773195876289, 'recall': 0.7720329024676851, 'f1-score': 0.7621809744779583, 'auc': 0.746301056667219}
#   0%|          | 0/8070 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.7224287484510533, 'precision': 0.7435567010309279, 'recall': 0.698547215496368, 'f1-score': 0.7203495630461924, 'auc': 0.723004572215189}
#   0%|          | 0/8146 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.7196319018404908, 'precision': 0.7093425605536332, 'recall': 0.75, 'f1-score': 0.7291049199762892, 'auc': 0.7194444444444444}
#   0%|          | 0/8034 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.7199751088985687, 'precision': 0.7194835680751174, 'recall': 0.7439320388349514, 'f1-score': 0.7315035799522672, 'auc': 0.7193478840407196}
#   0%|          | 0/8058 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.7196029776674938, 'precision': 0.731829573934837, 'recall': 0.7104622871046229, 'f1-score': 0.7209876543209877, 'auc': 0.719788105577628}
#   0%|          | 0/8002 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.7245471580262336, 'precision': 0.7385786802030457, 'recall': 0.7123623011015912, 'f1-score': 0.7252336448598131, 'auc': 0.7248035995303874}
#   0%|          | 0/8100 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.7432098765432099, 'precision': 0.7345750873108265, 'recall': 0.7704517704517705, 'f1-score': 0.7520858164481525, 'auc': 0.742903787847608}
#   0%|          | 0/8176 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.726161369193154, 'precision': 0.7284090909090909, 'recall': 0.7541176470588236, 'f1-score': 0.7410404624277458, 'auc': 0.7250232001197425}
#   0%|          | 0/8082 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.7346938775510204, 'precision': 0.722158438576349, 'recall': 0.7708333333333334, 'f1-score': 0.7457024303497332, 'auc': 0.7343554931335831}

# %%
DATA_NUMBER=5
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : blip.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.5071193866374589, 'precision': 0.5280575539568345, 'recall': 0.3908413205537806, 'f1-score': 0.44920440636474906, 'auc': 0.5105277628699004}
#   0%|          | 0/8994 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.49583101723179546, 'precision': 0.48764769065520946, 'recall': 0.5135746606334841, 'f1-score': 0.5002754820936639, 'auc': 0.49613159261182405}
#   0%|          | 0/9084 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.5134837644468905, 'precision': 0.5006944444444444, 'recall': 0.8137697516930023, 'f1-score': 0.6199484092863284, 'auc': 0.5207409445897879}
#   0%|          | 0/9188 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.5217627856365615, 'precision': 0.5173010380622838, 'recall': 0.6507072905331882, 'f1-score': 0.5763855421686747, 'auc': 0.5217627856365614}
#   0%|          | 0/9122 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.5057534246575343, 'precision': 0.5126582278481012, 'recall': 0.35294117647058826, 'f1-score': 0.4180645161290323, 'auc': 0.506680070043453}
#   0%|          | 0/9204 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.518739815317762, 'precision': 0.5317139001349528, 'recall': 0.42229367631296894, 'f1-score': 0.4707287933094385, 'auc': 0.5200675430022995}
#   0%|          | 0/8986 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.5150166852057843, 'precision': 0.5250338294993234, 'recall': 0.42684268426842686, 'f1-score': 0.470873786407767, 'auc': 0.5160085187371382}
#   0%|          | 0/9204 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.4915806626833243, 'precision': 0.4890710382513661, 'recall': 0.38913043478260867, 'f1-score': 0.4334140435835351, 'auc': 0.4915250436670916}
#   0%|          | 0/9138 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.5016411378555798, 'precision': 0.4932182490752158, 'recall': 0.4444444444444444, 'f1-score': 0.46756282875511396, 'auc': 0.5007782567049809}
#   0%|          | 0/9030 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.5166112956810631, 'precision': 0.5127877237851662, 'recall': 0.4490481522956327, 'f1-score': 0.4788059701492537, 'auc': 0.5158712831576739}

# %%
DATA_NUMBER=6
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : incrementalDrift.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.7262569832402235, 'precision': 0.7433628318584071, 'recall': 0.711864406779661, 'f1-score': 0.7272727272727273, 'auc': 0.7266328403325056}
#   0%|          | 0/8072 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.6334365325077399, 'precision': 0.6866566716641679, 'recall': 0.544589774078478, 'f1-score': 0.6074270557029177, 'auc': 0.6372819671425981}
#   0%|          | 0/8060 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.6699751861042184, 'precision': 0.6784660766961652, 'recall': 0.5943152454780362, 'f1-score': 0.6336088154269973, 'auc': 0.667086023693672}
#   0%|          | 0/8024 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.6959501557632399, 'precision': 0.71671388101983, 'recall': 0.6372795969773299, 'f1-score': 0.6746666666666665, 'auc': 0.695335236219861}
#   0%|          | 0/8006 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.7153558052434457, 'precision': 0.7359009628610729, 'recall': 0.6695869837296621, 'f1-score': 0.7011795543905635, 'auc': 0.7152418106693141}
#   0%|          | 0/8012 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.7217716781035558, 'precision': 0.7472826086956522, 'recall': 0.6790123456790124, 'f1-score': 0.7115135834411385, 'auc': 0.7222300063830118}
#   0%|          | 0/8082 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.7074829931972789, 'precision': 0.7372549019607844, 'recall': 0.6746411483253588, 'f1-score': 0.7045596502186133, 'auc': 0.7086393961857267}
#   0%|          | 0/8088 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.7187886279357231, 'precision': 0.7408376963350786, 'recall': 0.6877278250303767, 'f1-score': 0.7132955261499686, 'auc': 0.7193356106283959}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.735330836454432, 'precision': 0.7503410641200545, 'recall': 0.695322376738306, 'f1-score': 0.7217847769028871, 'auc': 0.7348375138931973}
#   0%|          | 0/8092 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.7251389746757257, 'precision': 0.7217741935483871, 'recall': 0.6929032258064516, 'f1-score': 0.7070441079657671, 'auc': 0.7238212811496711}

# %%
DATA_NUMBER=7
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7gradualDrift.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.6394891944990176, 'precision': 0.609375, 'recall': 0.7692307692307693, 'f1-score': 0.6800348735832608, 'auc': 0.6399969893120578}
#   0%|          | 0/10100 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.6405940594059406, 'precision': 0.6179507545671168, 'recall': 0.7605083088954057, 'f1-score': 0.6818580192813322, 'auc': 0.6390304834346637}
#   0%|          | 0/10124 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.6582716049382716, 'precision': 0.624124513618677, 'recall': 0.7932739861523245, 'f1-score': 0.6986062717770035, 'auc': 0.6584713126027895}
#   0%|          | 0/10092 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.6656760772659732, 'precision': 0.6353846153846154, 'recall': 0.804284323271665, 'f1-score': 0.7099269445638161, 'auc': 0.6632308713132519}
#   0%|          | 0/10082 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.6668319286068418, 'precision': 0.6452119309262166, 'recall': 0.7888675623800384, 'f1-score': 0.7098445595854923, 'auc': 0.6626389093951474}
#   0%|          | 0/10050 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.6656716417910448, 'precision': 0.627172195892575, 'recall': 0.7987927565392354, 'f1-score': 0.7026548672566373, 'auc': 0.6671129137026885}
#   0%|          | 0/10276 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.6400778210116731, 'precision': 0.6118827160493827, 'recall': 0.7699029126213592, 'f1-score': 0.6818572656921754, 'auc': 0.6398247506576582}
#   0%|          | 0/10128 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.6475814412635735, 'precision': 0.602952602952603, 'recall': 0.7926455566905005, 'f1-score': 0.6849073256840247, 'auc': 0.652292214830446}
#   0%|          | 0/10178 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.656188605108055, 'precision': 0.6343919442292796, 'recall': 0.7822349570200573, 'f1-score': 0.7005988023952096, 'auc': 0.6524926049003219}
#   0%|          | 0/10160 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.6619094488188977, 'precision': 0.6376811594202898, 'recall': 0.7977099236641222, 'f1-score': 0.708774904620602, 'auc': 0.657493173214175}

# %%
DATA_NUMBER=8
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7suddenDrift.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.6246290801186943, 'precision': 0.5782575173477256, 'recall': 0.7796257796257796, 'f1-score': 0.6640106241699868, 'auc': 0.6317940218883615}
#   0%|          | 0/10062 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.6602086438152012, 'precision': 0.6368715083798883, 'recall': 0.7770204479065238, 'f1-score': 0.7, 'auc': 0.6577800008295296}
#   0%|          | 0/10020 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.6631736526946108, 'precision': 0.6408450704225352, 'recall': 0.7913043478260869, 'f1-score': 0.7081712062256809, 'auc': 0.6588100686498857}
#   0%|          | 0/10054 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.6454500248632521, 'precision': 0.6166407465007776, 'recall': 0.7828232971372162, 'f1-score': 0.6898651587646804, 'auc': 0.6444176605926563}
#   0%|          | 0/10186 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.6643768400392541, 'precision': 0.6236220472440945, 'recall': 0.7935871743486974, 'f1-score': 0.6984126984126985, 'auc': 0.6669858948666565}
#   0%|          | 0/10188 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.6673209028459274, 'precision': 0.6332807570977917, 'recall': 0.7903543307086615, 'f1-score': 0.7031523642732048, 'auc': 0.6676820577222369}
#   0%|          | 0/10132 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.6655155402072027, 'precision': 0.6347687400318979, 'recall': 0.7834645669291339, 'f1-score': 0.7013215859030837, 'auc': 0.6652238759472573}
#   0%|          | 0/10170 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.6450344149459194, 'precision': 0.6161462300076161, 'recall': 0.7877312560856865, 'f1-score': 0.6914529914529914, 'auc': 0.6436173658779971}
#   0%|          | 0/10216 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.6545988258317026, 'precision': 0.6166407465007776, 'recall': 0.7882703777335984, 'f1-score': 0.6919720767888308, 'auc': 0.6566592736452193}
#   0%|          | 0/10234 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.6619443087445042, 'precision': 0.6213895394223263, 'recall': 0.7936191425722832, 'f1-score': 0.6970227670753065, 'auc': 0.6645298777995515}
