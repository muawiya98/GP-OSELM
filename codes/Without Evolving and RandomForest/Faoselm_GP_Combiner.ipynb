# %%
# !pip install -q scikit-multiflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.6/450.6 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-multiflow (setup.py) ... done

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from skmultiflow.drift_detection import ADWIN, DDM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from matplotlib.colors import ListedColormap
from multiprocessing.pool import ThreadPool
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle
from contextlib import suppress
from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from random import shuffle
import seaborn as sns
from time import time
import pandas as pd
import numpy as np
import warnings
import scipy.io
import pickle
import sys
import gc
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/data'
code_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Codes/Shared Codes'
results_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Results'
feature_selection_results = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_results'
sys.path.insert(0,code_path)
from oselm import set_use_know
from SharedFunctions import main,generate_oselm_models

# %%
filenames = ['kddcup99_csv.csv','ISCX2012.csv','CSE-CIC2018.csv','CICIDS2017.csv','7recurrentDrift.csv', 'blip.csv', 'incrementalDrift.csv',
             '7gradualDrift.csv', '7suddenDrift.csv']
filenames = list(map(lambda x: os.path.join(data_path, x), filenames))

# %%
data_name = ['kddcup99','ISCX2012','CSE-CIC2018','CICIDS2017','7recurrentDrift', 'blip', 'incrementalDrift','7gradualDrift', '7suddenDrift']

# %%
# # use_know = False
# # set_use_know(use_know)
# # path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
# # os.makedirs(path, exist_ok=True)
# # for f_name,d_name in zip(filenames,data_name):
# #   main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
# #        feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path)

# %%
DATA_NUMBER=0
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : kddcup99_csv.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.9955099422706863, 'precision': 0.9975609756097561, 'recall': 0.9939246658566221, 'f1-score': 0.9957395009129641, 'auc': 0.9956036372761372}
#   0%|          | 0/7832 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.9948947032546267, 'precision': 0.9935400516795866, 'recall': 0.9961139896373057, 'f1-score': 0.9948253557567917, 'auc': 0.9949123407306025}
#   0%|          | 0/7836 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.9942602040816326, 'precision': 0.9975308641975309, 'recall': 0.9914110429447853, 'f1-score': 0.9944615384615385, 'auc': 0.9943775002240527}
#   0%|          | 0/7876 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.9949238578680203, 'precision': 0.9962871287128713, 'recall': 0.9938271604938271, 'f1-score': 0.9950556242274413, 'auc': 0.9949553557038326}
#   0%|          | 0/7854 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.9929980903882877, 'precision': 0.9934895833333334, 'recall': 0.9921976592977894, 'f1-score': 0.992843201040989, 'auc': 0.992981622666351}
#   0%|          | 0/7916 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.9690656565656566, 'precision': 0.9945280437756497, 'recall': 0.9417098445595855, 'f1-score': 0.9673985362608116, 'auc': 0.9683918680926006}
#   0%|          | 0/7856 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.989821882951654, 'precision': 0.9869791666666666, 'recall': 0.9921465968586387, 'f1-score': 0.9895561357702348, 'auc': 0.9898851796174382}
#   0%|          | 0/7896 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.990506329113924, 'precision': 0.9962311557788944, 'recall': 0.9850931677018634, 'f1-score': 0.9906308557151781, 'auc': 0.990611099979964}
#   0%|          | 0/7892 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.9791006966434452, 'precision': 0.9987179487179487, 'recall': 0.9605425400739828, 'f1-score': 0.9792583280955375, 'auc': 0.9796202283703246}
#   0%|          | 0/7790 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.9281129653401797, 'precision': 0.8744343891402715, 'recall': 0.9987080103359173, 'f1-score': 0.9324487334137516, 'auc': 0.928563188841428}

# %%
DATA_NUMBER=1
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : ISCX2012.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.728402734617775, 'precision': 0.9939759036144579, 'recall': 0.43137254901960786, 'f1-score': 0.601640838650866, 'auc': 0.7145014403865813}
#   0%|          | 0/8018 [00:00<?, ?it/s]
# RandomForest
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2 {'accuracy': 0.48192019950124687, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'auc': 0.5}
#   0%|          | 0/8004 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.7276702061211743, 'precision': 1.0, 'recall': 0.44599745870393903, 'f1-score': 0.616871704745167, 'auc': 0.7229987293519695}
#   0%|          | 0/8040 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.7257462686567164, 'precision': 1.0, 'recall': 0.45285359801488834, 'f1-score': 0.623398804440649, 'auc': 0.7264267990074442}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.7340823970037453, 'precision': 1.0, 'recall': 0.45663265306122447, 'f1-score': 0.6269702276707529, 'auc': 0.7283163265306123}
#   0%|          | 0/8018 [00:00<?, ?it/s]
# RandomForest
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 6 {'accuracy': 0.49875311720698257, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'auc': 0.5}
#   0%|          | 0/8026 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.727895392278954, 'precision': 0.9943181818181818, 'recall': 0.445859872611465, 'f1-score': 0.6156552330694811, 'auc': 0.721711909509143}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# RandomForest
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 8 {'accuracy': 0.5037453183520599, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'auc': 0.5}
#   0%|          | 0/8138 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.7266584766584766, 'precision': 1.0, 'recall': 0.4579780755176614, 'f1-score': 0.6282372598162071, 'auc': 0.7289890377588307}
#   0%|          | 0/8122 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.7218461538461538, 'precision': 1.0, 'recall': 0.45278450363196127, 'f1-score': 0.6233333333333333, 'auc': 0.7263922518159807}

# %%
DATA_NUMBER=2
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CSE-CIC2018.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 0.5}
#   0%|          | 0/8000 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.09125, 'precision': 0.9931972789115646, 'recall': 0.09130706691682301, 'f1-score': 0.1672394043528064, 'auc': 0.045653533458411506}
#   0%|          | 0/15972 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15970 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.9946775203506575, 'precision': 0.9900062460961899, 'recall': 0.9993694829760403, 'f1-score': 0.9946658299341073, 'auc': 0.9947096171099107}
#   0%|          | 0/15964 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.996868149076104, 'precision': 0.9936868686868687, 'recall': 1.0, 'f1-score': 0.9968334388853705, 'auc': 0.996911673872761}
#   0%|          | 0/15982 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.9340006255864873, 'precision': 0.8819910514541387, 'recall': 1.0, 'f1-score': 0.937295690936107, 'auc': 0.9348765432098766}
#   0%|          | 0/15984 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15978 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.9993742177722152, 'precision': 0.9987341772151899, 'recall': 1.0, 'f1-score': 0.999366687777074, 'auc': 0.9993819530284301}
#   0%|          | 0/15962 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15986 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.9937460913070669, 'precision': 0.9874134675896791, 'recall': 1.0, 'f1-score': 0.993666877770741, 'auc': 0.9938612645794966}

# %%
DATA_NUMBER=3
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CICIDS2017.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.9900935608145295, 'precision': 0.981859410430839, 'recall': 0.9976958525345622, 'f1-score': 0.9897142857142857, 'auc': 0.9904180000291357}
#   0%|          | 0/8974 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.9086350974930362, 'precision': 0.8524904214559387, 'recall': 0.9888888888888889, 'f1-score': 0.9156378600823046, 'auc': 0.9084109248913719}
#   0%|          | 0/9012 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.9245701608430393, 'precision': 0.8772770853307766, 'recall': 0.991332611050921, 'f1-score': 0.930824008138352, 'auc': 0.9229390327981877}
#   0%|          | 0/9038 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.9646017699115044, 'precision': 0.9321851453175457, 'recall': 0.9988465974625144, 'f1-score': 0.9643652561247216, 'auc': 0.9659482721637759}
#   0%|          | 0/9240 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.8582251082251082, 'precision': 0.7815993121238177, 'recall': 0.9912758996728462, 'f1-score': 0.8740384615384615, 'auc': 0.8592254901156928}
#   0%|          | 0/8962 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.9291689905186837, 'precision': 0.9107142857142857, 'recall': 0.9537953795379538, 'f1-score': 0.9317571198280494, 'auc': 0.9288207666920538}
#   0%|          | 0/8888 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.9566929133858267, 'precision': 0.9283489096573209, 'recall': 0.991130820399113, 'f1-score': 0.9587131367292225, 'auc': 0.956181848555721}
#   0%|          | 0/8910 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.8911335578002245, 'precision': 0.8371868978805395, 'recall': 0.9720357941834452, 'f1-score': 0.8995859213250518, 'auc': 0.890860239434065}
#   0%|          | 0/8874 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.6985915492957746, 'precision': 0.6213314244810307, 'recall': 0.9931350114416476, 'f1-score': 0.7644209599295464, 'auc': 0.703004797618715}
#   0%|          | 0/8898 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.9067415730337078, 'precision': 0.8616600790513834, 'recall': 0.9710467706013363, 'f1-score': 0.913089005235602, 'auc': 0.9061583059355889}

# %%
DATA_NUMBER=4
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7recurrentDrift.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.7492260061919505, 'precision': 0.762796504369538, 'recall': 0.7397094430992736, 'f1-score': 0.7510755992624462, 'auc': 0.7494491448702959}
#   0%|          | 0/8120 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.7179802955665024, 'precision': 0.7370325693606755, 'recall': 0.717978848413631, 'f1-score': 0.7273809523809524, 'auc': 0.7179803685793898}
#   0%|          | 0/8070 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.7304832713754646, 'precision': 0.7398773006134969, 'recall': 0.7300242130750605, 'f1-score': 0.7349177330895794, 'auc': 0.7304943400400683}
#   0%|          | 0/8146 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.7147239263803681, 'precision': 0.7033218785796106, 'recall': 0.748780487804878, 'f1-score': 0.7253396337861785, 'auc': 0.7145137006925625}
#   0%|          | 0/8034 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.7249533291848165, 'precision': 0.7247058823529412, 'recall': 0.7475728155339806, 'f1-score': 0.7359617682198327, 'auc': 0.7243611204106685}
#   0%|          | 0/8058 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.7233250620347395, 'precision': 0.7460732984293194, 'recall': 0.6934306569343066, 'f1-score': 0.7187894073139975, 'auc': 0.7239305183405711}
#   0%|          | 0/8002 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.7214241099312929, 'precision': 0.71849234393404, 'recall': 0.7466340269277846, 'f1-score': 0.7322929171668668, 'auc': 0.7208935440761373}
#   0%|          | 0/8100 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.7358024691358025, 'precision': 0.7239404352806414, 'recall': 0.7716727716727717, 'f1-score': 0.7470449172576833, 'auc': 0.7353994320286454}
#   0%|          | 0/8176 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.7224938875305623, 'precision': 0.720489977728285, 'recall': 0.7611764705882353, 'f1-score': 0.740274599542334, 'auc': 0.720919024098189}
#   0%|          | 0/8082 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.7161410018552876, 'precision': 0.7168894289185905, 'recall': 0.7230392156862745, 'f1-score': 0.7199511897498474, 'auc': 0.7160764118381435}

# %%
DATA_NUMBER=5
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : blip.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.5120481927710844, 'precision': 0.532258064516129, 'recall': 0.4217252396166134, 'f1-score': 0.47058823529411764, 'auc': 0.514695765242354}
#   0%|          | 0/8994 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.49305169538632576, 'precision': 0.4866666666666667, 'recall': 0.5780542986425339, 'f1-score': 0.5284384694932782, 'auc': 0.49449163019558395}
#   0%|          | 0/9084 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.5123830489818382, 'precision': 0.5, 'recall': 0.6410835214446953, 'f1-score': 0.5618199802176064, 'auc': 0.5154934255988246}
#   0%|          | 0/9188 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.5255712731229597, 'precision': 0.5231527093596059, 'recall': 0.5778019586507073, 'f1-score': 0.5491209927611169, 'auc': 0.5255712731229597}
#   0%|          | 0/9122 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.5013698630136987, 'precision': 0.5044943820224719, 'recall': 0.4891067538126362, 'f1-score': 0.49668141592920356, 'auc': 0.501444225858909}
#   0%|          | 0/9204 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.518739815317762, 'precision': 0.5397631133671743, 'recall': 0.34190782422293675, 'f1-score': 0.41863517060367456, 'auc': 0.521174176428649}
#   0%|          | 0/8986 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.5022246941045606, 'precision': 0.5069169960474308, 'recall': 0.5643564356435643, 'f1-score': 0.5340968245705361, 'auc': 0.501525799374088}
#   0%|          | 0/9204 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.4888647474198805, 'precision': 0.4892086330935252, 'recall': 0.5173913043478261, 'f1-score': 0.502905441098785, 'auc': 0.4888802341500259}
#   0%|          | 0/9138 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.48194748358862144, 'precision': 0.47647647647647645, 'recall': 0.5288888888888889, 'f1-score': 0.5013164823591364, 'auc': 0.48265565134099614}
#   0%|          | 0/9030 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.5027685492801772, 'precision': 0.4977085242896425, 'recall': 0.6080627099664053, 'f1-score': 0.5473790322580646, 'auc': 0.5039218259580109}

# %%
DATA_NUMBER=6
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : incrementalDrift.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.7262569832402235, 'precision': 0.7433628318584071, 'recall': 0.711864406779661, 'f1-score': 0.7272727272727273, 'auc': 0.7266328403325056}
#   0%|          | 0/8072 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.6334365325077399, 'precision': 0.6866566716641679, 'recall': 0.544589774078478, 'f1-score': 0.6074270557029177, 'auc': 0.6372819671425981}
#   0%|          | 0/8060 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.6699751861042184, 'precision': 0.6784660766961652, 'recall': 0.5943152454780362, 'f1-score': 0.6336088154269973, 'auc': 0.667086023693672}
#   0%|          | 0/8024 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.6959501557632399, 'precision': 0.71671388101983, 'recall': 0.6372795969773299, 'f1-score': 0.6746666666666665, 'auc': 0.695335236219861}
#   0%|          | 0/8006 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.7153558052434457, 'precision': 0.7359009628610729, 'recall': 0.6695869837296621, 'f1-score': 0.7011795543905635, 'auc': 0.7152418106693141}
#   0%|          | 0/8012 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.7217716781035558, 'precision': 0.7472826086956522, 'recall': 0.6790123456790124, 'f1-score': 0.7115135834411385, 'auc': 0.7222300063830118}
#   0%|          | 0/8082 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.7074829931972789, 'precision': 0.7372549019607844, 'recall': 0.6746411483253588, 'f1-score': 0.7045596502186133, 'auc': 0.7086393961857267}
#   0%|          | 0/8088 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.7187886279357231, 'precision': 0.7408376963350786, 'recall': 0.6877278250303767, 'f1-score': 0.7132955261499686, 'auc': 0.7193356106283959}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.735330836454432, 'precision': 0.7503410641200545, 'recall': 0.695322376738306, 'f1-score': 0.7217847769028871, 'auc': 0.7348375138931973}
#   0%|          | 0/8092 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.7251389746757257, 'precision': 0.7217741935483871, 'recall': 0.6929032258064516, 'f1-score': 0.7070441079657671, 'auc': 0.7238212811496711}

# %%
DATA_NUMBER=7
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7gradualDrift.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.6394891944990176, 'precision': 0.609375, 'recall': 0.7692307692307693, 'f1-score': 0.6800348735832608, 'auc': 0.6399969893120578}
#   0%|          | 0/10100 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.6405940594059406, 'precision': 0.6179507545671168, 'recall': 0.7605083088954057, 'f1-score': 0.6818580192813322, 'auc': 0.6390304834346637}
#   0%|          | 0/10124 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.6582716049382716, 'precision': 0.624124513618677, 'recall': 0.7932739861523245, 'f1-score': 0.6986062717770035, 'auc': 0.6584713126027895}
#   0%|          | 0/10092 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.6656760772659732, 'precision': 0.6353846153846154, 'recall': 0.804284323271665, 'f1-score': 0.7099269445638161, 'auc': 0.6632308713132519}
#   0%|          | 0/10082 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.6668319286068418, 'precision': 0.6452119309262166, 'recall': 0.7888675623800384, 'f1-score': 0.7098445595854923, 'auc': 0.6626389093951474}
#   0%|          | 0/10050 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.6656716417910448, 'precision': 0.627172195892575, 'recall': 0.7987927565392354, 'f1-score': 0.7026548672566373, 'auc': 0.6671129137026885}
#   0%|          | 0/10276 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.6400778210116731, 'precision': 0.6118827160493827, 'recall': 0.7699029126213592, 'f1-score': 0.6818572656921754, 'auc': 0.6398247506576582}
#   0%|          | 0/10128 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.6475814412635735, 'precision': 0.602952602952603, 'recall': 0.7926455566905005, 'f1-score': 0.6849073256840247, 'auc': 0.652292214830446}
#   0%|          | 0/10178 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.656188605108055, 'precision': 0.6343919442292796, 'recall': 0.7822349570200573, 'f1-score': 0.7005988023952096, 'auc': 0.6524926049003219}
#   0%|          | 0/10160 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.6619094488188977, 'precision': 0.6376811594202898, 'recall': 0.7977099236641222, 'f1-score': 0.708774904620602, 'auc': 0.657493173214175}

# %%
DATA_NUMBER=8
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7suddenDrift.csv ======================
# 0it [00:00, ?it/s]
# RandomForest
# 1 {'accuracy': 0.6246290801186943, 'precision': 0.5782575173477256, 'recall': 0.7796257796257796, 'f1-score': 0.6640106241699868, 'auc': 0.6317940218883615}
#   0%|          | 0/10062 [00:00<?, ?it/s]
# RandomForest
# 2 {'accuracy': 0.6602086438152012, 'precision': 0.6368715083798883, 'recall': 0.7770204479065238, 'f1-score': 0.7, 'auc': 0.6577800008295296}
#   0%|          | 0/10020 [00:00<?, ?it/s]
# RandomForest
# 3 {'accuracy': 0.6631736526946108, 'precision': 0.6408450704225352, 'recall': 0.7913043478260869, 'f1-score': 0.7081712062256809, 'auc': 0.6588100686498857}
#   0%|          | 0/10054 [00:00<?, ?it/s]
# RandomForest
# 4 {'accuracy': 0.6454500248632521, 'precision': 0.6166407465007776, 'recall': 0.7828232971372162, 'f1-score': 0.6898651587646804, 'auc': 0.6444176605926563}
#   0%|          | 0/10186 [00:00<?, ?it/s]
# RandomForest
# 5 {'accuracy': 0.6643768400392541, 'precision': 0.6236220472440945, 'recall': 0.7935871743486974, 'f1-score': 0.6984126984126985, 'auc': 0.6669858948666565}
#   0%|          | 0/10188 [00:00<?, ?it/s]
# RandomForest
# 6 {'accuracy': 0.6673209028459274, 'precision': 0.6332807570977917, 'recall': 0.7903543307086615, 'f1-score': 0.7031523642732048, 'auc': 0.6676820577222369}
#   0%|          | 0/10132 [00:00<?, ?it/s]
# RandomForest
# 7 {'accuracy': 0.6655155402072027, 'precision': 0.6347687400318979, 'recall': 0.7834645669291339, 'f1-score': 0.7013215859030837, 'auc': 0.6652238759472573}
#   0%|          | 0/10170 [00:00<?, ?it/s]
# RandomForest
# 8 {'accuracy': 0.6450344149459194, 'precision': 0.6161462300076161, 'recall': 0.7877312560856865, 'f1-score': 0.6914529914529914, 'auc': 0.6436173658779971}
#   0%|          | 0/10216 [00:00<?, ?it/s]
# RandomForest
# 9 {'accuracy': 0.6545988258317026, 'precision': 0.6166407465007776, 'recall': 0.7882703777335984, 'f1-score': 0.6919720767888308, 'auc': 0.6566592736452193}
#   0%|          | 0/10234 [00:00<?, ?it/s]
# RandomForest
# 10 {'accuracy': 0.6619443087445042, 'precision': 0.6213895394223263, 'recall': 0.7936191425722832, 'f1-score': 0.6970227670753065, 'auc': 0.6645298777995515}
