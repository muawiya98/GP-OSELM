# %%
# !pip install -q scikit-multiflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.6/450.6 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from skmultiflow.drift_detection import ADWIN, DDM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from matplotlib.colors import ListedColormap
from multiprocessing.pool import ThreadPool
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle
from contextlib import suppress
from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from random import shuffle
import seaborn as sns
from time import time
import pandas as pd
import numpy as np
import warnings
import scipy.io
import pickle
import sys
import gc
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/data'
code_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Codes/Shared Codes'
results_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Results'
feature_selection_results = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_results'
sys.path.insert(0,code_path)
from oselm import set_use_know
from SharedFunctions import main,generate_oselm_models

# %%
filenames = ['kddcup99_csv.csv','ISCX2012.csv','CSE-CIC2018.csv','CICIDS2017.csv','7recurrentDrift.csv', 'blip.csv', 'incrementalDrift.csv',
             '7gradualDrift.csv', '7suddenDrift.csv']
filenames = list(map(lambda x: os.path.join(data_path, x), filenames))

# %%
data_name = ['kddcup99','ISCX2012','CSE-CIC2018','CICIDS2017','7recurrentDrift', 'blip', 'incrementalDrift','7gradualDrift', '7suddenDrift']

# %%
# # use_know = True
# # set_use_know(use_know)
# # path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving')
# # os.makedirs(path, exist_ok=True)
# # for f_name,d_name in zip(filenames,data_name):
# #   DFS_results_path = os.path.join(feature_selection_results,d_name)
# #   main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
# #        feature_selection=["feature_evolving",''], result_save_path=path,DFS_results_path=DFS_results_path)

# %%
DATA_NUMBER=0
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",''],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : kddcup99_csv.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.994868505452213, 'precision': 1.0, 'recall': 0.9902794653705954, 'f1-score': 0.995115995115995, 'auc': 0.9951397326852978}
#   0%|          | 0/7832 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.99617102744097, 'precision': 0.9986979166666666, 'recall': 0.9935233160621761, 'f1-score': 0.996103896103896, 'auc': 0.996132727213478}
#   0%|          | 0/7836 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.9961734693877551, 'precision': 0.998766954377312, 'recall': 0.9938650306748467, 'f1-score': 0.996309963099631, 'auc': 0.9962685047132533}
#   0%|          | 0/7876 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.9980964467005076, 'precision': 1.0, 'recall': 0.9962962962962963, 'f1-score': 0.9981447124304267, 'auc': 0.9981481481481482}
#   0%|          | 0/7854 [00:00<?, ?it/s]
# Without Any FS
# ...

# %%
DATA_NUMBER=1
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",''],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : ISCX2012.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.8738346799254195, 'precision': 0.986159169550173, 'recall': 0.7450980392156863, 'f1-score': 0.8488458674609084, 'auc': 0.8678096831149522}
#   0%|          | 0/8018 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.8603491271820449, 'precision': 0.9967266775777414, 'recall': 0.7328519855595668, 'f1-score': 0.8446601941747572, 'auc': 0.8651323317189813}
#   0%|          | 0/8004 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.5202998126171143, 'precision': 0.5061409179056238, 'recall': 0.9949174078780177, 'f1-score': 0.6709511568123394, 'auc': 0.5281712346515396}
#   0%|          | 0/8040 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.8370646766169154, 'precision': 0.9945454545454545, 'recall': 0.6786600496277916, 'f1-score': 0.8067846607669618, 'auc': 0.8374597006243696}
# ...

# %%
DATA_NUMBER=2
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",''],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CSE-CIC2018.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 0.5}
#   0%|          | 0/8000 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15972 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15970 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15964 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15982 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# ...

# %%
DATA_NUMBER=3
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",''],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CICIDS2017.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.9812878370941112, 'precision': 0.9643652561247216, 'recall': 0.9976958525345622, 'f1-score': 0.9807474518686298, 'auc': 0.9819880737909903}
#   0%|          | 0/8974 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.9832869080779945, 'precision': 0.9728260869565217, 'recall': 0.9944444444444445, 'f1-score': 0.9835164835164836, 'auc': 0.9832557417752947}
#   0%|          | 0/9012 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.954520244037715, 'precision': 0.9295199182839632, 'recall': 0.9859154929577465, 'f1-score': 0.9568874868559412, 'auc': 0.9537532010243278}
#   0%|          | 0/9038 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.9828539823008849, 'precision': 0.9675615212527964, 'recall': 0.9976931949250288, 'f1-score': 0.9823963657013061, 'auc': 0.9834374582489119}
# ...

# %%
DATA_NUMBER=4
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",''],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7recurrentDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.643343653250774, 'precision': 0.6513317191283293, 'recall': 0.6513317191283293, 'f1-score': 0.6513317191283293, 'auc': 0.6431563538607425}
#   0%|          | 0/8120 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.6496305418719212, 'precision': 0.6736453201970444, 'recall': 0.6427732079905993, 'f1-score': 0.6578472639807577, 'auc': 0.6499765134390254}
#   0%|          | 0/8070 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.6232961586121437, 'precision': 0.6671779141104295, 'recall': 0.5266343825665859, 'f1-score': 0.5886332882273343, 'auc': 0.6256268359533438}
#   0%|          | 0/8146 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.6177914110429448, 'precision': 0.6014418125643667, 'recall': 0.7121951219512195, 'f1-score': 0.6521496370742602, 'auc': 0.6172086720867207}
# ...

# %%
DATA_NUMBER=5
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",''],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : blip.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.5027382256297919, 'precision': 0.552901023890785, 'recall': 0.17252396166134185, 'f1-score': 0.26298701298701294, 'auc': 0.5124175614394646}
#   0%|          | 0/8994 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.5086158977209561, 'precision': 0.5, 'recall': 0.7941176470588235, 'f1-score': 0.6136363636363636, 'auc': 0.5134522661523626}
#   0%|          | 0/9084 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.4991744634012108, 'precision': 0.4929411764705882, 'recall': 0.945823927765237, 'f1-score': 0.6481051817478731, 'auc': 0.5099688919169901}
#   0%|          | 0/9188 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.5059847660500544, 'precision': 0.5087440381558028, 'recall': 0.3482045701849837, 'f1-score': 0.41343669250646, 'auc': 0.5059847660500544}
#   0%|          | 0/9122 [00:00<?, ?it/s]
# ...

# %%
DATA_NUMBER=6
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",''],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : incrementalDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.6095592799503414, 'precision': 0.6280884265279584, 'recall': 0.5847457627118644, 'f1-score': 0.60564263322884, 'auc': 0.6102072762603908}
#   0%|          | 0/8072 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.6507739938080496, 'precision': 0.6530386740331492, 'recall': 0.7027348394768134, 'f1-score': 0.6769759450171821, 'auc': 0.6485250424774248}
#   0%|          | 0/8060 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.6470223325062034, 'precision': 0.6086956521739131, 'recall': 0.7416020671834626, 'f1-score': 0.6686080372743156, 'auc': 0.6506339691525905}
#   0%|          | 0/8024 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.6616822429906543, 'precision': 0.6380638063806381, 'recall': 0.7304785894206549, 'f1-score': 0.6811509101585438, 'auc': 0.6624032897781451}
# ...

# %%
DATA_NUMBER=7
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",''],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7gradualDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.6915520628683693, 'precision': 0.665807560137457, 'recall': 0.7642998027613412, 'f1-score': 0.711662075298439, 'auc': 0.6918367898346822}
#   0%|          | 0/10100 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.6346534653465347, 'precision': 0.5987525987525988, 'recall': 0.844574780058651, 'f1-score': 0.7007299270072992, 'auc': 0.6319162766893054}
#   0%|          | 0/10124 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.7145679012345679, 'precision': 0.7145688800792864, 'recall': 0.7131552917903067, 'f1-score': 0.7138613861386139, 'auc': 0.7145658115756267}
#   0%|          | 0/10092 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.637444279346211, 'precision': 0.5998645903859174, 'recall': 0.8627069133398247, 'f1-score': 0.707667731629393, 'auc': 0.6334703921537834}
# ...

# %%
DATA_NUMBER=8
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",''],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7suddenDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.705242334322453, 'precision': 0.658578856152513, 'recall': 0.7900207900207901, 'f1-score': 0.718336483931947, 'auc': 0.7091613384066214}
#   0%|          | 0/10062 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.6418281172379533, 'precision': 0.6071428571428571, 'recall': 0.8442064264849075, 'f1-score': 0.7063136456211813, 'auc': 0.6376204546217641}
#   0%|          | 0/10020 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.7075848303393214, 'precision': 0.7256281407035176, 'recall': 0.6975845410628019, 'f1-score': 0.7113300492610837, 'auc': 0.7079253974663855}
#   0%|          | 0/10054 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.6285430134261561, 'precision': 0.5939265536723164, 'recall': 0.8302073050345509, 'f1-score': 0.6924660354055167, 'auc': 0.6270275002126662}
# ...
