# %%
# !pip install -q scikit-multiflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.6/450.6 kB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-multiflow (setup.py) ... done

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from skmultiflow.drift_detection import ADWIN, DDM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from matplotlib.colors import ListedColormap
from multiprocessing.pool import ThreadPool
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle
from contextlib import suppress
from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from random import shuffle
import seaborn as sns
from time import time
import pandas as pd
import numpy as np
import warnings
import scipy.io
import pickle
import sys
import gc
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/data'
code_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Codes/Shared Codes'
results_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Results'
feature_selection_results = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_results'
sys.path.insert(0,code_path)
from oselm import set_use_know
from SharedFunctions import main,generate_oselm_models

# %%
filenames = ['kddcup99_csv.csv','ISCX2012.csv','CSE-CIC2018.csv','CICIDS2017.csv','7recurrentDrift.csv', 'blip.csv', 'incrementalDrift.csv',
             '7gradualDrift.csv', '7suddenDrift.csv']
filenames = list(map(lambda x: os.path.join(data_path, x), filenames))

# %%
data_name = ['kddcup99','ISCX2012','CSE-CIC2018','CICIDS2017','7recurrentDrift', 'blip', 'incrementalDrift','7gradualDrift', '7suddenDrift']

# %%
# # use_know = False
# # set_use_know(use_know)
# # path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving')
# # os.makedirs(path, exist_ok=True)
# # for f_name,d_name in zip(filenames,data_name):
# #   DFS_results_path = os.path.join(feature_selection_results,d_name)
# #   main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
# #        feature_selection=["feature_evolving",''], result_save_path=path,DFS_results_path=DFS_results_path)

# %%
DATA_NUMBER=0
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
     feature_selection=["feature_evolving",''],result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : kddcup99_csv.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.994868505452213, 'precision': 1.0, 'recall': 0.9902794653705954, 'f1-score': 0.995115995115995, 'auc': 0.9951397326852978}
#   0%|          | 0/7832 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.9968091895341417, 'precision': 1.0, 'recall': 0.9935233160621761, 'f1-score': 0.9967511371020142, 'auc': 0.9967616580310881}
#   0%|          | 0/7836 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.9961734693877551, 'precision': 0.998766954377312, 'recall': 0.9938650306748467, 'f1-score': 0.996309963099631, 'auc': 0.9962685047132533}
#   0%|          | 0/7876 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.9974619289340102, 'precision': 1.0, 'recall': 0.9950617283950617, 'f1-score': 0.9975247524752474, 'auc': 0.9975308641975309}
#   0%|          | 0/7854 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.9968173138128581, 'precision': 1.0, 'recall': 0.9934980494148244, 'f1-score': 0.9967384213959556, 'auc': 0.9967490247074122}
#   0%|          | 0/7916 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.9974747474747475, 'precision': 1.0, 'recall': 0.9948186528497409, 'f1-score': 0.9974025974025974, 'auc': 0.9974093264248705}
#   0%|          | 0/7856 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.9949109414758269, 'precision': 1.0, 'recall': 0.9895287958115183, 'f1-score': 0.9947368421052631, 'auc': 0.9947643979057592}
#   0%|          | 0/7896 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.9930379746835443, 'precision': 1.0, 'recall': 0.986335403726708, 'f1-score': 0.9931207004377736, 'auc': 0.993167701863354}
#   0%|          | 0/7892 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.9949335022165928, 'precision': 1.0, 'recall': 0.9901356350184957, 'f1-score': 0.9950433705080546, 'auc': 0.9950678175092478}
#   0%|          | 0/7790 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.9961489088575096, 'precision': 0.9987012987012988, 'recall': 0.9935400516795866, 'f1-score': 0.9961139896373058, 'auc': 0.9961322707377525}

# %%
DATA_NUMBER=1
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
     feature_selection=["feature_evolving",''],result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : ISCX2012.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.8744561839651958, 'precision': 0.9861830742659758, 'recall': 0.74640522875817, 'f1-score': 0.8497023809523809, 'auc': 0.868463277886194}
#   0%|          | 0/8018 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.6670822942643392, 'precision': 0.9380530973451328, 'recall': 0.38267148014440433, 'f1-score': 0.5435897435897435, 'auc': 0.6777522989337805}
#   0%|          | 0/8004 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.7195502810743285, 'precision': 0.9543010752688172, 'recall': 0.45108005082592123, 'f1-score': 0.6125970664365833, 'auc': 0.7150977649707002}
#   0%|          | 0/8040 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.8669154228855721, 'precision': 0.9933333333333333, 'recall': 0.739454094292804, 'f1-score': 0.8477951635846372, 'auc': 0.8672332815603672}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.8863920099875156, 'precision': 1.0, 'recall': 0.7678571428571429, 'f1-score': 0.8686868686868687, 'auc': 0.8839285714285714}
#   0%|          | 0/8018 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.8534912718204489, 'precision': 0.9965095986038395, 'recall': 0.7101990049751243, 'f1-score': 0.8293391430646332, 'auc': 0.8538495024875622}
#   0%|          | 0/8026 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.8717310087173101, 'precision': 0.9965694682675815, 'recall': 0.7401273885350318, 'f1-score': 0.8494152046783625, 'auc': 0.8688456674709264}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.869538077403246, 'precision': 0.9916107382550335, 'recall': 0.7433962264150943, 'f1-score': 0.8497483824586628, 'auc': 0.8686002197750813}
#   0%|          | 0/8138 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.8556511056511057, 'precision': 0.9949324324324325, 'recall': 0.7174177831912302, 'f1-score': 0.8336871903750884, 'auc': 0.8568501555361355}
#   0%|          | 0/8122 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.8596923076923076, 'precision': 0.9933993399339934, 'recall': 0.7288135593220338, 'f1-score': 0.840782122905028, 'auc': 0.861903650749878}

# %%
DATA_NUMBER=2
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
     feature_selection=["feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CSE-CIC2018.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 0.5}
#   0%|          | 0/8000 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15972 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15970 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15964 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15982 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15984 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15978 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15962 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15986 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}

# %%
DATA_NUMBER=3
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
     feature_selection=["feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CICIDS2017.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.9807374793615851, 'precision': 0.9632925472747497, 'recall': 0.9976958525345622, 'f1-score': 0.9801924165251839, 'auc': 0.9814612034011062}
#   0%|          | 0/8974 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.9877437325905293, 'precision': 0.9792576419213974, 'recall': 0.9966666666666667, 'f1-score': 0.9878854625550662, 'auc': 0.9877188081936685}
#   0%|          | 0/9012 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.985579589572934, 'precision': 0.9776357827476039, 'recall': 0.9945828819068255, 'f1-score': 0.9860365198711063, 'auc': 0.9853596227715946}
#   0%|          | 0/9038 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.9856194690265486, 'precision': 0.9740698985343855, 'recall': 0.9965397923875432, 'f1-score': 0.9851767388825542, 'auc': 0.9860488547485006}
#   0%|          | 0/9240 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.9816017316017316, 'precision': 0.9691817215727949, 'recall': 0.9945474372955289, 'f1-score': 0.9817007534983854, 'auc': 0.9816990677347678}
#   0%|          | 0/8962 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.984941438929169, 'precision': 0.9783080260303688, 'recall': 0.9922992299229924, 'f1-score': 0.9852539595849263, 'auc': 0.9848373977669259}
#   0%|          | 0/8888 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.9820022497187851, 'precision': 0.9697624190064795, 'recall': 0.9955654101995566, 'f1-score': 0.9824945295404814, 'auc': 0.9818009699399609}
#   0%|          | 0/8910 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.9837261503928171, 'precision': 0.970620239390642, 'recall': 0.9977628635346756, 'f1-score': 0.9840044125758411, 'auc': 0.9836787290646352}
#   0%|          | 0/8874 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.9870422535211267, 'precision': 0.979706877113867, 'recall': 0.994279176201373, 'f1-score': 0.986939239068711, 'auc': 0.9871506868798208}
#   0%|          | 0/8898 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.9859550561797753, 'precision': 0.9791437980241493, 'recall': 0.9933184855233853, 'f1-score': 0.9861802100608071, 'auc': 0.9858882677050034}

# %%
DATA_NUMBER=4
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
     feature_selection=["feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7recurrentDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.6402476780185758, 'precision': 0.6495726495726496, 'recall': 0.6440677966101694, 'f1-score': 0.6468085106382979, 'auc': 0.640158106163133}
#   0%|          | 0/8120 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.6477832512315271, 'precision': 0.6728624535315985, 'recall': 0.6380728554641598, 'f1-score': 0.655006031363088, 'auc': 0.6482731677062067}
#   0%|          | 0/8070 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.6548946716232962, 'precision': 0.6584216725559482, 'recall': 0.6767554479418886, 'f1-score': 0.6674626865671641, 'auc': 0.6543675716866802}
#   0%|          | 0/8146 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.6576687116564417, 'precision': 0.6566985645933014, 'recall': 0.6695121951219513, 'f1-score': 0.6630434782608696, 'auc': 0.6575956037338151}
#   0%|          | 0/8034 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.6695706285003111, 'precision': 0.670547147846333, 'recall': 0.6990291262135923, 'f1-score': 0.6844919786096256, 'auc': 0.6687993651502189}
#   0%|          | 0/8058 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.6203473945409429, 'precision': 0.6258992805755396, 'recall': 0.635036496350365, 'f1-score': 0.6304347826086957, 'auc': 0.6200498937448028}
#   0%|          | 0/8002 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.6102435977514054, 'precision': 0.6166868198307134, 'recall': 0.6242350061199511, 'f1-score': 0.6204379562043796, 'auc': 0.6099491357130368}
#   0%|          | 0/8100 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.678395061728395, 'precision': 0.6732558139534883, 'recall': 0.706959706959707, 'f1-score': 0.6896962477665276, 'auc': 0.6780741106583804}
#   0%|          | 0/8176 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.6185819070904646, 'precision': 0.6326291079812206, 'recall': 0.6341176470588236, 'f1-score': 0.6333725029377204, 'auc': 0.6179494087711421}
#   0%|          | 0/8082 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.660482374768089, 'precision': 0.6557759626604434, 'recall': 0.6887254901960784, 'f1-score': 0.6718469814704123, 'auc': 0.6602179261217596}

# %%
DATA_NUMBER=5
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
     feature_selection=["feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : blip.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.49726177437020813, 'precision': 0.5337620578778135, 'recall': 0.17678381256656017, 'f1-score': 0.2656, 'auc': 0.5066557168807998}
#   0%|          | 0/8994 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.5097276264591439, 'precision': 0.500709219858156, 'recall': 0.7986425339366516, 'f1-score': 0.6155187445510026, 'auc': 0.5146218134164132}
#   0%|          | 0/9084 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.4826637314254265, 'precision': 0.4640957446808511, 'recall': 0.3939051918735892, 'f1-score': 0.4261294261294261, 'auc': 0.4805186539389429}
#   0%|          | 0/9188 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.5081610446137106, 'precision': 0.5113122171945701, 'recall': 0.36887921653971706, 'f1-score': 0.4285714285714286, 'auc': 0.5081610446137105}
#   0%|          | 0/9122 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.5128767123287671, 'precision': 0.5399449035812672, 'recall': 0.21350762527233116, 'f1-score': 0.3060109289617487, 'auc': 0.5146920706295504}
#   0%|          | 0/9204 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.4964693101575231, 'precision': 0.5098684210526315, 'recall': 0.16613076098606644, 'f1-score': 0.25060630557801133, 'auc': 0.5010169223432535}
#   0%|          | 0/8986 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.517797552836485, 'precision': 0.547085201793722, 'recall': 0.2684268426842684, 'f1-score': 0.36014760147601477, 'auc': 0.5206026226919654}
#   0%|          | 0/9204 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.4964693101575231, 'precision': 0.4903047091412742, 'recall': 0.1923913043478261, 'f1-score': 0.2763466042154567, 'auc': 0.4963042298069206}
#   0%|          | 0/9138 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.513129102844639, 'precision': 0.5086505190311419, 'recall': 0.32666666666666666, 'f1-score': 0.39783491204330174, 'auc': 0.5103160919540229}
#   0%|          | 0/9030 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.5083056478405316, 'precision': 0.5017519271198319, 'recall': 0.8017917133258678, 'f1-score': 0.6172413793103448, 'auc': 0.5115201721065264}

# %%
DATA_NUMBER=6
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
     feature_selection=["feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : incrementalDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.6871508379888268, 'precision': 0.6987654320987654, 'recall': 0.6852300242130751, 'f1-score': 0.6919315403422984, 'auc': 0.6872009993676841}
#   0%|          | 0/8072 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.6891640866873066, 'precision': 0.7020262216924911, 'recall': 0.7003567181926278, 'f1-score': 0.7011904761904761, 'auc': 0.688679651085978}
#   0%|          | 0/8060 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.674937965260546, 'precision': 0.6513317191283293, 'recall': 0.6950904392764858, 'f1-score': 0.6725000000000001, 'auc': 0.675707510807694}
#   0%|          | 0/8024 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.6728971962616822, 'precision': 0.669609079445145, 'recall': 0.6687657430730478, 'f1-score': 0.6691871455576559, 'auc': 0.6728538949643907}
#   0%|          | 0/8006 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.6142322097378277, 'precision': 0.6107711138310894, 'recall': 0.6245306633291614, 'f1-score': 0.6175742574257426, 'auc': 0.614257859684506}
#   0%|          | 0/8012 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.6862133499688085, 'precision': 0.6766398158803222, 'recall': 0.725925925925926, 'f1-score': 0.7004169148302561, 'auc': 0.6857876792303021}
#   0%|          | 0/8082 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.6338899196042053, 'precision': 0.6480582524271845, 'recall': 0.638755980861244, 'f1-score': 0.6433734939759036, 'auc': 0.6337185794190983}
#   0%|          | 0/8088 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.6118665018541409, 'precision': 0.6238881829733164, 'recall': 0.5965978128797084, 'f1-score': 0.6099378881987577, 'auc': 0.6121353844272757}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.6416978776529338, 'precision': 0.6392811296534018, 'recall': 0.629582806573957, 'f1-score': 0.6343949044585988, 'auc': 0.6415484932993089}
#   0%|          | 0/8092 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.6213712168004941, 'precision': 0.6035805626598465, 'recall': 0.6090322580645161, 'f1-score': 0.6062941554271033, 'auc': 0.6208668399327321}

# %%
DATA_NUMBER=7
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
     feature_selection=["feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7gradualDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.7043222003929273, 'precision': 0.701171875, 'recall': 0.7080867850098619, 'f1-score': 0.704612365063788, 'auc': 0.7043369345792949}
#   0%|          | 0/10100 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.698019801980198, 'precision': 0.7054726368159204, 'recall': 0.6930596285434996, 'f1-score': 0.6992110453648915, 'auc': 0.6980844782637257}
#   0%|          | 0/10124 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.7180246913580247, 'precision': 0.691304347826087, 'recall': 0.7863501483679525, 'f1-score': 0.7357704766311893, 'auc': 0.718125764519282}
#   0%|          | 0/10092 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.6968796433878157, 'precision': 0.6919518963922294, 'recall': 0.7283349561830574, 'f1-score': 0.7096774193548389, 'auc': 0.6963247361560448}
#   0%|          | 0/10082 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.7124442240951909, 'precision': 0.7012195121951219, 'recall': 0.772552783109405, 'f1-score': 0.7351598173515981, 'auc': 0.7103789556572666}
#   0%|          | 0/10050 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.7034825870646766, 'precision': 0.7022357723577236, 'recall': 0.6951710261569416, 'f1-score': 0.698685540950455, 'auc': 0.7033925996926441}
#   0%|          | 0/10276 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.708171206225681, 'precision': 0.6882661996497373, 'recall': 0.7631067961165049, 'f1-score': 0.7237569060773481, 'auc': 0.7080641193058158}
#   0%|          | 0/10128 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.6929911154985192, 'precision': 0.6755162241887905, 'recall': 0.7017364657814096, 'f1-score': 0.6883767535070141, 'auc': 0.6932751096815357}
#   0%|          | 0/10178 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.7185658153241651, 'precision': 0.7093639575971732, 'recall': 0.766953199617956, 'f1-score': 0.737035337310693, 'auc': 0.717146973924246}
#   0%|          | 0/10160 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.7091535433070866, 'precision': 0.695132365499573, 'recall': 0.7767175572519084, 'f1-score': 0.7336638125281658, 'auc': 0.7069563396015639}

# %%
DATA_NUMBER=8
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
     feature_selection=["feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7suddenDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.7101879327398615, 'precision': 0.6643356643356644, 'recall': 0.7900207900207901, 'f1-score': 0.7217473884140551, 'auc': 0.713878319538697}
#   0%|          | 0/10062 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.6845504222553402, 'precision': 0.696, 'recall': 0.6777020447906524, 'f1-score': 0.6867291563887519, 'auc': 0.6846928073851843}
#   0%|          | 0/10020 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.7085828343313373, 'precision': 0.6976336546888694, 'recall': 0.7690821256038647, 'f1-score': 0.7316176470588234, 'auc': 0.7065224869505391}
#   0%|          | 0/10054 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.69617105917454, 'precision': 0.6741767764298093, 'recall': 0.7680157946692991, 'f1-score': 0.7180433779418552, 'auc': 0.6956311438276356}
#   0%|          | 0/10186 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.6967615309126595, 'precision': 0.6599326599326599, 'recall': 0.7855711422845691, 'f1-score': 0.7172918572735589, 'auc': 0.6985548019115154}
#   0%|          | 0/10188 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.6943081452404318, 'precision': 0.691333982473223, 'recall': 0.6988188976377953, 'f1-score': 0.695056289769946, 'auc': 0.6943213861965883}
#   0%|          | 0/10132 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.718302910705476, 'precision': 0.7263479145473042, 'recall': 0.702755905511811, 'f1-score': 0.7143571785892946, 'auc': 0.7183413553276168}
#   0%|          | 0/10170 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.7123893805309734, 'precision': 0.6959219858156028, 'recall': 0.7643622200584226, 'f1-score': 0.728538283062645, 'auc': 0.7118732649448023}
#   0%|          | 0/10216 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.7113502935420744, 'precision': 0.6830985915492958, 'recall': 0.7713717693836978, 'f1-score': 0.7245564892623716, 'auc': 0.7122754800675714}
#   0%|          | 0/10234 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.7024914509037616, 'precision': 0.6669491525423729, 'recall': 0.7846460618145563, 'f1-score': 0.7210261108566193, 'auc': 0.7041046401026805}
