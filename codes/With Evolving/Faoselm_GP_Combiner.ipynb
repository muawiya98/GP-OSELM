# %%
# !pip install -q scikit-multiflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.6/450.6 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-multiflow (setup.py) ... done

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from skmultiflow.drift_detection import ADWIN, DDM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from matplotlib.colors import ListedColormap
from multiprocessing.pool import ThreadPool
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle
from contextlib import suppress
from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from random import shuffle
import seaborn as sns
from time import time
import pandas as pd
import numpy as np
import warnings
import scipy.io
import pickle
import sys
import gc
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/data'
code_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Codes/Shared Codes'
results_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Results'
feature_selection_results = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_results'
sys.path.insert(0,code_path)
from oselm import set_use_know
from SharedFunctions import main,generate_oselm_models

# %%
filenames = ['kddcup99_csv.csv','ISCX2012.csv','CSE-CIC2018.csv','CICIDS2017.csv','7recurrentDrift.csv', 'blip.csv', 'incrementalDrift.csv',
             '7gradualDrift.csv', '7suddenDrift.csv']
filenames = list(map(lambda x: os.path.join(data_path, x), filenames))

# %%
data_name = ['kddcup99','ISCX2012','CSE-CIC2018','CICIDS2017','7recurrentDrift', 'blip', 'incrementalDrift','7gradualDrift', '7suddenDrift']

# %%
# # use_know = False
# # set_use_know(use_know)
# # path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_evolving_DFS')
# # os.makedirs(path, exist_ok=True)
# # for f_name,d_name in zip(filenames,data_name):
# #   DFS_results_path = os.path.join(feature_selection_results_evolving,d_name)
# #   main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
# #        feature_selection=["feature_evolving",'DFS_feature_selection'], result_save_path=path,DFS_results_path=DFS_results_path)

# %%
DATA_NUMBER=0
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["feature_evolving",'DFS_feature_selection'], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : kddcup99_csv.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.9955099422706863, 'precision': 1.0, 'recall': 0.991494532199271, 'f1-score': 0.9957291031116534, 'auc': 0.9957472660996355}
# Evolving DFS
#   0%|          | 0/6265 [00:00<?, ?it/s]
# 2 {'accuracy': 0.99617102744097, 'precision': 0.9974025974025974, 'recall': 0.9948186528497409, 'f1-score': 0.9961089494163424, 'auc': 0.9961514647896503}
# Evolving DFS
#   0%|          | 0/6268 [00:00<?, ?it/s]
# 3 {'accuracy': 0.9936224489795918, 'precision': 0.9975278121137207, 'recall': 0.9901840490797545, 'f1-score': 0.9938423645320197, 'auc': 0.9937640032915374}
# Evolving DFS
#   0%|          | 0/6300 [00:00<?, ?it/s]
# 4 {'accuracy': 0.9974619289340102, 'precision': 0.9975308641975309, 'recall': 0.9975308641975309, 'f1-score': 0.9975308641975309, 'auc': 0.9974599490700448}
# Evolving DFS
#   0%|          | 0/6283 [00:00<?, ?it/s]
# 5 {'accuracy': 0.9980903882877148, 'precision': 0.9961139896373057, 'recall': 1.0, 'f1-score': 0.9980532121998702, 'auc': 0.9981296758104737}
# Evolving DFS
#   0%|          | 0/6332 [00:00<?, ?it/s]
# 6 {'accuracy': 0.9949494949494949, 'precision': 0.9948186528497409, 'recall': 0.9948186528497409, 'f1-score': 0.9948186528497409, 'auc': 0.9949462722376783}
# Evolving DFS
#   0%|          | 0/6284 [00:00<?, ?it/s]
# 7 {'accuracy': 0.9923664122137404, 'precision': 0.9947368421052631, 'recall': 0.9895287958115183, 'f1-score': 0.9921259842519685, 'auc': 0.9922891503810067}
# Evolving DFS
#   0%|          | 0/6316 [00:00<?, ?it/s]
# 8 {'accuracy': 0.9291139240506329, 'precision': 0.9043173862310385, 'recall': 0.9627329192546584, 'f1-score': 0.9326113116726835, 'auc': 0.9284632338208776}
# Evolving DFS
#   0%|          | 0/6313 [00:00<?, ?it/s]
# 9 {'accuracy': 0.9943001899936669, 'precision': 0.9987562189054726, 'recall': 0.9901356350184957, 'f1-score': 0.9944272445820433, 'auc': 0.994416775842581}
# Evolving DFS
#   0%|          | 0/6232 [00:00<?, ?it/s]
# 10 {'accuracy': 0.9961489088575096, 'precision': 0.9987012987012988, 'recall': 0.9935400516795866, 'f1-score': 0.9961139896373058, 'auc': 0.9961322707377525}

# %%
DATA_NUMBER=1
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
      feature_selection=["feature_evolving",'DFS_feature_selection'], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : ISCX2012.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.48166563082660035, 'precision': 0.4708368554522401, 'recall': 0.7281045751633987, 'f1-score': 0.5718685831622176, 'auc': 0.4931992070129789}
# Evolving DFS
#   0%|          | 0/6414 [00:00<?, ?it/s]
# 2 {'accuracy': 0.8609725685785536, 'precision': 0.9871794871794872, 'recall': 0.7412755716004813, 'f1-score': 0.8467353951890034, 'auc': 0.8654631415570323}
# Evolving DFS
#   0%|          | 0/6403 [00:00<?, ?it/s]
# 3 {'accuracy': 0.49406620861961276, 'precision': 0.49273531269741, 'recall': 0.9911054637865311, 'f1-score': 0.6582278481012659, 'auc': 0.5023094886500222}
# Evolving DFS
#   0%|          | 0/6432 [00:00<?, ?it/s]
# 4 {'accuracy': 0.7381840796019901, 'precision': 1.0, 'recall': 0.47766749379652607, 'f1-score': 0.6465155331654072, 'auc': 0.7388337468982631}
# Evolving DFS
#   0%|          | 0/6406 [00:00<?, ?it/s]
# 5 {'accuracy': 0.45692883895131087, 'precision': 0.23780487804878048, 'recall': 0.04974489795918367, 'f1-score': 0.08227848101265822, 'auc': 0.44846658100893166}
# Evolving DFS
#   0%|          | 0/6414 [00:00<?, ?it/s]
# 6 {'accuracy': 0.7687032418952618, 'precision': 0.9931662870159453, 'recall': 0.5422885572139303, 'f1-score': 0.7015285599356396, 'auc': 0.7692692786069651}
# Evolving DFS
#   0%|          | 0/6420 [00:00<?, ?it/s]
# 7 {'accuracy': 0.42714819427148193, 'precision': 0.15025906735751296, 'recall': 0.03694267515923567, 'f1-score': 0.05930470347648262, 'auc': 0.4185931402592768}
# Evolving DFS
#   0%|          | 0/6406 [00:00<?, ?it/s]
# 8 {'accuracy': 0.4556803995006242, 'precision': 0.25161290322580643, 'recall': 0.04905660377358491, 'f1-score': 0.08210526315789475, 'auc': 0.45265717425358304}
# Evolving DFS
#   0%|          | 0/6510 [00:00<?, ?it/s]
# 9 {'accuracy': 0.7174447174447175, 'precision': 0.9918256130790191, 'recall': 0.44336175395858707, 'f1-score': 0.6127946127946128, 'auc': 0.7198221409198139}
# Evolving DFS
#   0%|          | 0/6497 [00:00<?, ?it/s]
# 10 {'accuracy': 0.7470769230769231, 'precision': 0.9905437352245863, 'recall': 0.5072639225181598, 'f1-score': 0.6709367493995196, 'auc': 0.7511288323479409}

# %%
DATA_NUMBER=2
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
      feature_selection=["feature_evolving",'DFS_feature_selection'], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CSE-CIC2018.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 0.5}
# Evolving DFS
#   0%|          | 0/6400 [00:00<?, ?it/s]
# 2 {'accuracy': 0.999375, 'precision': 1.0, 'recall': 0.9993746091307066, 'f1-score': 0.9996872067563339, 'auc': 0.9996873045653534}
# Evolving DFS
#   0%|          | 0/12777 [00:00<?, ?it/s]
# 3 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving DFS
#   0%|          | 0/12776 [00:00<?, ?it/s]
# 4 {'accuracy': 0.9987476518472135, 'precision': 0.9974842767295597, 'recall': 1.0, 'f1-score': 0.9987405541561712, 'auc': 0.9987562189054726}
# Evolving DFS
#   0%|          | 0/12771 [00:00<?, ?it/s]
# 5 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving DFS
#   0%|          | 0/12785 [00:00<?, ?it/s]
# 6 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving DFS
#   0%|          | 0/12787 [00:00<?, ?it/s]
# 7 {'accuracy': 0.8914607444479199, 'precision': 0.8202072538860103, 'recall': 1.0, 'f1-score': 0.9012240250498149, 'auc': 0.8925030978934325}
# Evolving DFS
#   0%|          | 0/12782 [00:00<?, ?it/s]
# 8 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving DFS
#   0%|          | 0/12769 [00:00<?, ?it/s]
# 9 {'accuracy': 0.9996868149076104, 'precision': 1.0, 'recall': 0.9993626513702996, 'f1-score': 0.999681224099458, 'auc': 0.9996813256851498}
# Evolving DFS
#   0%|          | 0/12788 [00:00<?, ?it/s]
# 10 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}

# %%
DATA_NUMBER=3
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
      feature_selection=["feature_evolving",'DFS_feature_selection'], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CICIDS2017.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.9829389102916896, 'precision': 0.971815107102593, 'recall': 0.9930875576036866, 'f1-score': 0.9823361823361823, 'auc': 0.9833720190547411}
# Evolving DFS
#   0%|          | 0/7179 [00:00<?, ?it/s]
# 2 {'accuracy': 0.9688022284122563, 'precision': 0.948936170212766, 'recall': 0.9911111111111112, 'f1-score': 0.9695652173913043, 'auc': 0.968739913097455}
# Evolving DFS
#   0%|          | 0/7209 [00:00<?, ?it/s]
# 3 {'accuracy': 0.8973932334997227, 'precision': 0.8819875776397516, 'recall': 0.9230769230769231, 'f1-score': 0.9020645844362097, 'auc': 0.8967657342657342}
# Evolving DFS
#   0%|          | 0/7230 [00:00<?, ?it/s]
# 4 {'accuracy': 0.8711283185840708, 'precision': 0.8738207547169812, 'recall': 0.8546712802768166, 'f1-score': 0.8641399416909621, 'auc': 0.8704812299364955}
# Evolving DFS
#   0%|          | 0/7392 [00:00<?, ?it/s]
# 5 {'accuracy': 0.9128787878787878, 'precision': 0.8978947368421053, 'recall': 0.9302071973827699, 'f1-score': 0.9137653990358864, 'auc': 0.9130090766720509}
# Evolving DFS
#   0%|          | 0/7169 [00:00<?, ?it/s]
# 6 {'accuracy': 0.9040713887339654, 'precision': 0.8725985844287159, 'recall': 0.9493949394939494, 'f1-score': 0.9093782929399368, 'auc': 0.9034305014211829}
# Evolving DFS
#   0%|          | 0/7110 [00:00<?, ?it/s]
# 7 {'accuracy': 0.9240719910011248, 'precision': 0.8748778103616813, 'recall': 0.9922394678492239, 'f1-score': 0.9298701298701298, 'auc': 0.9230603731940183}
# Evolving DFS
#   0%|          | 0/7128 [00:00<?, ?it/s]
# 8 {'accuracy': 0.7575757575757576, 'precision': 0.7338056680161943, 'recall': 0.8109619686800895, 'f1-score': 0.7704569606801275, 'auc': 0.7573953987544592}
# Evolving DFS
#   0%|          | 0/7099 [00:00<?, ?it/s]
# 9 {'accuracy': 0.8580281690140845, 'precision': 0.8440265486725663, 'recall': 0.8729977116704806, 'f1-score': 0.858267716535433, 'auc': 0.8582524629384588}
# Evolving DFS
#   0%|          | 0/7118 [00:00<?, ?it/s]
# 10 {'accuracy': 0.6067415730337079, 'precision': 0.6426512968299711, 'recall': 0.49665924276169265, 'f1-score': 0.5603015075376884, 'auc': 0.6077400522198486}

# %%
DATA_NUMBER=4
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
      feature_selection=["feature_evolving",'DFS_feature_selection'], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7recurrentDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.6489164086687307, 'precision': 0.6604708798017348, 'recall': 0.6452784503631961, 'f1-score': 0.6527862829148805, 'auc': 0.649001709338759}
# Evolving DFS
#   0%|          | 0/6496 [00:00<?, ?it/s]
# 2 {'accuracy': 0.7586206896551724, 'precision': 0.7558528428093646, 'recall': 0.7967097532314924, 'f1-score': 0.7757437070938216, 'auc': 0.7566989904579196}
# Evolving DFS
#   0%|          | 0/6456 [00:00<?, ?it/s]
# 3 {'accuracy': 0.6059479553903345, 'precision': 0.670863309352518, 'recall': 0.4515738498789346, 'f1-score': 0.5397973950795948, 'auc': 0.6096701736704317}
# Evolving DFS
#   0%|          | 0/6516 [00:00<?, ?it/s]
# 4 {'accuracy': 0.496319018404908, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'auc': 0.4993827160493827}
# Evolving DFS
#   0%|          | 0/6427 [00:00<?, ?it/s]
# 5 {'accuracy': 0.6751711263223398, 'precision': 0.6935897435897436, 'recall': 0.6565533980582524, 'f1-score': 0.6745635910224438, 'auc': 0.6756585636523701}
# Evolving DFS
#   0%|          | 0/6446 [00:00<?, ?it/s]
# 6 {'accuracy': 0.6705955334987593, 'precision': 0.6622073578595318, 'recall': 0.7226277372262774, 'f1-score': 0.6910994764397905, 'auc': 0.6695417167144045}
# Evolving DFS
#   0%|          | 0/6401 [00:00<?, ?it/s]
# 7 {'accuracy': 0.565896314803248, 'precision': 0.5567970204841713, 'recall': 0.7319461444308446, 'f1-score': 0.632469592808038, 'auc': 0.5624016436439938}
# Evolving DFS
#   0%|          | 0/6480 [00:00<?, ?it/s]
# 8 {'accuracy': 0.5796296296296296, 'precision': 0.5950413223140496, 'recall': 0.5274725274725275, 'f1-score': 0.5592233009708737, 'auc': 0.5802156644853274}
# Evolving DFS
#   0%|          | 0/6540 [00:00<?, ?it/s]
# 9 {'accuracy': 0.565403422982885, 'precision': 0.6112, 'recall': 0.44941176470588234, 'f1-score': 0.5179661016949152, 'auc': 0.5701257296811855}
# Evolving DFS
#   0%|          | 0/6465 [00:00<?, ?it/s]
# 10 {'accuracy': 0.6802721088435374, 'precision': 0.6475814412635735, 'recall': 0.803921568627451, 'f1-score': 0.7173318753417167, 'auc': 0.67911434236616}

# %%
DATA_NUMBER=5
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
      feature_selection=["feature_evolving",'DFS_feature_selection'], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : blip.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.4950711938663746, 'precision': 0.5253731343283582, 'recall': 0.18743343982960597, 'f1-score': 0.2762951334379906, 'auc': 0.5040887605010488}
# Evolving DFS
#   0%|          | 0/7195 [00:00<?, ?it/s]
# 2 {'accuracy': 0.5063924402445803, 'precision': 0.4954337899543379, 'recall': 0.24547511312217193, 'f1-score': 0.32829046898638425, 'auc': 0.5019725292386816}
# Evolving DFS
#   0%|          | 0/7267 [00:00<?, ?it/s]
# 3 {'accuracy': 0.5118326912493121, 'precision': 0.499672988881622, 'recall': 0.8623024830699775, 'f1-score': 0.632712215320911, 'auc': 0.5203026915886944}
# Evolving DFS
#   0%|          | 0/7350 [00:00<?, ?it/s]
# 4 {'accuracy': 0.4771490750816104, 'precision': 0.48692403486924035, 'recall': 0.8509249183895539, 'f1-score': 0.6194059405940594, 'auc': 0.4771490750816105}
# Evolving DFS
#   0%|          | 0/7297 [00:00<?, ?it/s]
# 5 {'accuracy': 0.5090410958904109, 'precision': 0.5234042553191489, 'recall': 0.2679738562091503, 'f1-score': 0.3544668587896254, 'auc': 0.5105029148741451}
# Evolving DFS
#   0%|          | 0/7363 [00:00<?, ?it/s]
# 6 {'accuracy': 0.5024443237370994, 'precision': 0.5103030303030303, 'recall': 0.4512325830653805, 'f1-score': 0.4789533560864619, 'auc': 0.5031493311802673}
# Evolving DFS
#   0%|          | 0/7188 [00:00<?, ?it/s]
# 7 {'accuracy': 0.5083426028921023, 'precision': 0.5079063883617964, 'recall': 0.8833883388338833, 'f1-score': 0.6449799196787148, 'auc': 0.5041238657049056}
# Evolving DFS
#   0%|          | 0/7363 [00:00<?, ?it/s]
# 8 {'accuracy': 0.4959261271048343, 'precision': 0.4852941176470588, 'recall': 0.14347826086956522, 'f1-score': 0.22147651006711408, 'auc': 0.4957347873294623}
# Evolving DFS
#   0%|          | 0/7310 [00:00<?, ?it/s]
# 9 {'accuracy': 0.48468271334792123, 'precision': 0.48533519553072624, 'recall': 0.7722222222222223, 'f1-score': 0.5960548885077187, 'auc': 0.48902059386973173}
# Evolving DFS
#   0%|          | 0/7224 [00:00<?, ?it/s]
# 10 {'accuracy': 0.5038759689922481, 'precision': 0.49333333333333335, 'recall': 0.12430011198208286, 'f1-score': 0.19856887298747763, 'auc': 0.4997185116317862}

# %%
DATA_NUMBER=6
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
      feature_selection=["feature_evolving",'DFS_feature_selection'], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : incrementalDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.6896337678460583, 'precision': 0.7257617728531855, 'recall': 0.6343825665859564, 'f1-score': 0.6770025839793281, 'auc': 0.6910766336114496}
# Evolving DFS
#   0%|          | 0/6457 [00:00<?, ?it/s]
# 2 {'accuracy': 0.6681114551083591, 'precision': 0.6899128268991283, 'recall': 0.6587395957193817, 'f1-score': 0.6739659367396593, 'auc': 0.6685170846813963}
# Evolving DFS
#   0%|          | 0/6448 [00:00<?, ?it/s]
# 3 {'accuracy': 0.4801488833746898, 'precision': 0.4801488833746898, 'recall': 1.0, 'f1-score': 0.6487845766974014, 'auc': 0.5}
# Evolving DFS
#   0%|          | 0/6419 [00:00<?, ?it/s]
# 4 {'accuracy': 0.5358255451713395, 'precision': 0.6195121951219512, 'recall': 0.15994962216624686, 'f1-score': 0.2542542542542543, 'auc': 0.5318860317982899}
# Evolving DFS
#   0%|          | 0/6404 [00:00<?, ?it/s]
# 5 {'accuracy': 0.49875156054931336, 'precision': 0.49875156054931336, 'recall': 1.0, 'f1-score': 0.6655560183256977, 'auc': 0.5}
# Evolving DFS
#   0%|          | 0/6409 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 6 {'accuracy': 0.49469744229569557, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'auc': 0.5}
# Evolving DFS
#   0%|          | 0/6465 [00:00<?, ?it/s]
# 7 {'accuracy': 0.5435992578849722, 'precision': 0.5688202247191011, 'recall': 0.48444976076555024, 'f1-score': 0.5232558139534883, 'auc': 0.5456819866567828}
# Evolving DFS
#   0%|          | 0/6470 [00:00<?, ?it/s]
# 8 {'accuracy': 0.5173053152039555, 'precision': 0.5283018867924528, 'recall': 0.47630619684082626, 'f1-score': 0.5009584664536741, 'auc': 0.5180273122568911}
# Evolving DFS
#   0%|          | 0/6406 [00:00<?, ?it/s]
# 9 {'accuracy': 0.50187265917603, 'precision': 0.4976958525345622, 'recall': 0.9557522123893806, 'f1-score': 0.6545454545454545, 'auc': 0.5074692011392032}
# Evolving DFS
#   0%|          | 0/6473 [00:00<?, ?it/s]
# 10 {'accuracy': 0.5287214329833231, 'precision': 0.5043041606886657, 'recall': 0.9070967741935484, 'f1-score': 0.648224988473951, 'auc': 0.5441881975233145}

# %%
DATA_NUMBER=7
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
      feature_selection=["feature_evolving",'DFS_feature_selection'], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7gradualDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.6301571709233792, 'precision': 0.587642713230356, 'recall': 0.8629191321499013, 'f1-score': 0.6991610067918499, 'auc': 0.6310681766424654}
# Evolving DFS
#   0%|          | 0/8080 [00:00<?, ?it/s]
# 2 {'accuracy': 0.502970297029703, 'precision': 0.5048247841543931, 'recall': 0.9716520039100685, 'f1-score': 0.6644385026737969, 'auc': 0.4968591012529279}
# Evolving DFS
#   0%|          | 0/8099 [00:00<?, ?it/s]
# 3 {'accuracy': 0.6854320987654321, 'precision': 0.6414523449319214, 'recall': 0.8387734915924827, 'f1-score': 0.7269609944277754, 'auc': 0.6856589351453538}
# Evolving DFS
#   0%|          | 0/8073 [00:00<?, ?it/s]
# 4 {'accuracy': 0.6498266468548787, 'precision': 0.6271860095389508, 'recall': 0.7682570593963, 'f1-score': 0.6905908096280088, 'auc': 0.6477374006658919}
# Evolving DFS
#   0%|          | 0/8065 [00:00<?, ?it/s]
# 5 {'accuracy': 0.6807139315815568, 'precision': 0.6852886405959032, 'recall': 0.7063339731285988, 'f1-score': 0.6956521739130435, 'auc': 0.6798336532309661}
# Evolving DFS
#   0%|          | 0/8040 [00:00<?, ?it/s]
# 6 {'accuracy': 0.5059701492537313, 'precision': 0.5007012622720898, 'recall': 0.3591549295774648, 'f1-score': 0.4182776801405975, 'auc': 0.5043806143950316}
# Evolving DFS
#   0%|          | 0/8220 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 7 {'accuracy': 0.4990272373540856, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'auc': 0.5}
# Evolving DFS
#   0%|          | 0/8102 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 8 {'accuracy': 0.516781836130306, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'auc': 0.5}
# Evolving DFS
#   0%|          | 0/8142 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 9 {'accuracy': 0.4857563850687623, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'auc': 0.5}
# Evolving DFS
#   0%|          | 0/8128 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 10 {'accuracy': 0.484251968503937, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'auc': 0.5}

# %%
DATA_NUMBER=8
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'faoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
      feature_selection=["feature_evolving",'DFS_feature_selection'], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7suddenDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.7151335311572701, 'precision': 0.7027310924369747, 'recall': 0.6954261954261954, 'f1-score': 0.6990595611285267, 'auc': 0.7142225316753619}
# Evolving DFS
#   0%|          | 0/8049 [00:00<?, ?it/s]
# 2 {'accuracy': 0.639344262295082, 'precision': 0.6278674596431606, 'recall': 0.7195715676728335, 'f1-score': 0.6705989110707805, 'auc': 0.6376762503678569}
# Evolving DFS
#   0%|          | 0/8016 [00:00<?, ?it/s]
# 3 {'accuracy': 0.6516966067864272, 'precision': 0.6227239621267298, 'recall': 0.8260869565217391, 'f1-score': 0.7101328903654485, 'auc': 0.6457576165477633}
# Evolving DFS
#   0%|          | 0/8043 [00:00<?, ?it/s]
# 4 {'accuracy': 0.5753356539035306, 'precision': 0.616398243045388, 'recall': 0.4155972359328727, 'f1-score': 0.49646226415094336, 'auc': 0.5765360929163362}
# Evolving DFS
#   0%|          | 0/8148 [00:00<?, ?it/s]
# 5 {'accuracy': 0.6064769381746811, 'precision': 0.6303191489361702, 'recall': 0.4749498997995992, 'f1-score': 0.5417142857142857, 'auc': 0.6038211037459535}
# Evolving DFS
#   0%|          | 0/8150 [00:00<?, ?it/s]
# 6 {'accuracy': 0.6467124631992149, 'precision': 0.6203252032520326, 'recall': 0.7509842519685039, 'f1-score': 0.6794300979519146, 'auc': 0.6470185447709448}
# Evolving DFS
#   0%|          | 0/8105 [00:00<?, ?it/s]
# 7 {'accuracy': 0.6536753823384311, 'precision': 0.6282679738562091, 'recall': 0.7568897637795275, 'f1-score': 0.6866071428571429, 'auc': 0.6534201538976767}
# Evolving DFS
#   0%|          | 0/8136 [00:00<?, ?it/s]
# 8 {'accuracy': 0.6474926253687315, 'precision': 0.6278877887788779, 'recall': 0.7409931840311588, 'f1-score': 0.6797677534613668, 'auc': 0.6465641193244175}
# Evolving DFS
#   0%|          | 0/8172 [00:00<?, ?it/s]
# 9 {'accuracy': 0.5954011741682974, 'precision': 0.6198125836680054, 'recall': 0.4602385685884692, 'f1-score': 0.5282373074729036, 'auc': 0.5933177428684157}
# Evolving DFS
#   0%|          | 0/8187 [00:00<?, ?it/s]
# 10 {'accuracy': 0.6653639472398633, 'precision': 0.6409574468085106, 'recall': 0.7208374875373879, 'f1-score': 0.678554669169404, 'auc': 0.6664532265273146}
