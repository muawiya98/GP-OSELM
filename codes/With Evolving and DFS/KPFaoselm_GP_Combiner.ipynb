# %%
# !pip install -q scikit-multiflow

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from skmultiflow.drift_detection import ADWIN, DDM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from matplotlib.colors import ListedColormap
from multiprocessing.pool import ThreadPool
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle
from contextlib import suppress
from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from random import shuffle
import seaborn as sns
from time import time
import pandas as pd
import numpy as np
import warnings
import scipy.io
import pickle
import sys
import gc
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/data'
code_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Codes/Shared Codes'
results_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Results'
feature_selection_results = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_results'
sys.path.insert(0,code_path)
from oselm import set_use_know
from SharedFunctions import main,generate_oselm_models

# %%
filenames = ['kddcup99_csv.csv','ISCX2012.csv','CSE-CIC2018.csv','CICIDS2017.csv','7recurrentDrift.csv', 'blip.csv', 'incrementalDrift.csv',
             '7gradualDrift.csv', '7suddenDrift.csv']
filenames = list(map(lambda x: os.path.join(data_path, x), filenames))

# %%
data_name = ['kddcup99','ISCX2012','CSE-CIC2018','CICIDS2017','7recurrentDrift', 'blip', 'incrementalDrift','7gradualDrift', '7suddenDrift']

# %%
# # use_know = True
# # set_use_know(use_know)
# # path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS')
# # os.makedirs(path, exist_ok=True)
# # for f_name,d_name in zip(filenames,data_name):
# #   DFS_results_path = os.path.join(feature_selection_results,d_name)
# #   main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
# #        feature_selection=["feature_evolving",'DFS_feature_selection'], result_save_path=path,DFS_results_path=DFS_results_path)

# %%
DATA_NUMBER=0
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)

# %%
DATA_NUMBER=1
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : ISCX2012.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.6339341205717837, 'precision': 0.5692913385826772, 'recall': 0.9450980392156862, 'f1-score': 0.7105651105651106, 'auc': 0.6484968869064214}
#   0%|          | 0/8018 [00:00<?, ?it/s]
# Evolving DFS
# 2 {'accuracy': 0.8684538653366584, 'precision': 0.9813664596273292, 'recall': 0.7605294825511432, 'f1-score': 0.8569491525423728, 'auc': 0.8725027749107591}
#   0%|          | 0/8004 [00:00<?, ?it/s]
# Evolving DFS
# 3 {'accuracy': 0.49406620861961276, 'precision': 0.49273531269741, 'recall': 0.9911054637865311, 'f1-score': 0.6582278481012659, 'auc': 0.5023094886500222}
#   0%|          | 0/8040 [00:00<?, ?it/s]
# Evolving DFS
# 4 {'accuracy': 0.7325870646766169, 'precision': 1.0, 'recall': 0.4665012406947891, 'f1-score': 0.6362098138747886, 'auc': 0.7332506203473945}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# Evolving DFS
# 5 {'accuracy': 0.45131086142322097, 'precision': 0.07207207207207207, 'recall': 0.01020408163265306, 'f1-score': 0.017877094972067038, 'auc': 0.4421436056085025}
#   0%|          | 0/8018 [00:00<?, ?it/s]
# Evolving DFS
# 6 {'accuracy': 0.773067331670823, 'precision': 0.9932735426008968, 'recall': 0.5509950248756219, 'f1-score': 0.7087999999999999, 'auc': 0.7736225124378109}
#   0%|          | 0/8026 [00:00<?, ?it/s]
# Evolving DFS
# 7 {'accuracy': 0.4259028642590286, 'precision': 0.15577889447236182, 'recall': 0.03949044585987261, 'f1-score': 0.06300813008130081, 'auc': 0.4174309720164162}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# Evolving DFS
# 8 {'accuracy': 0.45692883895131087, 'precision': 0.2549019607843137, 'recall': 0.04905660377358491, 'f1-score': 0.08227848101265824, 'auc': 0.4538963316265694}
#   0%|          | 0/8138 [00:00<?, ?it/s]
# Evolving DFS
# 9 {'accuracy': 0.711916461916462, 'precision': 0.9888888888888889, 'recall': 0.4336175395858709, 'f1-score': 0.6028789161727349, 'auc': 0.7143304550469628}
#   0%|          | 0/8122 [00:00<?, ?it/s]
# Evolving DFS
# 10 {'accuracy': 0.7476923076923077, 'precision': 0.9905660377358491, 'recall': 0.5084745762711864, 'f1-score': 0.672, 'auc': 0.7517341592244543}

# %%
DATA_NUMBER=2
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CSE-CIC2018.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 0.5}
#   0%|          | 0/8000 [00:00<?, ?it/s]
# Evolving DFS
# 2 {'accuracy': 0.999375, 'precision': 0.999375, 'recall': 1.0, 'f1-score': 0.9996874023132228, 'auc': 0.5}
#   0%|          | 0/15972 [00:00<?, ?it/s]
# Evolving DFS
# 3 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15970 [00:00<?, ?it/s]
# Evolving DFS
# 4 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15964 [00:00<?, ?it/s]
# Evolving DFS
# 5 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15982 [00:00<?, ?it/s]
# Evolving DFS
# 6 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15984 [00:00<?, ?it/s]
# Evolving DFS
# 7 {'accuracy': 0.9330622458554895, 'precision': 0.8809126321647189, 'recall': 1.0, 'f1-score': 0.9366863905325443, 'auc': 0.9337050805452293}
#   0%|          | 0/15978 [00:00<?, ?it/s]
# Evolving DFS
# 8 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15962 [00:00<?, ?it/s]
# Evolving DFS
# 9 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15986 [00:00<?, ?it/s]
# Evolving DFS
# 10 {'accuracy': 0.9996873045653534, 'precision': 1.0, 'recall': 0.9993626513702996, 'f1-score': 0.999681224099458, 'auc': 0.9996813256851498}

# %%
DATA_NUMBER=3
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CICIDS2017.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.9818381948266374, 'precision': 0.96962879640045, 'recall': 0.9930875576036866, 'f1-score': 0.981217985202049, 'auc': 0.9823182782749729}
#   0%|          | 0/8974 [00:00<?, ?it/s]
# Evolving DFS
# 2 {'accuracy': 0.9688022284122563, 'precision': 0.948936170212766, 'recall': 0.9911111111111112, 'f1-score': 0.9695652173913043, 'auc': 0.968739913097455}
#   0%|          | 0/9012 [00:00<?, ?it/s]
# Evolving DFS
# 3 {'accuracy': 0.8768718801996672, 'precision': 0.8693361433087461, 'recall': 0.8938244853737811, 'f1-score': 0.8814102564102564, 'auc': 0.8764576972323451}
#   0%|          | 0/9038 [00:00<?, ?it/s]
# Evolving DFS
# 4 {'accuracy': 0.8816371681415929, 'precision': 0.8783314020857474, 'recall': 0.8742791234140715, 'f1-score': 0.8763005780346822, 'auc': 0.8813478507612335}
#   0%|          | 0/9240 [00:00<?, ?it/s]
# Evolving DFS
# 5 {'accuracy': 0.8344155844155844, 'precision': 0.8082744702320888, 'recall': 0.8735005452562704, 'f1-score': 0.839622641509434, 'auc': 0.8347094563016045}
#   0%|          | 0/8962 [00:00<?, ?it/s]
# Evolving DFS
# 6 {'accuracy': 0.9375348577802566, 'precision': 0.8981018981018981, 'recall': 0.988998899889989, 'f1-score': 0.9413612565445026, 'auc': 0.9368071422526868}
#   0%|          | 0/8888 [00:00<?, ?it/s]
# Evolving DFS
# 7 {'accuracy': 0.9167604049493814, 'precision': 0.90625, 'recall': 0.9323725055432373, 'f1-score': 0.9191256830601093, 'auc': 0.9165287185250434}
#   0%|          | 0/8910 [00:00<?, ?it/s]
# Evolving DFS
# 8 {'accuracy': 0.7822671156004489, 'precision': 0.7680084745762712, 'recall': 0.8109619686800895, 'f1-score': 0.7889009793253536, 'auc': 0.782170173529234}
#   0%|          | 0/8874 [00:00<?, ?it/s]
# Evolving DFS
# 9 {'accuracy': 0.8377464788732394, 'precision': 0.813034188034188, 'recall': 0.8707093821510298, 'f1-score': 0.8408839779005525, 'auc': 0.8382403736504316}
#   0%|          | 0/8898 [00:00<?, ?it/s]
# Evolving DFS
# 10 {'accuracy': 0.7382022471910112, 'precision': 0.7596153846153846, 'recall': 0.7037861915367484, 'f1-score': 0.7306358381502891, 'auc': 0.7385144109611179}

# %%
DATA_NUMBER=4
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7recurrentDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.6501547987616099, 'precision': 0.660122699386503, 'recall': 0.6513317191283293, 'f1-score': 0.6556977452772699, 'auc': 0.650127203036915}
#   0%|          | 0/8120 [00:00<?, ?it/s]
# Evolving DFS
# 2 {'accuracy': 0.7580049261083743, 'precision': 0.7555803571428571, 'recall': 0.7955346650998825, 'f1-score': 0.7750429307384087, 'auc': 0.7561114463921146}
#   0%|          | 0/8070 [00:00<?, ?it/s]
# Evolving DFS
# 3 {'accuracy': 0.5427509293680297, 'precision': 0.6732283464566929, 'recall': 0.20702179176755447, 'f1-score': 0.31666666666666665, 'auc': 0.550845921264488}
#   0%|          | 0/8146 [00:00<?, ?it/s]
# Evolving DFS
# 4 {'accuracy': 0.4736196319018405, 'precision': 0.4291044776119403, 'recall': 0.1402439024390244, 'f1-score': 0.21139705882352947, 'auc': 0.4756775067750677}
#   0%|          | 0/8034 [00:00<?, ?it/s]
# Evolving DFS
# 5 {'accuracy': 0.6832607342874922, 'precision': 0.6927784577723378, 'recall': 0.6868932038834952, 'f1-score': 0.6898232784887264, 'auc': 0.6831656313159494}
#   0%|          | 0/8058 [00:00<?, ?it/s]
# Evolving DFS
# 6 {'accuracy': 0.6569478908188585, 'precision': 0.6580493537015276, 'recall': 0.681265206812652, 'f1-score': 0.6694560669456067, 'auc': 0.6564553882164527}
#   0%|          | 0/8002 [00:00<?, ?it/s]
# Evolving DFS
# 7 {'accuracy': 0.5465334166146159, 'precision': 0.5622435020519836, 'recall': 0.5030599755201959, 'f1-score': 0.5310077519379846, 'auc': 0.5474483551070367}
#   0%|          | 0/8100 [00:00<?, ?it/s]
# Evolving DFS
# 8 {'accuracy': 0.5975308641975309, 'precision': 0.5814634146341463, 'recall': 0.7277167277167277, 'f1-score': 0.6464208242950108, 'auc': 0.5960681016860792}
#   0%|          | 0/8176 [00:00<?, ?it/s]
# Evolving DFS
# 9 {'accuracy': 0.511002444987775, 'precision': 0.5827814569536424, 'recall': 0.20705882352941177, 'f1-score': 0.3055555555555556, 'auc': 0.5233767400089807}
#   0%|          | 0/8082 [00:00<?, ?it/s]
# Evolving DFS
# 10 {'accuracy': 0.6827458256029685, 'precision': 0.6513486513486514, 'recall': 0.7990196078431373, 'f1-score': 0.7176664832140892, 'auc': 0.6816571197767498}

# %%
DATA_NUMBER=5
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : blip.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.5021905805038335, 'precision': 0.5681818181818182, 'recall': 0.13312034078807242, 'f1-score': 0.2157031924072476, 'auc': 0.5130088738889629}
#   0%|          | 0/8994 [00:00<?, ?it/s]
# Evolving DFS
# 2 {'accuracy': 0.5058365758754864, 'precision': 0.49440715883668906, 'recall': 0.25, 'f1-score': 0.33208114199849736, 'auc': 0.5015027322404372}
#   0%|          | 0/9084 [00:00<?, ?it/s]
# Evolving DFS
# 3 {'accuracy': 0.5162355531095212, 'precision': 0.5022801302931597, 'recall': 0.8702031602708804, 'f1-score': 0.6369268897149939, 'auc': 0.5247900871171802}
#   0%|          | 0/9188 [00:00<?, ?it/s]
# Evolving DFS
# 4 {'accuracy': 0.48639825897714906, 'precision': 0.4926772114821324, 'recall': 0.9151251360174102, 'f1-score': 0.6405178979436404, 'auc': 0.48639825897714906}
#   0%|          | 0/9122 [00:00<?, ?it/s]
# Evolving DFS
# 5 {'accuracy': 0.4964383561643836, 'precision': 0.4838709677419355, 'recall': 0.016339869281045753, 'f1-score': 0.03161222339304531, 'auc': 0.4993496479812064}
#   0%|          | 0/9204 [00:00<?, ?it/s]
# Evolving DFS
# 6 {'accuracy': 0.5084193373166758, 'precision': 0.5426829268292683, 'recall': 0.1907824222936763, 'f1-score': 0.28231562252180814, 'auc': 0.5127920922041068}
#   0%|          | 0/8986 [00:00<?, ?it/s]
# Evolving DFS
# 7 {'accuracy': 0.4988876529477197, 'precision': 0.5024570024570024, 'recall': 0.8998899889988999, 'f1-score': 0.6448561292865589, 'auc': 0.4943769405061992}
#   0%|          | 0/9204 [00:00<?, ?it/s]
# Evolving DFS
# 8 {'accuracy': 0.49212384573601303, 'precision': 0.4949358541525996, 'recall': 0.7967391304347826, 'f1-score': 0.6105789254477302, 'auc': 0.4922892177689656}
#   0%|          | 0/9138 [00:00<?, ?it/s]
# Evolving DFS
# 9 {'accuracy': 0.49015317286652077, 'precision': 0.4870967741935484, 'recall': 0.6711111111111111, 'f1-score': 0.5644859813084112, 'auc': 0.4928831417624521}
#   0%|          | 0/9030 [00:00<?, ?it/s]
# Evolving DFS
# 10 {'accuracy': 0.5038759689922481, 'precision': 0.49869451697127937, 'recall': 0.6416573348264277, 'f1-score': 0.5612144955925563, 'auc': 0.5053850748611876}

# %%
DATA_NUMBER=6
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : incrementalDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.6883923029174426, 'precision': 0.7237569060773481, 'recall': 0.6343825665859564, 'f1-score': 0.6761290322580645, 'auc': 0.6898027482611311}
#   0%|          | 0/8072 [00:00<?, ?it/s]
# Evolving DFS
# 2 {'accuracy': 0.6681114551083591, 'precision': 0.6899128268991283, 'recall': 0.6587395957193817, 'f1-score': 0.6739659367396593, 'auc': 0.6685170846813963}
#   0%|          | 0/8060 [00:00<?, ?it/s]
# Evolving DFS
# 3 {'accuracy': 0.4981389578163772, 'precision': 0.4820880245649949, 'recall': 0.6085271317829457, 'f1-score': 0.5379782981153627, 'auc': 0.5023542580155779}
#   0%|          | 0/8024 [00:00<?, ?it/s]
# Evolving DFS
# 4 {'accuracy': 0.5433021806853583, 'precision': 0.5388535031847134, 'recall': 0.5327455919395466, 'f1-score': 0.5357821405953135, 'auc': 0.5431915382632382}
#   0%|          | 0/8006 [00:00<?, ?it/s]
# Evolving DFS
# 5 {'accuracy': 0.6647940074906367, 'precision': 0.6286836935166994, 'recall': 0.8010012515644556, 'f1-score': 0.7044578976334617, 'auc': 0.6651332534285541}
#   0%|          | 0/8012 [00:00<?, ?it/s]
# Evolving DFS
# 6 {'accuracy': 0.5377417342482844, 'precision': 0.7254901960784313, 'recall': 0.13703703703703704, 'f1-score': 0.23052959501557635, 'auc': 0.5420368035122134}
#   0%|          | 0/8082 [00:00<?, ?it/s]
# Evolving DFS
# 7 {'accuracy': 0.6314162028447743, 'precision': 0.6232032854209446, 'recall': 0.7260765550239234, 'f1-score': 0.6707182320441989, 'auc': 0.6280830918525507}
#   0%|          | 0/8088 [00:00<?, ?it/s]
# Evolving DFS
# 8 {'accuracy': 0.569221260815822, 'precision': 0.562874251497006, 'recall': 0.6852976913730255, 'f1-score': 0.6180821917808219, 'auc': 0.5671771475733053}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# Evolving DFS
# 9 {'accuracy': 0.684769038701623, 'precision': 0.6710526315789473, 'recall': 0.7092288242730721, 'f1-score': 0.6896127842655194, 'auc': 0.6850706390169305}
#   0%|          | 0/8092 [00:00<?, ?it/s]
# Evolving DFS
# 10 {'accuracy': 0.4644842495367511, 'precision': 0.45855855855855854, 'recall': 0.6567741935483871, 'f1-score': 0.5400530503978779, 'auc': 0.4723444427457575}

# %%
DATA_NUMBER=7
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7gradualDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.6242632612966601, 'precision': 0.5829447035309794, 'recall': 0.8629191321499013, 'f1-score': 0.6958250497017894, 'auc': 0.6251973351551855}
#   0%|          | 0/10100 [00:00<?, ?it/s]
# Evolving DFS
# 2 {'accuracy': 0.501980198019802, 'precision': 0.5043927648578811, 'recall': 0.9540566959921799, 'f1-score': 0.6599053414469235, 'auc': 0.49608551951063357}
#   0%|          | 0/10124 [00:00<?, ?it/s]
# Evolving DFS
# 3 {'accuracy': 0.6869135802469136, 'precision': 0.6426949280847842, 'recall': 0.8397626112759644, 'f1-score': 0.728130360205832, 'auc': 0.6871396882809804}
#   0%|          | 0/10092 [00:00<?, ?it/s]
# Evolving DFS
# 4 {'accuracy': 0.6503219415552254, 'precision': 0.6276849642004774, 'recall': 0.7682570593963, 'f1-score': 0.6908931698774081, 'auc': 0.6482414329239565}
#   0%|          | 0/10082 [00:00<?, ?it/s]
# Evolving DFS
# 5 {'accuracy': 0.6807139315815568, 'precision': 0.6852886405959032, 'recall': 0.7063339731285988, 'f1-score': 0.6956521739130435, 'auc': 0.6798336532309661}
#   0%|          | 0/10050 [00:00<?, ?it/s]
# Evolving DFS
# 6 {'accuracy': 0.5099502487562189, 'precision': 0.5319148936170213, 'recall': 0.07545271629778671, 'f1-score': 0.13215859030837004, 'auc': 0.5052460431882634}
#   0%|          | 0/10276 [00:00<?, ?it/s]
# Evolving DFS
# 7 {'accuracy': 0.6760700389105059, 'precision': 0.6504132231404959, 'recall': 0.7640776699029126, 'f1-score': 0.7026785714285715, 'auc': 0.6758984840742633}
#   0%|          | 0/10128 [00:00<?, ?it/s]
# Evolving DFS
# 8 {'accuracy': 0.5725567620927937, 'precision': 0.5413313825896123, 'recall': 0.7558733401430031, 'f1-score': 0.6308610400682013, 'auc': 0.5785097359740803}
#   0%|          | 0/10178 [00:00<?, ?it/s]
# Evolving DFS
# 9 {'accuracy': 0.6021611001964636, 'precision': 0.5849462365591398, 'recall': 0.7793696275071633, 'f1-score': 0.6683046683046683, 'auc': 0.5969648946433693}
#   0%|          | 0/10160 [00:00<?, ?it/s]
# Evolving DFS
# 10 {'accuracy': 0.6687992125984252, 'precision': 0.6553438276719138, 'recall': 0.7547709923664122, 'f1-score': 0.7015521064301552, 'auc': 0.6660033823620678}

# %%
DATA_NUMBER=8
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7suddenDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.6246290801186943, 'precision': 0.5782575173477256, 'recall': 0.7796257796257796, 'f1-score': 0.6640106241699868, 'auc': 0.6317940218883615}
#   0%|          | 0/10062 [00:00<?, ?it/s]
# Evolving DFS
# 2 {'accuracy': 0.626428216592151, 'precision': 0.5963559915907498, 'recall': 0.8286270691333982, 'f1-score': 0.693561532192339, 'auc': 0.6222242850737985}
#   0%|          | 0/10020 [00:00<?, ?it/s]
# Evolving DFS
# 3 {'accuracy': 0.6377245508982036, 'precision': 0.6061855670103092, 'recall': 0.8521739130434782, 'f1-score': 0.7084337349397589, 'auc': 0.6304213218468164}
#   0%|          | 0/10054 [00:00<?, ?it/s]
# Evolving DFS
# 4 {'accuracy': 0.662357036300348, 'precision': 0.6488413547237076, 'recall': 0.7186574531095755, 'f1-score': 0.6819672131147541, 'auc': 0.6619339369756294}
#   0%|          | 0/10186 [00:00<?, ?it/s]
# Evolving DFS
# 5 {'accuracy': 0.6746810598626104, 'precision': 0.6502242152466368, 'recall': 0.7264529058116233, 'f1-score': 0.6862281116895409, 'auc': 0.6757264529058116}
#   0%|          | 0/10188 [00:00<?, ?it/s]
# Evolving DFS
# 6 {'accuracy': 0.5672227674190383, 'precision': 0.5503003003003003, 'recall': 0.7214566929133859, 'f1-score': 0.6243611584327087, 'auc': 0.5676755088833074}
#   0%|          | 0/10132 [00:00<?, ?it/s]
# Evolving DFS
# 7 {'accuracy': 0.5920078934385792, 'precision': 0.5697416974169742, 'recall': 0.7598425196850394, 'f1-score': 0.6512020244622523, 'auc': 0.5915928721076038}
#   0%|          | 0/10170 [00:00<?, ?it/s]
# Evolving DFS
# 8 {'accuracy': 0.5948869223205506, 'precision': 0.5762584522915102, 'recall': 0.7468354430379747, 'f1-score': 0.6505513146734521, 'auc': 0.593377999572612}
#   0%|          | 0/10216 [00:00<?, ?it/s]
# Evolving DFS
# 9 {'accuracy': 0.6682974559686888, 'precision': 0.6418685121107266, 'recall': 0.7375745526838966, 'f1-score': 0.6864014801110082, 'auc': 0.6693653110240292}
#   0%|          | 0/10234 [00:00<?, ?it/s]
# Evolving DFS
# 10 {'accuracy': 0.6199316072300928, 'precision': 0.5856816450875857, 'recall': 0.7666999002991027, 'f1-score': 0.6640759930915371, 'auc': 0.6228135516821185}
