# %%
# !pip install -q scikit-multiflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.6/450.6 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-multiflow (setup.py) ... done

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from skmultiflow.drift_detection import ADWIN, DDM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from matplotlib.colors import ListedColormap
from multiprocessing.pool import ThreadPool
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle
from contextlib import suppress
from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from random import shuffle
import seaborn as sns
from time import time
import pandas as pd
import numpy as np
import warnings
import scipy.io
import pickle
import sys
import gc
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/MyDrive/Colab_Notebooks/Muawiya/Genetic Programming Combiner with DFS/data'
code_path = '/content/drive/MyDrive/Colab_Notebooks/Muawiya/Genetic Programming Combiner with DFS/Codes/Shared Codes'
results_path = '/content/drive/MyDrive/Colab_Notebooks/Muawiya/Genetic Programming Combiner with DFS/Results'
feature_selection_results = '/content/drive/MyDrive/Colab_Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_results'
feature_selection_issam = '/content/drive/MyDrive/Colab_Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_issam'
sys.path.insert(0,code_path)
from oselm import set_use_know
from SharedFunctions import main, generate_oselm_models

# %%
filenames = ['kddcup99_csv.csv','ISCX2012.csv','CSE-CIC2018.csv','CICIDS2017.csv','Recurrent_Drift.csv', 'Blip_Drift.csv', 'Incremental_Drift.csv',
             'Gradual_Drift.csv', 'Sudden_Drift.csv']
filenames = list(map(lambda x: os.path.join(data_path, x), filenames))

# %%
data_name = ['kddcup99','ISCX2012','CSE-CIC2018','CICIDS2017','Recurrent_Drift', 'Blip_Drift', 'Incremental_Drift','Gradual_Drift', 'Sudden_Drift']

# %%
# # use_know = True
# # set_use_know(use_know)
# # path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS') # IssamDFS
# # os.makedirs(path, exist_ok=True)
# # for f_name,d_name in zip(filenames,data_name):
# #   DFS_results_path = os.path.join(feature_selection_results,d_name) # feature_selection_issam
# #   main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
# #        feature_selection=["feature_evolving",'DFS_feature_selection'], result_save_path=path,DFS_results_path=DFS_results_path)

# %%
# DATA_NUMBER=0
# ChunkNumber=0
# use_know = True
# set_use_know(use_know)
# path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS') # IssamDFS
# os.makedirs(path, exist_ok=True)
# f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
# DFS_results_path = os.path.join(feature_selection_results,d_name) #  feature_selection_issam
# main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
#      result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber,is_synthetic=False)

# %%
# DATA_NUMBER=1
# ChunkNumber=0
# use_know = True
# set_use_know(use_know)
# path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS') # IssamDFS
# os.makedirs(path, exist_ok=True)
# f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
# DFS_results_path = os.path.join(feature_selection_results,d_name) # feature_selection_issam
# main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
#      result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber,is_synthetic=False,chunk_size = 1000)

# %%
# DATA_NUMBER=2
# ChunkNumber=0
# use_know = True
# set_use_know(use_know)
# path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS') # IssamDFS
# os.makedirs(path, exist_ok=True)
# f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
# DFS_results_path = os.path.join(feature_selection_results,d_name) # feature_selection_issam
# main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
#      result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber,is_synthetic=False,chunk_size = 3500)

# %%
# DATA_NUMBER=3
# ChunkNumber=0
# use_know = True
# set_use_know(use_know)
# path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS') # IssamDFS
# os.makedirs(path, exist_ok=True)
# f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
# DFS_results_path = os.path.join(feature_selection_issam,d_name) # feature_selection_issam
# main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
#      result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber,is_synthetic=False,chunk_size = 1000)

# %%
DATA_NUMBER=4
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS') # IssamDFS
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name) # feature_selection_issam
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)

# %%
DATA_NUMBER=5
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS') # IssamDFS
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name) # feature_selection_issam
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)

# %%
DATA_NUMBER=6
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS') # IssamDFS
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name) # feature_selection_issam
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)

# %%
DATA_NUMBER=7
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS') # IssamDFS
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name) # feature_selection_issam
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)

# %%
DATA_NUMBER=8
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_DFS') # IssamDFS
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name) # feature_selection_issam
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True, feature_selection=["feature_evolving",'DFS_feature_selection'],
     result_save_path=path,DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : Sudden_Drift.csv ======================
# 0it [00:00, ?it/s]
# Evolving DFS
# 1 {'accuracy': 0.8461538461538461, 'precision': 0.8245614035087719, 'recall': 0.8867924528301887, 'f1-score': 0.8545454545454546, 'auc': 0.8453570107288199}
# Evolving DFS
# 2 {'accuracy': 0.8431372549019608, 'precision': 0.9444444444444444, 'recall': 0.7083333333333334, 'f1-score': 0.8095238095238096, 'auc': 0.8356481481481483}
# Evolving DFS
# 3 {'accuracy': 0.8495575221238938, 'precision': 1.0, 'recall': 0.7571428571428571, 'f1-score': 0.8617886178861789, 'auc': 0.8785714285714286}
# Evolving DFS
# 4 {'accuracy': 0.8823529411764706, 'precision': 1.0, 'recall': 0.7966101694915254, 'f1-score': 0.8867924528301886, 'auc': 0.8983050847457628}
# Evolving DFS
# 5 {'accuracy': 0.8666666666666667, 'precision': 1.0, 'recall': 0.6956521739130435, 'f1-score': 0.8205128205128205, 'auc': 0.8478260869565217}
# Evolving DFS
# 6 {'accuracy': 0.8921568627450981, 'precision': 1.0, 'recall': 0.7924528301886793, 'f1-score': 0.8842105263157896, 'auc': 0.8962264150943396}
# Evolving DFS
# 7 {'accuracy': 0.8888888888888888, 'precision': 1.0, 'recall': 0.7735849056603774, 'f1-score': 0.8723404255319149, 'auc': 0.8867924528301887}
# Evolving DFS
# 8 {'accuracy': 0.8252427184466019, 'precision': 1.0, 'recall': 0.6949152542372882, 'f1-score': 0.8200000000000001, 'auc': 0.847457627118644}
# Evolving DFS
# 9 {'accuracy': 0.9357798165137615, 'precision': 1.0, 'recall': 0.8703703703703703, 'f1-score': 0.9306930693069307, 'auc': 0.9351851851851851}
# Evolving DFS
# 10 {'accuracy': 0.9210526315789473, 'precision': 1.0, 'recall': 0.8548387096774194, 'f1-score': 0.9217391304347826, 'auc': 0.9274193548387097}
# Evolving DFS
# 11 {'accuracy': 0.8584905660377359, 'precision': 1.0, 'recall': 0.7222222222222222, 'f1-score': 0.8387096774193548, 'auc': 0.8611111111111112}
# Evolving DFS
# 12 {'accuracy': 0.8431372549019608, 'precision': 1.0, 'recall': 0.68, 'f1-score': 0.8095238095238095, 'auc': 0.8400000000000001}
# Evolving DFS
# 13 {'accuracy': 0.8725490196078431, 'precision': 1.0, 'recall': 0.75, 'f1-score': 0.8571428571428571, 'auc': 0.875}
# Evolving DFS
# 14 {'accuracy': 0.8173076923076923, 'precision': 1.0, 'recall': 0.6607142857142857, 'f1-score': 0.7956989247311829, 'auc': 0.8303571428571428}
# Evolving DFS
# 15 {'accuracy': 0.8571428571428571, 'precision': 1.0, 'recall': 0.7, 'f1-score': 0.8235294117647058, 'auc': 0.85}
# Evolving DFS
# 16 {'accuracy': 0.89, 'precision': 1.0, 'recall': 0.7659574468085106, 'f1-score': 0.8674698795180723, 'auc': 0.8829787234042553}
# Evolving DFS
# 17 {'accuracy': 0.9019607843137255, 'precision': 1.0, 'recall': 0.8181818181818182, 'f1-score': 0.9, 'auc': 0.9090909090909092}
# Evolving DFS
# 18 {'accuracy': 0.8878504672897196, 'precision': 1.0, 'recall': 0.7692307692307693, 'f1-score': 0.8695652173913044, 'auc': 0.8846153846153846}
# Evolving DFS
# 19 {'accuracy': 0.897196261682243, 'precision': 1.0, 'recall': 0.7659574468085106, 'f1-score': 0.8674698795180723, 'auc': 0.8829787234042553}
# Evolving DFS
# 20 {'accuracy': 0.8623853211009175, 'precision': 1.0, 'recall': 0.7169811320754716, 'f1-score': 0.8351648351648352, 'auc': 0.8584905660377358}
# Evolving DFS
# 21 {'accuracy': 0.8737864077669902, 'precision': 1.0, 'recall': 0.74, 'f1-score': 0.8505747126436781, 'auc': 0.87}
# Evolving DFS
# 22 {'accuracy': 0.8846153846153846, 'precision': 1.0, 'recall': 0.7735849056603774, 'f1-score': 0.8723404255319149, 'auc': 0.8867924528301887}
# Evolving DFS
# 23 {'accuracy': 0.8807339449541285, 'precision': 1.0, 'recall': 0.723404255319149, 'f1-score': 0.8395061728395062, 'auc': 0.8617021276595744}
# Evolving DFS
# 24 {'accuracy': 0.8446601941747572, 'precision': 1.0, 'recall': 0.6923076923076923, 'f1-score': 0.8181818181818181, 'auc': 0.8461538461538461}
# Evolving DFS
# 25 {'accuracy': 0.8725490196078431, 'precision': 0.9767441860465116, 'recall': 0.7777777777777778, 'f1-score': 0.8659793814432991, 'auc': 0.8784722222222221}
# Evolving DFS
# 26 {'accuracy': 0.8932038834951457, 'precision': 1.0, 'recall': 0.7608695652173914, 'f1-score': 0.8641975308641976, 'auc': 0.8804347826086957}
# Evolving DFS
# 27 {'accuracy': 0.88, 'precision': 1.0, 'recall': 0.7818181818181819, 'f1-score': 0.8775510204081634, 'auc': 0.8909090909090909}
# Evolving DFS
# 28 {'accuracy': 0.8640776699029126, 'precision': 1.0, 'recall': 0.7358490566037735, 'f1-score': 0.8478260869565216, 'auc': 0.8679245283018868}
# Evolving DFS
# 29 {'accuracy': 0.8514851485148515, 'precision': 1.0, 'recall': 0.6875, 'f1-score': 0.8148148148148148, 'auc': 0.84375}
# Evolving DFS
# 30 {'accuracy': 0.8653846153846154, 'precision': 0.9555555555555556, 'recall': 0.7818181818181819, 'f1-score': 0.86, 'auc': 0.8705009276437847}
# Evolving DFS
# 31 {'accuracy': 0.8490566037735849, 'precision': 1.0, 'recall': 0.6981132075471698, 'f1-score': 0.8222222222222222, 'auc': 0.8490566037735849}
# Evolving DFS
# 32 {'accuracy': 0.8811881188118812, 'precision': 0.975609756097561, 'recall': 0.7843137254901961, 'f1-score': 0.8695652173913043, 'auc': 0.882156862745098}
# Evolving DFS
# 33 {'accuracy': 0.8431372549019608, 'precision': 1.0, 'recall': 0.68, 'f1-score': 0.8095238095238095, 'auc': 0.8400000000000001}
# Evolving DFS
# 34 {'accuracy': 0.8571428571428571, 'precision': 1.0, 'recall': 0.7321428571428571, 'f1-score': 0.8453608247422679, 'auc': 0.8660714285714286}
# Evolving DFS
# 35 {'accuracy': 0.8269230769230769, 'precision': 0.95, 'recall': 0.7037037037037037, 'f1-score': 0.8085106382978724, 'auc': 0.8318518518518518}
# Evolving DFS
# 36 {'accuracy': 0.9074074074074074, 'precision': 0.98, 'recall': 0.8448275862068966, 'f1-score': 0.9074074074074074, 'auc': 0.9124137931034483}
# Evolving DFS
# 37 {'accuracy': 0.9215686274509803, 'precision': 1.0, 'recall': 0.84, 'f1-score': 0.9130434782608696, 'auc': 0.9199999999999999}
# Evolving DFS
# 38 {'accuracy': 0.839622641509434, 'precision': 0.9523809523809523, 'recall': 0.7272727272727273, 'f1-score': 0.8247422680412371, 'auc': 0.8440285204991088}
# Evolving DFS
# 39 {'accuracy': 0.8691588785046729, 'precision': 1.0, 'recall': 0.7454545454545455, 'f1-score': 0.8541666666666666, 'auc': 0.8727272727272728}
# Evolving DFS
# 40 {'accuracy': 0.8846153846153846, 'precision': 1.0, 'recall': 0.8032786885245902, 'f1-score': 0.8909090909090909, 'auc': 0.9016393442622951}
# Evolving DFS
# 41 {'accuracy': 0.9345794392523364, 'precision': 1.0, 'recall': 0.8703703703703703, 'f1-score': 0.9306930693069307, 'auc': 0.9351851851851851}
# Evolving DFS
# 42 {'accuracy': 0.8846153846153846, 'precision': 1.0, 'recall': 0.7857142857142857, 'f1-score': 0.88, 'auc': 0.8928571428571428}
# Evolving DFS
# 43 {'accuracy': 0.8796296296296297, 'precision': 0.9782608695652174, 'recall': 0.7894736842105263, 'f1-score': 0.8737864077669902, 'auc': 0.8849329205366356}
# Evolving DFS
# 44 {'accuracy': 0.8461538461538461, 'precision': 1.0, 'recall': 0.7142857142857143, 'f1-score': 0.8333333333333333, 'auc': 0.8571428571428572}
# Evolving DFS
# 45 {'accuracy': 0.8910891089108911, 'precision': 0.9736842105263158, 'recall': 0.7872340425531915, 'f1-score': 0.8705882352941177, 'auc': 0.8843577620173364}
# Evolving DFS
# 46 {'accuracy': 0.7941176470588235, 'precision': 0.9655172413793104, 'recall': 0.5833333333333334, 'f1-score': 0.7272727272727274, 'auc': 0.7824074074074074}
# Evolving DFS
# 47 {'accuracy': 0.9047619047619048, 'precision': 1.0, 'recall': 0.8076923076923077, 'f1-score': 0.8936170212765957, 'auc': 0.9038461538461539}
# Evolving DFS
# 48 {'accuracy': 0.8918918918918919, 'precision': 1.0, 'recall': 0.7551020408163265, 'f1-score': 0.8604651162790697, 'auc': 0.8775510204081632}
# Evolving DFS
# 49 {'accuracy': 0.8811881188118812, 'precision': 1.0, 'recall': 0.7966101694915254, 'f1-score': 0.8867924528301886, 'auc': 0.8983050847457628}
# Evolving DFS
# 50 {'accuracy': 0.8529411764705882, 'precision': 0.9285714285714286, 'recall': 0.7647058823529411, 'f1-score': 0.8387096774193549, 'auc': 0.8529411764705882}
# Evolving DFS
# 51 {'accuracy': 0.8613861386138614, 'precision': 1.0, 'recall': 0.7142857142857143, 'f1-score': 0.8333333333333333, 'auc': 0.8571428571428572}
# Evolving DFS
# 52 {'accuracy': 0.875, 'precision': 0.9743589743589743, 'recall': 0.76, 'f1-score': 0.853932584269663, 'auc': 0.8707407407407408}
# Evolving DFS
# 53 {'accuracy': 0.8571428571428571, 'precision': 1.0, 'recall': 0.7058823529411765, 'f1-score': 0.8275862068965517, 'auc': 0.8529411764705883}
# Evolving DFS
# 54 {'accuracy': 0.8785046728971962, 'precision': 0.9347826086956522, 'recall': 0.8113207547169812, 'f1-score': 0.8686868686868686, 'auc': 0.8778825995807128}
# Evolving DFS
# 55 {'accuracy': 0.8737864077669902, 'precision': 1.0, 'recall': 0.7450980392156863, 'f1-score': 0.8539325842696629, 'auc': 0.8725490196078431}
# Evolving DFS
# 56 {'accuracy': 0.8529411764705882, 'precision': 1.0, 'recall': 0.7169811320754716, 'f1-score': 0.8351648351648352, 'auc': 0.8584905660377358}
# Evolving DFS
# 57 {'accuracy': 0.9029126213592233, 'precision': 0.9767441860465116, 'recall': 0.8235294117647058, 'f1-score': 0.8936170212765957, 'auc': 0.9021493212669682}
# Evolving DFS
# 58 {'accuracy': 0.8543689320388349, 'precision': 1.0, 'recall': 0.7413793103448276, 'f1-score': 0.8514851485148515, 'auc': 0.8706896551724138}
# Evolving DFS
# 59 {'accuracy': 0.8878504672897196, 'precision': 1.0, 'recall': 0.7857142857142857, 'f1-score': 0.88, 'auc': 0.8928571428571428}
# Evolving DFS
# 60 {'accuracy': 0.8888888888888888, 'precision': 1.0, 'recall': 0.7142857142857143, 'f1-score': 0.8333333333333333, 'auc': 0.8571428571428572}
# Evolving DFS
# 61 {'accuracy': 0.9019607843137255, 'precision': 1.0, 'recall': 0.7916666666666666, 'f1-score': 0.8837209302325582, 'auc': 0.8958333333333333}
# Evolving DFS
# 62 {'accuracy': 0.8857142857142857, 'precision': 1.0, 'recall': 0.75, 'f1-score': 0.8571428571428571, 'auc': 0.875}
# Evolving DFS
# 63 {'accuracy': 0.9019607843137255, 'precision': 1.0, 'recall': 0.8113207547169812, 'f1-score': 0.8958333333333334, 'auc': 0.9056603773584906}
# Evolving DFS
# 64 {'accuracy': 0.8921568627450981, 'precision': 1.0, 'recall': 0.8035714285714286, 'f1-score': 0.8910891089108911, 'auc': 0.9017857142857143}
# Evolving DFS
# 65 {'accuracy': 0.8910891089108911, 'precision': 1.0, 'recall': 0.7708333333333334, 'f1-score': 0.8705882352941177, 'auc': 0.8854166666666667}
# Evolving DFS
# 66 {'accuracy': 0.8558558558558559, 'precision': 1.0, 'recall': 0.6981132075471698, 'f1-score': 0.8222222222222222, 'auc': 0.8490566037735849}
# Evolving DFS
# 67 {'accuracy': 0.875, 'precision': 0.9767441860465116, 'recall': 0.7777777777777778, 'f1-score': 0.8659793814432991, 'auc': 0.8788888888888888}
# Evolving DFS
# 68 {'accuracy': 0.8557692307692307, 'precision': 1.0, 'recall': 0.7115384615384616, 'f1-score': 0.8314606741573033, 'auc': 0.8557692307692308}
# Evolving DFS
# 69 {'accuracy': 0.9345794392523364, 'precision': 1.0, 'recall': 0.8444444444444444, 'f1-score': 0.9156626506024096, 'auc': 0.9222222222222223}
# Evolving DFS
# 70 {'accuracy': 0.8737864077669902, 'precision': 1.0, 'recall': 0.7636363636363637, 'f1-score': 0.865979381443299, 'auc': 0.8818181818181818}
# Evolving DFS
# 71 {'accuracy': 0.9117647058823529, 'precision': 1.0, 'recall': 0.8043478260869565, 'f1-score': 0.891566265060241, 'auc': 0.9021739130434783}
# Evolving DFS
# 72 {'accuracy': 0.8613861386138614, 'precision': 1.0, 'recall': 0.7307692307692307, 'f1-score': 0.8444444444444443, 'auc': 0.8653846153846154}
# Evolving DFS
# 73 {'accuracy': 0.897196261682243, 'precision': 1.0, 'recall': 0.78, 'f1-score': 0.8764044943820225, 'auc': 0.89}
# Evolving DFS
# 74 {'accuracy': 0.8411214953271028, 'precision': 1.0, 'recall': 0.6792452830188679, 'f1-score': 0.8089887640449438, 'auc': 0.8396226415094339}
# Evolving DFS
# 75 {'accuracy': 0.8543689320388349, 'precision': 0.9772727272727273, 'recall': 0.7543859649122807, 'f1-score': 0.8514851485148516, 'auc': 0.8663234172387492}
# Evolving DFS
# 76 {'accuracy': 0.87, 'precision': 1.0, 'recall': 0.74, 'f1-score': 0.8505747126436781, 'auc': 0.87}
# Evolving DFS
# 77 {'accuracy': 0.8611111111111112, 'precision': 1.0, 'recall': 0.6666666666666666, 'f1-score': 0.8, 'auc': 0.8333333333333333}
# Evolving DFS
# 78 {'accuracy': 0.8349514563106796, 'precision': 1.0, 'recall': 0.7017543859649122, 'f1-score': 0.8247422680412371, 'auc': 0.8508771929824561}
# Evolving DFS
# 79 {'accuracy': 0.8952380952380953, 'precision': 1.0, 'recall': 0.7708333333333334, 'f1-score': 0.8705882352941177, 'auc': 0.8854166666666667}
# Evolving DFS
# 80 {'accuracy': 0.9326923076923077, 'precision': 1.0, 'recall': 0.8771929824561403, 'f1-score': 0.9345794392523363, 'auc': 0.9385964912280702}
# Evolving DFS
# 81 {'accuracy': 0.8725490196078431, 'precision': 1.0, 'recall': 0.717391304347826, 'f1-score': 0.8354430379746834, 'auc': 0.8586956521739131}
# Evolving DFS
# 82 {'accuracy': 0.8921568627450981, 'precision': 1.0, 'recall': 0.7843137254901961, 'f1-score': 0.8791208791208792, 'auc': 0.892156862745098}
# Evolving DFS
# 83 {'accuracy': 0.8910891089108911, 'precision': 1.0, 'recall': 0.7659574468085106, 'f1-score': 0.8674698795180723, 'auc': 0.8829787234042553}
# Evolving DFS
# 84 {'accuracy': 0.8679245283018868, 'precision': 1.0, 'recall': 0.7142857142857143, 'f1-score': 0.8333333333333333, 'auc': 0.8571428571428572}
# Evolving DFS
# 85 {'accuracy': 0.8653846153846154, 'precision': 1.0, 'recall': 0.7307692307692307, 'f1-score': 0.8444444444444443, 'auc': 0.8653846153846154}
# Evolving DFS
# 86 {'accuracy': 0.912621359223301, 'precision': 1.0, 'recall': 0.8125, 'f1-score': 0.896551724137931, 'auc': 0.90625}
# Evolving DFS
# 87 {'accuracy': 0.8235294117647058, 'precision': 1.0, 'recall': 0.6470588235294118, 'f1-score': 0.7857142857142858, 'auc': 0.8235294117647058}
# Evolving DFS
# 88 {'accuracy': 0.9108910891089109, 'precision': 1.0, 'recall': 0.7857142857142857, 'f1-score': 0.88, 'auc': 0.8928571428571428}
# Evolving DFS
# 89 {'accuracy': 0.9, 'precision': 1.0, 'recall': 0.7959183673469388, 'f1-score': 0.8863636363636364, 'auc': 0.8979591836734694}
# Evolving DFS
# 90 {'accuracy': 0.8285714285714286, 'precision': 1.0, 'recall': 0.6538461538461539, 'f1-score': 0.7906976744186047, 'auc': 0.8269230769230769}
# Evolving DFS
# 91 {'accuracy': 0.8725490196078431, 'precision': 1.0, 'recall': 0.74, 'f1-score': 0.8505747126436781, 'auc': 0.87}
# Evolving DFS
# 92 {'accuracy': 0.8962264150943396, 'precision': 1.0, 'recall': 0.7755102040816326, 'f1-score': 0.8735632183908045, 'auc': 0.8877551020408163}
# Evolving DFS
# 93 {'accuracy': 0.9519230769230769, 'precision': 1.0, 'recall': 0.9, 'f1-score': 0.9473684210526316, 'auc': 0.95}
# Evolving DFS
# 94 {'accuracy': 0.912621359223301, 'precision': 1.0, 'recall': 0.8125, 'f1-score': 0.896551724137931, 'auc': 0.90625}
# Evolving DFS
# 95 {'accuracy': 0.9215686274509803, 'precision': 1.0, 'recall': 0.84, 'f1-score': 0.9130434782608696, 'auc': 0.9199999999999999}
# Evolving DFS
# 96 {'accuracy': 0.9117647058823529, 'precision': 1.0, 'recall': 0.8, 'f1-score': 0.888888888888889, 'auc': 0.9}
# Evolving DFS
# 97 {'accuracy': 0.8761904761904762, 'precision': 1.0, 'recall': 0.7636363636363637, 'f1-score': 0.865979381443299, 'auc': 0.8818181818181818}
# Evolving DFS
# 98 {'accuracy': 0.8543689320388349, 'precision': 1.0, 'recall': 0.7368421052631579, 'f1-score': 0.8484848484848484, 'auc': 0.868421052631579}
# Evolving DFS
# 99 {'accuracy': 0.9, 'precision': 0.975, 'recall': 0.8125, 'f1-score': 0.8863636363636362, 'auc': 0.8966346153846153}
# Evolving DFS
# 100 {'accuracy': 0.8461538461538461, 'precision': 1.0, 'recall': 0.7288135593220338, 'f1-score': 0.8431372549019608, 'auc': 0.8644067796610169}
