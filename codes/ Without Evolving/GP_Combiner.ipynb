# %%
# !pip install -q scikit-multiflow

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from skmultiflow.drift_detection import ADWIN, DDM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from matplotlib.colors import ListedColormap
from multiprocessing.pool import ThreadPool
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle
from contextlib import suppress
from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from random import shuffle
import seaborn as sns
from time import time
import pandas as pd
import numpy as np
import warnings
import scipy.io
import pickle
import sys
import gc
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/data'
code_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Codes/Shared Codes'
results_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Results'
feature_selection_results = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_results'

# %%
sys.path.insert(0,code_path)
from oselm import set_use_know
from SharedFunctions import main,generate_oselm_models

# %%
filenames = ['kddcup99_csv.csv','ISCX2012.csv','CSE-CIC2018.csv','CICIDS2017.csv','7recurrentDrift.csv', 'blip.csv', 'incrementalDrift.csv',
             '7gradualDrift.csv', '7suddenDrift.csv']
filenames = list(map(lambda x: os.path.join(data_path, x), filenames))

# %%
data_name = ['kddcup99','ISCX2012','CSE-CIC2018','CICIDS2017','7recurrentDrift', 'blip', 'incrementalDrift','7gradualDrift', '7suddenDrift']

# %%
# # use_know = False
# # set_use_know(use_know)
# # path = os.path.join(results_path,'gp_combiner_with_model_replacement_DFS')
# # os.makedirs(path, exist_ok=True)
# # for f_name,d_name in zip(filenames,data_name):
# #   DFS_results_path = os.path.join(feature_selection_results,d_name)
# #   main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
# #        feature_selection=["with_out_feature_evolving",'DFS_feature_selection'], result_save_path=path,DFS_results_path=DFS_results_path)

# %%
DATA_NUMBER=0
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
      feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : kddcup99_csv.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.9942270686337396, 'precision': 0.9975550122249389, 'recall': 0.991494532199271, 'f1-score': 0.9945155393053018, 'auc': 0.9943885704474617}
#   0%|          | 0/7832 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.9968091895341417, 'precision': 1.0, 'recall': 0.9935233160621761, 'f1-score': 0.9967511371020142, 'auc': 0.9967616580310881}
#   0%|          | 0/7836 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.9961734693877551, 'precision': 0.998766954377312, 'recall': 0.9938650306748467, 'f1-score': 0.996309963099631, 'auc': 0.9962685047132533}
#   0%|          | 0/7876 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.9980964467005076, 'precision': 1.0, 'recall': 0.9962962962962963, 'f1-score': 0.9981447124304267, 'auc': 0.9981481481481482}
#   0%|          | 0/7854 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.9961807765754297, 'precision': 1.0, 'recall': 0.9921976592977894, 'f1-score': 0.9960835509138382, 'auc': 0.9960988296488946}
#   0%|          | 0/7916 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.9968434343434344, 'precision': 1.0, 'recall': 0.9935233160621761, 'f1-score': 0.9967511371020142, 'auc': 0.9967616580310881}
#   0%|          | 0/7856 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.9942748091603053, 'precision': 1.0, 'recall': 0.9882198952879581, 'f1-score': 0.9940750493745886, 'auc': 0.994109947643979}
#   0%|          | 0/7896 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.9949367088607595, 'precision': 1.0, 'recall': 0.9900621118012423, 'f1-score': 0.9950062421972534, 'auc': 0.9950310559006211}
#   0%|          | 0/7892 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.9955668144395187, 'precision': 1.0, 'recall': 0.9913686806411838, 'f1-score': 0.9956656346749225, 'auc': 0.9956843403205919}
#   0%|          | 0/7790 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.9961489088575096, 'precision': 0.9987012987012988, 'recall': 0.9935400516795866, 'f1-score': 0.9961139896373058, 'auc': 0.9961322707377525}

# %%
DATA_NUMBER=1
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
      feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : ISCX2012.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.8638906152889994, 'precision': 0.9857651245551602, 'recall': 0.7241830065359477, 'f1-score': 0.8349660889223813, 'auc': 0.857352166775083}
#   0%|          | 0/8018 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.85785536159601, 'precision': 0.9967051070840197, 'recall': 0.7280385078219013, 'f1-score': 0.8414464534075105, 'auc': 0.8627255928501485}
#   0%|          | 0/8004 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.8550905683947533, 'precision': 0.9946524064171123, 'recall': 0.7090216010165185, 'f1-score': 0.827893175074184, 'auc': 0.8526680486655074}
#   0%|          | 0/8040 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.8687810945273632, 'precision': 0.9950083194675541, 'recall': 0.7419354838709677, 'f1-score': 0.8500355366027008, 'auc': 0.8690974177459577}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.8826466916354557, 'precision': 1.0, 'recall': 0.7602040816326531, 'f1-score': 0.8637681159420291, 'auc': 0.8801020408163265}
#   0%|          | 0/8018 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.8528678304239401, 'precision': 0.9965034965034965, 'recall': 0.7089552238805971, 'f1-score': 0.8284883720930233, 'auc': 0.8532276119402987}
#   0%|          | 0/8026 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.8698630136986302, 'precision': 0.996551724137931, 'recall': 0.7363057324840764, 'f1-score': 0.8468864468864469, 'auc': 0.8669348394454487}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.867665418227216, 'precision': 0.9932318104906938, 'recall': 0.7383647798742138, 'f1-score': 0.8470418470418469, 'auc': 0.8667040751911341}
#   0%|          | 0/8138 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.8556511056511057, 'precision': 0.9949324324324325, 'recall': 0.7174177831912302, 'f1-score': 0.8336871903750884, 'auc': 0.8568501555361355}
#   0%|          | 0/8122 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.848, 'precision': 0.9931856899488927, 'recall': 0.7058111380145279, 'f1-score': 0.8251946213729653, 'auc': 0.8504024400961251}

# %%
DATA_NUMBER=2
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
      feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CSE-CIC2018.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 0.5}
#   0%|          | 0/8000 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15972 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15970 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15964 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15982 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15984 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15978 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15962 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15986 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}

# %%
DATA_NUMBER=3
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
      feature_selection=["with_out_feature_evolving",''], result_save_path=path,
      DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CICIDS2017.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.9812878370941112, 'precision': 0.9685393258426966, 'recall': 0.9930875576036866, 'f1-score': 0.9806598407281001, 'auc': 0.9817914078850888}
#   0%|          | 0/8974 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.984958217270195, 'precision': 0.9749727965179543, 'recall': 0.9955555555555555, 'f1-score': 0.9851566794942277, 'auc': 0.9849286157666045}
#   0%|          | 0/9012 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.9844703272323905, 'precision': 0.975557917109458, 'recall': 0.9945828819068255, 'f1-score': 0.9849785407725322, 'auc': 0.984223259135231}
#   0%|          | 0/9038 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.9889380530973452, 'precision': 0.9796149490373726, 'recall': 0.9976931949250288, 'f1-score': 0.9885714285714285, 'auc': 0.9892823041575197}
#   0%|          | 0/9240 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.9853896103896104, 'precision': 0.9754273504273504, 'recall': 0.9956379498364231, 'f1-score': 0.9854290339989207, 'auc': 0.9854666655734211}
#   0%|          | 0/8962 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.984941438929169, 'precision': 0.973175965665236, 'recall': 0.9977997799779978, 'f1-score': 0.9853340575774036, 'auc': 0.9847596184957863}
#   0%|          | 0/8888 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.9870641169853769, 'precision': 0.9792802617230099, 'recall': 0.9955654101995566, 'f1-score': 0.9873556899395273, 'auc': 0.9869379562413308}
#   0%|          | 0/8910 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.9854096520763187, 'precision': 0.9748358862144421, 'recall': 0.9966442953020134, 'f1-score': 0.9856194690265487, 'auc': 0.9853716972005563}
#   0%|          | 0/8874 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.9898591549295774, 'precision': 0.9852607709750567, 'recall': 0.994279176201373, 'f1-score': 0.989749430523918, 'auc': 0.9899253816633946}
#   0%|          | 0/8898 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.9910112359550561, 'precision': 0.98568281938326, 'recall': 0.9966592427616926, 'f1-score': 0.991140642303433, 'auc': 0.9909600068683747}

# %%
DATA_NUMBER=4
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
      feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7recurrentDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.6142414860681115, 'precision': 0.6215568862275449, 'recall': 0.6283292978208233, 'f1-score': 0.6249247441300421, 'auc': 0.6139111634858235}
#   0%|          | 0/8120 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.6483990147783252, 'precision': 0.6690821256038647, 'recall': 0.6509988249118684, 'f1-score': 0.6599166170339488, 'auc': 0.6482678471260506}
#   0%|          | 0/8070 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.6195786864931846, 'precision': 0.6295843520782396, 'recall': 0.6234866828087167, 'f1-score': 0.6265206812652068, 'auc': 0.6194844581556274}
#   0%|          | 0/8146 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.6030674846625766, 'precision': 0.6028537455410226, 'recall': 0.6182926829268293, 'f1-score': 0.6104756170981336, 'auc': 0.6029735019572418}
#   0%|          | 0/8034 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.6179215930304915, 'precision': 0.6335877862595419, 'recall': 0.6043689320388349, 'f1-score': 0.6186335403726707, 'auc': 0.618276420042406}
#   0%|          | 0/8058 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.6259305210918115, 'precision': 0.639135959339263, 'recall': 0.6119221411192214, 'f1-score': 0.6252330640149161, 'auc': 0.6262142351165728}
#   0%|          | 0/8002 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.6171143035602749, 'precision': 0.6304347826086957, 'recall': 0.6034271725826194, 'f1-score': 0.616635397123202, 'auc': 0.6174023618015136}
#   0%|          | 0/8100 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.6148148148148148, 'precision': 0.6226415094339622, 'recall': 0.6043956043956044, 'f1-score': 0.6133828996282528, 'auc': 0.614931884594806}
#   0%|          | 0/8176 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.6265281173594132, 'precision': 0.6455542021924482, 'recall': 0.6235294117647059, 'f1-score': 0.6343506882106522, 'auc': 0.6266502020655591}
#   0%|          | 0/8082 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.6171923314780458, 'precision': 0.6165680473372781, 'recall': 0.6384803921568627, 'f1-score': 0.6273329319686936, 'auc': 0.6169930050671955}

# %%
DATA_NUMBER=5
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
      feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : blip.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.5109529025191676, 'precision': 0.5991379310344828, 'recall': 0.14802981895633652, 'f1-score': 0.23740392826643894, 'auc': 0.5215910086889912}
#   0%|          | 0/8994 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.5086158977209561, 'precision': 0.5, 'recall': 0.7816742081447964, 'f1-score': 0.6098852603706973, 'auc': 0.5132414756570977}
#   0%|          | 0/9084 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.4991744634012108, 'precision': 0.47560975609756095, 'recall': 0.26410835214446954, 'f1-score': 0.33962264150943394, 'auc': 0.49349348863936693}
#   0%|          | 0/9188 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.5027203482045702, 'precision': 0.5040387722132472, 'recall': 0.3394994559303591, 'f1-score': 0.4057217165149545, 'auc': 0.5027203482045701}
#   0%|          | 0/9122 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.5002739726027398, 'precision': 0.5081521739130435, 'recall': 0.2037037037037037, 'f1-score': 0.2908242612752721, 'auc': 0.5020723590183348}
#   0%|          | 0/9204 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.503530689842477, 'precision': 0.527536231884058, 'recall': 0.19506966773847803, 'f1-score': 0.28482003129890454, 'auc': 0.5077771246181377}
#   0%|          | 0/8986 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.5166852057842046, 'precision': 0.5398406374501992, 'recall': 0.29812981298129815, 'f1-score': 0.3841247342310419, 'auc': 0.5191436466481294}
#   0%|          | 0/9204 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.4823465507876154, 'precision': 0.44554455445544555, 'recall': 0.14673913043478262, 'f1-score': 0.22076860179885527, 'auc': 0.48216435349100695}
#   0%|          | 0/9138 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.5103938730853391, 'precision': 0.5055187637969095, 'recall': 0.2544444444444444, 'f1-score': 0.3385070214338507, 'auc': 0.5065325670498084}
#   0%|          | 0/9030 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.5060908084163898, 'precision': 0.5003494060097834, 'recall': 0.8017917133258678, 'f1-score': 0.6161790017211703, 'auc': 0.509329591602693}

# %%
DATA_NUMBER=6
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
      feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : incrementalDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.6188702669149596, 'precision': 0.6338383838383839, 'recall': 0.6077481840193705, 'f1-score': 0.6205191594561187, 'auc': 0.619160716213507}
#   0%|          | 0/8072 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.6167182662538699, 'precision': 0.6441558441558441, 'recall': 0.5897740784780023, 'f1-score': 0.6157666045934203, 'auc': 0.617884455259673}
#   0%|          | 0/8060 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.6321339950372209, 'precision': 0.6173800259403373, 'recall': 0.6149870801033591, 'f1-score': 0.6161812297734627, 'auc': 0.6314792202426104}
#   0%|          | 0/8024 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.6261682242990654, 'precision': 0.6209476309226932, 'recall': 0.6272040302267002, 'f1-score': 0.6240601503759399, 'auc': 0.6261790804647681}
#   0%|          | 0/8006 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.6229712858926342, 'precision': 0.6184690157958688, 'recall': 0.6370463078848561, 'f1-score': 0.6276202219482121, 'auc': 0.6230063419872599}
#   0%|          | 0/8012 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.6568933250155957, 'precision': 0.6633165829145728, 'recall': 0.6518518518518519, 'f1-score': 0.6575342465753425, 'auc': 0.6569473635047406}
#   0%|          | 0/8082 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.62708719851577, 'precision': 0.6469104665825978, 'recall': 0.6136363636363636, 'f1-score': 0.6298342541436465, 'auc': 0.627560819462228}
#   0%|          | 0/8088 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.6223733003708282, 'precision': 0.6335012594458438, 'recall': 0.6111786148238153, 'f1-score': 0.6221397649969079, 'auc': 0.6225704394873794}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.6641697877652933, 'precision': 0.6599241466498104, 'recall': 0.6599241466498104, 'f1-score': 0.6599241466498104, 'auc': 0.6641174370733638}
#   0%|          | 0/8092 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.6417541692402717, 'precision': 0.6217228464419475, 'recall': 0.6425806451612903, 'f1-score': 0.631979695431472, 'auc': 0.6417879529123988}

# %%
DATA_NUMBER=7
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
      feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7gradualDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.7082514734774067, 'precision': 0.6855123674911661, 'recall': 0.7652859960552268, 'f1-score': 0.723205964585275, 'auc': 0.7084747005716447}
#   0%|          | 0/10100 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.7054455445544554, 'precision': 0.6890459363957597, 'recall': 0.7624633431085044, 'f1-score': 0.7238979118329467, 'auc': 0.7047020827879533}
#   0%|          | 0/10124 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.7180246913580247, 'precision': 0.691304347826087, 'recall': 0.7863501483679525, 'f1-score': 0.7357704766311893, 'auc': 0.718125764519282}
#   0%|          | 0/10092 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.6988608221892025, 'precision': 0.6878923766816144, 'recall': 0.7468354430379747, 'f1-score': 0.7161531279178338, 'auc': 0.6980144957125357}
#   0%|          | 0/10082 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.7124442240951909, 'precision': 0.7012195121951219, 'recall': 0.772552783109405, 'f1-score': 0.7351598173515981, 'auc': 0.7103789556572666}
#   0%|          | 0/10050 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.7134328358208956, 'precision': 0.6879496402877698, 'recall': 0.7696177062374245, 'f1-score': 0.7264957264957266, 'auc': 0.7140411365832791}
#   0%|          | 0/10276 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.708171206225681, 'precision': 0.6882661996497373, 'recall': 0.7631067961165049, 'f1-score': 0.7237569060773481, 'auc': 0.7080641193058158}
#   0%|          | 0/10128 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.6954590325765054, 'precision': 0.6557659208261618, 'recall': 0.7783452502553626, 'f1-score': 0.7118169079869221, 'auc': 0.6981506576014157}
#   0%|          | 0/10178 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.7185658153241651, 'precision': 0.7093639575971732, 'recall': 0.766953199617956, 'f1-score': 0.737035337310693, 'auc': 0.717146973924246}
#   0%|          | 0/10160 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.7091535433070866, 'precision': 0.695132365499573, 'recall': 0.7767175572519084, 'f1-score': 0.7336638125281658, 'auc': 0.7069563396015639}

# %%
DATA_NUMBER=8
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
      feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7suddenDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.7101879327398615, 'precision': 0.6643356643356644, 'recall': 0.7900207900207901, 'f1-score': 0.7217473884140551, 'auc': 0.713878319538697}
#   0%|          | 0/10062 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.7133631395926477, 'precision': 0.7012522361359571, 'recall': 0.7633885102239533, 'f1-score': 0.7310023310023309, 'auc': 0.7123230583574127}
#   0%|          | 0/10020 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.7085828343313373, 'precision': 0.6976336546888694, 'recall': 0.7690821256038647, 'f1-score': 0.7316176470588234, 'auc': 0.7065224869505391}
#   0%|          | 0/10054 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.69617105917454, 'precision': 0.6741767764298093, 'recall': 0.7680157946692991, 'f1-score': 0.7180433779418552, 'auc': 0.6956311438276356}
#   0%|          | 0/10186 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.6967615309126595, 'precision': 0.6599326599326599, 'recall': 0.7855711422845691, 'f1-score': 0.7172918572735589, 'auc': 0.6985548019115154}
#   0%|          | 0/10188 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.703631010794897, 'precision': 0.6794425087108014, 'recall': 0.7677165354330708, 'f1-score': 0.7208872458410351, 'auc': 0.7038191287732869}
#   0%|          | 0/10132 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.7232363098174642, 'precision': 0.7051397655545536, 'recall': 0.7696850393700787, 'f1-score': 0.736, 'auc': 0.7231214514357812}
#   0%|          | 0/10170 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.7123893805309734, 'precision': 0.6959219858156028, 'recall': 0.7643622200584226, 'f1-score': 0.728538283062645, 'auc': 0.7118732649448023}
#   0%|          | 0/10216 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.7113502935420744, 'precision': 0.6830985915492958, 'recall': 0.7713717693836978, 'f1-score': 0.7245564892623716, 'auc': 0.7122754800675714}
#   0%|          | 0/10234 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.7024914509037616, 'precision': 0.6669491525423729, 'recall': 0.7846460618145563, 'f1-score': 0.7210261108566193, 'auc': 0.7041046401026805}
