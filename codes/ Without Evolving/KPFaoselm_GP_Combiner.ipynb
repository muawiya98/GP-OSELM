# %%
# !pip install -q scikit-multiflow

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from skmultiflow.drift_detection import ADWIN, DDM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from matplotlib.colors import ListedColormap
from multiprocessing.pool import ThreadPool
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle
from contextlib import suppress
from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from random import shuffle
import seaborn as sns
from time import time
import pandas as pd
import numpy as np
import warnings
import scipy.io
import pickle
import sys
import gc
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/data'
code_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Codes/Shared Codes'
results_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Results'
feature_selection_results = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_results'
sys.path.insert(0,code_path)
from oselm import set_use_know
from SharedFunctions import main,generate_oselm_models

# %%
filenames = ['kddcup99_csv.csv','ISCX2012.csv','CSE-CIC2018.csv','CICIDS2017.csv','7recurrentDrift.csv', 'blip.csv', 'incrementalDrift.csv',
             '7gradualDrift.csv', '7suddenDrift.csv']
filenames = list(map(lambda x: os.path.join(data_path, x), filenames))

# %%
data_name = ['kddcup99','ISCX2012','CSE-CIC2018','CICIDS2017','7recurrentDrift', 'blip', 'incrementalDrift','7gradualDrift', '7suddenDrift']

# %%
# # use_know = True
# # set_use_know(use_know)
# # path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement')
# # os.makedirs(path, exist_ok=True)
# # for f_name,d_name in zip(filenames,data_name):
# #   DFS_results_path = os.path.join(feature_selection_results,d_name)
# #   main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
# #       feature_selection=["with_out_feature_evolving",''], result_save_path=path,DFS_results_path=DFS_results_path)

# %%
DATA_NUMBER=0
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : kddcup99_csv.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.994868505452213, 'precision': 0.9987760097919217, 'recall': 0.991494532199271, 'f1-score': 0.9951219512195122, 'auc': 0.9950679182735485}
#   0%|          | 0/7832 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.9968091895341417, 'precision': 1.0, 'recall': 0.9935233160621761, 'f1-score': 0.9967511371020142, 'auc': 0.9967616580310881}
#   0%|          | 0/7836 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.9961734693877551, 'precision': 0.998766954377312, 'recall': 0.9938650306748467, 'f1-score': 0.996309963099631, 'auc': 0.9962685047132533}
#   0%|          | 0/7876 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.9961928934010152, 'precision': 0.9975247524752475, 'recall': 0.9950617283950617, 'f1-score': 0.9962917181705809, 'auc': 0.9962253811688103}
#   0%|          | 0/7854 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.9949077021005729, 'precision': 0.9973856209150327, 'recall': 0.9921976592977894, 'f1-score': 0.9947848761408085, 'auc': 0.9948519468558772}
#   0%|          | 0/7916 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.9968434343434344, 'precision': 1.0, 'recall': 0.9935233160621761, 'f1-score': 0.9967511371020142, 'auc': 0.9967616580310881}
#   0%|          | 0/7856 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.9936386768447837, 'precision': 1.0, 'recall': 0.9869109947643979, 'f1-score': 0.9934123847167325, 'auc': 0.993455497382199}
#   0%|          | 0/7896 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.9962025316455696, 'precision': 1.0, 'recall': 0.9925465838509316, 'f1-score': 0.9962593516209477, 'auc': 0.9962732919254658}
#   0%|          | 0/7892 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.9949335022165928, 'precision': 0.9987577639751553, 'recall': 0.9913686806411838, 'f1-score': 0.9950495049504952, 'auc': 0.9950332986539253}
#   0%|          | 0/7790 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.9955070603337612, 'precision': 0.9974059662775616, 'recall': 0.9935400516795866, 'f1-score': 0.9954692556634304, 'auc': 0.9954945156357118}

# %%
DATA_NUMBER=1
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : ISCX2012.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.8645121193287756, 'precision': 0.9857904085257548, 'recall': 0.7254901960784313, 'f1-score': 0.8358433734939759, 'auc': 0.8580057615463248}
#   0%|          | 0/8018 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.8559850374064838, 'precision': 0.9966887417218543, 'recall': 0.7244283995186522, 'f1-score': 0.8390243902439025, 'auc': 0.8609205386985239}
#   0%|          | 0/8004 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.8557151780137414, 'precision': 0.9982078853046595, 'recall': 0.7077509529860229, 'f1-score': 0.8282527881040891, 'auc': 0.8532612258787609}
#   0%|          | 0/8040 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.8694029850746269, 'precision': 0.9950166112956811, 'recall': 0.7431761786600496, 'f1-score': 0.8508522727272727, 'auc': 0.8697177651404985}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.8838951310861424, 'precision': 1.0, 'recall': 0.7627551020408163, 'f1-score': 0.8654124457308249, 'auc': 0.8813775510204082}
#   0%|          | 0/8018 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.850997506234414, 'precision': 0.9964850615114236, 'recall': 0.7052238805970149, 'f1-score': 0.8259286234522943, 'auc': 0.8513619402985075}
#   0%|          | 0/8026 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.8679950186799502, 'precision': 0.9982608695652174, 'recall': 0.7312101910828025, 'f1-score': 0.8441176470588235, 'auc': 0.8649960821431064}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.865792759051186, 'precision': 0.9931972789115646, 'recall': 0.7345911949685534, 'f1-score': 0.8445408532176427, 'auc': 0.8648172827383038}
#   0%|          | 0/8138 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.8556511056511057, 'precision': 0.9949324324324325, 'recall': 0.7174177831912302, 'f1-score': 0.8336871903750884, 'auc': 0.8568501555361355}
#   0%|          | 0/8122 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.8510769230769231, 'precision': 0.9932432432432432, 'recall': 0.711864406779661, 'f1-score': 0.8293370944992947, 'auc': 0.8534290744786915}

# %%
DATA_NUMBER=2
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CSE-CIC2018.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 0.5}
#   0%|          | 0/8000 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15972 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15970 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15964 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15982 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15984 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15978 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15962 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
#   0%|          | 0/15986 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}

# %%
DATA_NUMBER=3
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CICIDS2017.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.9812878370941112, 'precision': 0.9685393258426966, 'recall': 0.9930875576036866, 'f1-score': 0.9806598407281001, 'auc': 0.9817914078850888}
#   0%|          | 0/8974 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.9844011142061281, 'precision': 0.972885032537961, 'recall': 0.9966666666666667, 'f1-score': 0.9846322722283206, 'auc': 0.9843668528864059}
#   0%|          | 0/9012 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.9805879090404881, 'precision': 0.9693446088794926, 'recall': 0.9934994582881906, 'f1-score': 0.9812734082397003, 'auc': 0.9802724564168226}
#   0%|          | 0/9038 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.9878318584070797, 'precision': 0.9774011299435028, 'recall': 0.9976931949250288, 'f1-score': 0.9874429223744293, 'auc': 0.9882196049014093}
#   0%|          | 0/9240 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.9837662337662337, 'precision': 0.9743315508021391, 'recall': 0.9934569247546347, 'f1-score': 0.9838012958963284, 'auc': 0.9838390961044925}
#   0%|          | 0/8962 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.9860568878973787, 'precision': 0.975268817204301, 'recall': 0.9977997799779978, 'f1-score': 0.9864056552474171, 'auc': 0.9858908402152432}
#   0%|          | 0/8888 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.9797525309336333, 'precision': 0.9645922746781116, 'recall': 0.9966740576496674, 'f1-score': 0.9803707742639041, 'auc': 0.9795014123864775}
#   0%|          | 0/8910 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.9848484848484849, 'precision': 0.9737704918032787, 'recall': 0.9966442953020134, 'f1-score': 0.9850746268656717, 'auc': 0.9848086341374933}
#   0%|          | 0/8874 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.9859154929577465, 'precision': 0.975363941769317, 'recall': 0.9965675057208238, 'f1-score': 0.9858517260894171, 'auc': 0.9860750958126872}
#   0%|          | 0/8898 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.9898876404494382, 'precision': 0.9835164835164835, 'recall': 0.9966592427616926, 'f1-score': 0.9900442477876106, 'auc': 0.9898262200203022}

# %%
DATA_NUMBER=4
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7recurrentDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.6154798761609908, 'precision': 0.6221692491060786, 'recall': 0.6319612590799032, 'f1-score': 0.6270270270270271, 'auc': 0.6150934305538933}
#   0%|          | 0/8120 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.6391625615763546, 'precision': 0.6556991774383079, 'recall': 0.6556991774383079, 'f1-score': 0.6556991774383079, 'auc': 0.6383282433116507}
#   0%|          | 0/8070 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.6201982651796778, 'precision': 0.6284680337756333, 'recall': 0.6307506053268765, 'f1-score': 0.6296072507552871, 'auc': 0.61994383058222}
#   0%|          | 0/8146 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.6024539877300613, 'precision': 0.6014150943396226, 'recall': 0.6219512195121951, 'f1-score': 0.6115107913669064, 'auc': 0.6023336344474556}
#   0%|          | 0/8034 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.6204107031736155, 'precision': 0.6347607052896725, 'recall': 0.6116504854368932, 'f1-score': 0.6229913473423979, 'auc': 0.6206400575332615}
#   0%|          | 0/8058 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.6271712158808933, 'precision': 0.6389937106918239, 'recall': 0.6180048661800487, 'f1-score': 0.6283240568954855, 'auc': 0.6273568634697712}
#   0%|          | 0/8002 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.6246096189881324, 'precision': 0.6343283582089553, 'recall': 0.6242350061199511, 'f1-score': 0.6292412091301667, 'auc': 0.6246175030599755}
#   0%|          | 0/8100 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.6129629629629629, 'precision': 0.62, 'recall': 0.6056166056166056, 'f1-score': 0.6127239036442248, 'auc': 0.6130455063039333}
#   0%|          | 0/8176 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.632640586797066, 'precision': 0.6469893742621016, 'recall': 0.6447058823529411, 'f1-score': 0.6458456098998231, 'auc': 0.6321493788355036}
#   0%|          | 0/8082 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.6134817563388992, 'precision': 0.6127508854781583, 'recall': 0.6360294117647058, 'f1-score': 0.624173180998196, 'auc': 0.6132706359697437}

# %%
DATA_NUMBER=5
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : blip.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.5104052573932092, 'precision': 0.5974025974025974, 'recall': 0.14696485623003194, 'f1-score': 0.2358974358974359, 'auc': 0.5210585273258389}
#   0%|          | 0/8994 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.5036131183991106, 'precision': 0.49679258731290094, 'recall': 0.7884615384615384, 'f1-score': 0.6095321381722781, 'auc': 0.5084384195039933}
#   0%|          | 0/9084 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.5046780407264722, 'precision': 0.4950704225352113, 'recall': 0.7934537246049661, 'f1-score': 0.6097137901127493, 'auc': 0.5116570449018386}
#   0%|          | 0/9188 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.5168661588683352, 'precision': 0.538083538083538, 'recall': 0.2383025027203482, 'f1-score': 0.33031674208144796, 'auc': 0.5168661588683352}
#   0%|          | 0/9122 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.4997260273972603, 'precision': 0.5047438330170778, 'recall': 0.289760348583878, 'f1-score': 0.36816608996539796, 'auc': 0.5009992481618398}
#   0%|          | 0/9204 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.4850624660510592, 'precision': 0.47863247863247865, 'recall': 0.18006430868167203, 'f1-score': 0.26168224299065423, 'auc': 0.4892612292307038}
#   0%|          | 0/8986 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.5139043381535039, 'precision': 0.543424317617866, 'recall': 0.24092409240924093, 'f1-score': 0.33384146341463417, 'auc': 0.516974982087635}
#   0%|          | 0/9204 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.5225420966865834, 'precision': 0.5448577680525164, 'recall': 0.27065217391304347, 'f1-score': 0.36165577342047933, 'auc': 0.5224053486286173}
#   0%|          | 0/9138 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.5147702407002188, 'precision': 0.5144766146993318, 'recall': 0.25666666666666665, 'f1-score': 0.34247590808005934, 'auc': 0.5108764367816092}
#   0%|          | 0/9030 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.49224806201550386, 'precision': 0.47129186602870815, 'recall': 0.2206047032474804, 'f1-score': 0.30053394355453855, 'auc': 0.4892727787869385}

# %%
DATA_NUMBER=6
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : incrementalDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.6188702669149596, 'precision': 0.6338383838383839, 'recall': 0.6077481840193705, 'f1-score': 0.6205191594561187, 'auc': 0.619160716213507}
#   0%|          | 0/8072 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.6235294117647059, 'precision': 0.648786717752235, 'recall': 0.6040428061831153, 'f1-score': 0.625615763546798, 'auc': 0.6243728242801881}
#   0%|          | 0/8060 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.6296526054590571, 'precision': 0.616600790513834, 'recall': 0.6046511627906976, 'f1-score': 0.6105675146771037, 'auc': 0.6286978964311484}
#   0%|          | 0/8024 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.6199376947040498, 'precision': 0.6130221130221131, 'recall': 0.628463476070529, 'f1-score': 0.6206467661691543, 'auc': 0.6200270524618983}
#   0%|          | 0/8006 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.6217228464419475, 'precision': 0.6195786864931846, 'recall': 0.6257822277847309, 'f1-score': 0.6226650062266501, 'auc': 0.6217329569807839}
#   0%|          | 0/8012 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.6593886462882096, 'precision': 0.6645885286783042, 'recall': 0.6580246913580247, 'f1-score': 0.6612903225806451, 'auc': 0.6594032662338674}
#   0%|          | 0/8082 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.6357452071737786, 'precision': 0.6511627906976745, 'recall': 0.6363636363636364, 'f1-score': 0.6436781609195402, 'auc': 0.6357234314980793}
#   0%|          | 0/8088 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.6260815822002472, 'precision': 0.63625, 'recall': 0.6184690157958688, 'f1-score': 0.6272335181762169, 'auc': 0.6262156399734062}
#   0%|          | 0/8008 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.6610486891385767, 'precision': 0.6597938144329897, 'recall': 0.6472819216182049, 'f1-score': 0.6534779834077856, 'auc': 0.6608789386142812}
#   0%|          | 0/8092 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.6368128474366893, 'precision': 0.6170212765957447, 'recall': 0.6361290322580645, 'f1-score': 0.6264294790343075, 'auc': 0.6367848952759517}

# %%
DATA_NUMBER=7
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7gradualDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.6915520628683693, 'precision': 0.665807560137457, 'recall': 0.7642998027613412, 'f1-score': 0.711662075298439, 'auc': 0.6918367898346822}
#   0%|          | 0/10100 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.7074257425742574, 'precision': 0.6908127208480566, 'recall': 0.7644183773216031, 'f1-score': 0.7257540603248259, 'auc': 0.706682608921584}
#   0%|          | 0/10124 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.7145679012345679, 'precision': 0.6845694799658995, 'recall': 0.7942631058358062, 'f1-score': 0.7353479853479855, 'auc': 0.7146857935490668}
#   0%|          | 0/10092 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.6874690440812283, 'precision': 0.671280276816609, 'recall': 0.7555988315481986, 'f1-score': 0.7109482363719651, 'auc': 0.6862671577095831}
#   0%|          | 0/10082 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.7183936539414972, 'precision': 0.7086267605633803, 'recall': 0.772552783109405, 'f1-score': 0.7392102846648301, 'auc': 0.7165328018111128}
#   0%|          | 0/10050 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.7119402985074627, 'precision': 0.684772929652716, 'recall': 0.7736418511066399, 'f1-score': 0.7264997638167219, 'auc': 0.712608327128123}
#   0%|          | 0/10276 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.7101167315175098, 'precision': 0.6893542757417103, 'recall': 0.7669902912621359, 'f1-score': 0.7261029411764706, 'auc': 0.7100058668786314}
#   0%|          | 0/10128 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.6984205330700889, 'precision': 0.6608391608391608, 'recall': 0.7722165474974464, 'f1-score': 0.7121997173810646, 'auc': 0.7008169652482455}
#   0%|          | 0/10178 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.7156188605108055, 'precision': 0.7024221453287197, 'recall': 0.775549188156638, 'f1-score': 0.7371765773944621, 'auc': 0.7138615506000582}
#   0%|          | 0/10160 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.7125984251968503, 'precision': 0.6989708404802745, 'recall': 0.7776717557251909, 'f1-score': 0.7362240289069558, 'auc': 0.7104822193260101}

# %%
DATA_NUMBER=8
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_results,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7suddenDrift.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.705242334322453, 'precision': 0.658578856152513, 'recall': 0.7900207900207901, 'f1-score': 0.718336483931947, 'auc': 0.7091613384066214}
#   0%|          | 0/10062 [00:00<?, ?it/s]
# Without Any FS
# 2 {'accuracy': 0.7203179334326876, 'precision': 0.7082585278276481, 'recall': 0.7682570593963, 'f1-score': 0.7370387669313404, 'auc': 0.7193212274669127}
#   0%|          | 0/10020 [00:00<?, ?it/s]
# Without Any FS
# 3 {'accuracy': 0.7130738522954092, 'precision': 0.7035398230088495, 'recall': 0.7681159420289855, 'f1-score': 0.7344110854503463, 'auc': 0.7111993538834297}
#   0%|          | 0/10054 [00:00<?, ?it/s]
# Without Any FS
# 4 {'accuracy': 0.6971655892590751, 'precision': 0.6747404844290658, 'recall': 0.769990128331688, 'f1-score': 0.719225449515906, 'auc': 0.69661831065883}
#   0%|          | 0/10186 [00:00<?, ?it/s]
# Without Any FS
# 5 {'accuracy': 0.7011776251226692, 'precision': 0.6646909398814564, 'recall': 0.7865731462925851, 'f1-score': 0.7205139972464433, 'auc': 0.7029019577616772}
#   0%|          | 0/10188 [00:00<?, ?it/s]
# Without Any FS
# 6 {'accuracy': 0.7016683022571149, 'precision': 0.6761658031088082, 'recall': 0.7706692913385826, 'f1-score': 0.7203311867525298, 'auc': 0.7018708491917962}
#   0%|          | 0/10132 [00:00<?, ?it/s]
# Without Any FS
# 7 {'accuracy': 0.7217562900838678, 'precision': 0.7021466905187835, 'recall': 0.7726377952755905, 'f1-score': 0.7357075913776944, 'auc': 0.721630470338092}
#   0%|          | 0/10170 [00:00<?, ?it/s]
# Without Any FS
# 8 {'accuracy': 0.7084562438544739, 'precision': 0.6883680555555556, 'recall': 0.7721518987341772, 'f1-score': 0.7278568150527766, 'auc': 0.707823715007605}
#   0%|          | 0/10216 [00:00<?, ?it/s]
# Without Any FS
# 9 {'accuracy': 0.7113502935420744, 'precision': 0.6827768014059754, 'recall': 0.7723658051689861, 'f1-score': 0.7248134328358209, 'auc': 0.7122908023918149}
#   0%|          | 0/10234 [00:00<?, ?it/s]
# Without Any FS
# 10 {'accuracy': 0.7034684904738642, 'precision': 0.6689419795221843, 'recall': 0.7816550348953141, 'f1-score': 0.7209195402298849, 'auc': 0.7050037626583849}
