# %%
# !pip install -q scikit-multiflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.6/450.6 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-multiflow (setup.py) ... done

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from skmultiflow.drift_detection import ADWIN, DDM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from matplotlib.colors import ListedColormap
from multiprocessing.pool import ThreadPool
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle
from contextlib import suppress
from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from random import shuffle
import seaborn as sns
from time import time
import pandas as pd
import numpy as np
import warnings
import scipy.io
import pickle
import sys
import gc
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/MyDrive/Colab_Notebooks/Muawiya/Genetic Programming Combiner with DFS/data'
code_path = '/content/drive/MyDrive/Colab_Notebooks/Muawiya/Genetic Programming Combiner with DFS/Codes/Shared Codes'
results_path = '/content/drive/MyDrive/Colab_Notebooks/Muawiya/Genetic Programming Combiner with DFS/Results'
feature_selection_results = '/content/drive/MyDrive/Colab_Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_results'
feature_selection_issam = '/content/drive/MyDrive/Colab_Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_issam'
sys.path.insert(0,code_path)
from oselm import set_use_know
from SharedFunctions import main, generate_oselm_models

# %%
filenames = ['kddcup99_csv.csv','ISCX2012.csv','CSE-CIC2018.csv','CICIDS2017.csv','Recurrent_Drift.csv', 'Blip_Drift.csv', 'Incremental_Drift.csv',
             'Gradual_Drift.csv', 'Sudden_Drift.csv']
filenames = list(map(lambda x: os.path.join(data_path, x), filenames))

# %%
data_name = ['kddcup99','ISCX2012','CSE-CIC2018','CICIDS2017','Recurrent_Drift', 'Blip_Drift', 'Incremental_Drift','Gradual_Drift', 'Sudden_Drift']

# %%
# # use_know = False
# # set_use_know(use_know)
# # path = os.path.join(results_path,'gp_combiner_with_model_replacement_DFS') # IssamDFS
# # os.makedirs(path, exist_ok=True)
# # for f_name,d_name in zip(filenames,data_name):
# #   DFS_results_path = os.path.join(feature_selection_results,d_name) # feature_selection_issam
# #   main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
# #        feature_selection=["with_out_feature_evolving",'DFS_feature_selection'], result_save_path=path,DFS_results_path=DFS_results_path)

# %%
# DATA_NUMBER=0
# ChunkNumber=0
# use_know = False
# set_use_know(use_know)
# path = os.path.join(results_path,'gp_combiner_with_model_replacement_IssamDFS') # DFS
# os.makedirs(path, exist_ok=True)
# f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
# DFS_results_path = os.path.join(feature_selection_issam,d_name) # feature_selection_results
# main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
#       feature_selection=["with_out_feature_evolving",'DFS_feature_selection'], result_save_path=path,
#      DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber,is_synthetic=False)

# %%
# DATA_NUMBER=1
# ChunkNumber=0
# use_know = False
# set_use_know(use_know)
# path = os.path.join(results_path,'gp_combiner_with_model_replacement_IssamDFS') # DFS
# os.makedirs(path, exist_ok=True)
# f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
# DFS_results_path = os.path.join(feature_selection_issam,d_name) # feature_selection_results
# main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
#       feature_selection=["with_out_feature_evolving",'DFS_feature_selection'], result_save_path=path,
#      DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber,is_synthetic=False,chunk_size = 1000)

# %%
# DATA_NUMBER=2
# ChunkNumber=0
# use_know = False
# set_use_know(use_know)
# path = os.path.join(results_path,'gp_combiner_with_model_replacement_IssamDFS') # DFS
# os.makedirs(path, exist_ok=True)
# f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
# DFS_results_path = os.path.join(feature_selection_issam,d_name) # feature_selection_results
# main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
#       feature_selection=["with_out_feature_evolving",'DFS_feature_selection'], result_save_path=path,
#      DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber,is_synthetic=False,chunk_size = 3500)

# %%
# DATA_NUMBER=3
# ChunkNumber=0
# use_know = False
# set_use_know(use_know)
# path = os.path.join(results_path,'gp_combiner_with_model_replacement_IssamDFS') # DFS
# os.makedirs(path, exist_ok=True)
# f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
# DFS_results_path = os.path.join(feature_selection_issam,d_name) # feature_selection_results
# main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
#       feature_selection=["with_out_feature_evolving",'DFS_feature_selection'], result_save_path=path,
#       DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber,is_synthetic=False,chunk_size = 1000)

# %%
# DATA_NUMBER=4
# ChunkNumber=0
# use_know = False
# set_use_know(use_know)
# path = os.path.join(results_path,'gp_combiner_with_model_replacement_IssamDFS') # DFS
# os.makedirs(path, exist_ok=True)
# f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
# DFS_results_path = os.path.join(feature_selection_issam,d_name) # feature_selection_results
# main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
#       feature_selection=["with_out_feature_evolving",'DFS_feature_selection'], result_save_path=path,
#      DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)

# %%
# DATA_NUMBER=5
# ChunkNumber=0
# use_know = False
# set_use_know(use_know)
# path = os.path.join(results_path,'gp_combiner_with_model_replacement_IssamDFS') # DFS
# os.makedirs(path, exist_ok=True)
# f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
# DFS_results_path = os.path.join(feature_selection_issam,d_name) # feature_selection_results
# main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
#       feature_selection=["with_out_feature_evolving",'DFS_feature_selection'], result_save_path=path,
#      DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)

# %%
DATA_NUMBER=6
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_IssamDFS') # DFS
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_issam,d_name) # feature_selection_results
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
      feature_selection=["with_out_feature_evolving",'DFS_feature_selection'], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : Incremental_Drift.csv ======================
# 0it [00:00, ?it/s]
# DFS
# 1 {'accuracy': 0.6607142857142857, 'precision': 0.6351351351351351, 'recall': 0.8103448275862069, 'f1-score': 0.712121212121212, 'auc': 0.6551724137931034}
# DFS
# 2 {'accuracy': 0.6699029126213593, 'precision': 0.6885245901639344, 'recall': 0.7368421052631579, 'f1-score': 0.7118644067796609, 'auc': 0.6618993135011442}
# DFS
# 3 {'accuracy': 0.625, 'precision': 0.6268656716417911, 'recall': 0.75, 'f1-score': 0.6829268292682927, 'auc': 0.6145833333333333}
# DFS
# 4 {'accuracy': 0.6981132075471698, 'precision': 0.6666666666666666, 'recall': 0.7692307692307693, 'f1-score': 0.7142857142857142, 'auc': 0.6994301994301994}
# DFS
# 5 {'accuracy': 0.5841584158415841, 'precision': 0.5517241379310345, 'recall': 0.6666666666666666, 'f1-score': 0.6037735849056604, 'auc': 0.5880503144654088}
# DFS
# 6 {'accuracy': 0.5185185185185185, 'precision': 0.582089552238806, 'recall': 0.6190476190476191, 'f1-score': 0.6, 'auc': 0.4984126984126984}
# DFS
# 7 {'accuracy': 0.5943396226415094, 'precision': 0.59375, 'recall': 0.6909090909090909, 'f1-score': 0.6386554621848739, 'auc': 0.5905525846702318}
# DFS
# 8 {'accuracy': 0.6792452830188679, 'precision': 0.7192982456140351, 'recall': 0.6949152542372882, 'f1-score': 0.706896551724138, 'auc': 0.6772448611611972}
# DFS
# 9 {'accuracy': 0.5420560747663551, 'precision': 0.49019607843137253, 'recall': 0.5208333333333334, 'f1-score': 0.5050505050505051, 'auc': 0.5400776836158193}
# DFS
# 10 {'accuracy': 0.5779816513761468, 'precision': 0.6111111111111112, 'recall': 0.5689655172413793, 'f1-score': 0.5892857142857143, 'auc': 0.5786004056795132}
# DFS
# 11 {'accuracy': 0.660377358490566, 'precision': 0.6363636363636364, 'recall': 0.7777777777777778, 'f1-score': 0.7000000000000001, 'auc': 0.6581196581196581}
# DFS
# 12 {'accuracy': 0.65, 'precision': 0.6379310344827587, 'recall': 0.7254901960784313, 'f1-score': 0.6788990825688075, 'auc': 0.6484593837535014}
# DFS
# 13 {'accuracy': 0.6039603960396039, 'precision': 0.5625, 'recall': 0.5869565217391305, 'f1-score': 0.5744680851063831, 'auc': 0.6025691699604743}
# DFS
# 14 {'accuracy': 0.5769230769230769, 'precision': 0.5625, 'recall': 0.6923076923076923, 'f1-score': 0.6206896551724138, 'auc': 0.5769230769230769}
# DFS
# 15 {'accuracy': 0.6190476190476191, 'precision': 0.5789473684210527, 'recall': 0.673469387755102, 'f1-score': 0.6226415094339622, 'auc': 0.6224489795918366}
# DFS
# 16 {'accuracy': 0.5619047619047619, 'precision': 0.5, 'recall': 0.6956521739130435, 'f1-score': 0.5818181818181818, 'auc': 0.5766396462785557}
# DFS
# 17 {'accuracy': 0.5588235294117647, 'precision': 0.6461538461538462, 'recall': 0.65625, 'f1-score': 0.6511627906976746, 'auc': 0.5254934210526316}
# DFS
# 18 {'accuracy': 0.6057692307692307, 'precision': 0.603448275862069, 'recall': 0.660377358490566, 'f1-score': 0.6306306306306305, 'auc': 0.6046984831668517}
# DFS
# 19 {'accuracy': 0.5490196078431373, 'precision': 0.6029411764705882, 'recall': 0.6833333333333333, 'f1-score': 0.640625, 'auc': 0.5202380952380953}
# DFS
# 20 {'accuracy': 0.5714285714285714, 'precision': 0.5517241379310345, 'recall': 0.6274509803921569, 'f1-score': 0.5871559633027523, 'auc': 0.5729847494553377}
# DFS
# 21 {'accuracy': 0.638095238095238, 'precision': 0.6290322580645161, 'recall': 0.7222222222222222, 'f1-score': 0.6724137931034483, 'auc': 0.6356209150326798}
# DFS
# 22 {'accuracy': 0.6346153846153846, 'precision': 0.5806451612903226, 'recall': 0.75, 'f1-score': 0.6545454545454547, 'auc': 0.6428571428571428}
# DFS
# 23 {'accuracy': 0.5673076923076923, 'precision': 0.5789473684210527, 'recall': 0.6111111111111112, 'f1-score': 0.5945945945945946, 'auc': 0.5655555555555556}
# DFS
# 24 {'accuracy': 0.5420560747663551, 'precision': 0.5522388059701493, 'recall': 0.6607142857142857, 'f1-score': 0.6016260162601627, 'auc': 0.5362394957983193}
# DFS
# 25 {'accuracy': 0.6470588235294118, 'precision': 0.5833333333333334, 'recall': 0.7608695652173914, 'f1-score': 0.6603773584905662, 'auc': 0.65722049689441}
# DFS
# 26 {'accuracy': 0.5981308411214953, 'precision': 0.5483870967741935, 'recall': 0.6938775510204082, 'f1-score': 0.6126126126126127, 'auc': 0.6055594651653764}
# DFS
# 27 {'accuracy': 0.6454545454545455, 'precision': 0.6, 'recall': 0.8333333333333334, 'f1-score': 0.6976744186046512, 'auc': 0.6488095238095238}
# DFS
# 28 {'accuracy': 0.5619047619047619, 'precision': 0.5294117647058824, 'recall': 0.72, 'f1-score': 0.6101694915254237, 'auc': 0.5690909090909091}
# DFS
# 29 {'accuracy': 0.5576923076923077, 'precision': 0.5277777777777778, 'recall': 0.76, 'f1-score': 0.6229508196721312, 'auc': 0.5651851851851852}
# DFS
# 30 {'accuracy': 0.5392156862745098, 'precision': 0.49230769230769234, 'recall': 0.6956521739130435, 'f1-score': 0.5765765765765766, 'auc': 0.5531832298136645}
# DFS
# 31 {'accuracy': 0.6826923076923077, 'precision': 0.6229508196721312, 'recall': 0.7916666666666666, 'f1-score': 0.6972477064220183, 'auc': 0.6904761904761905}
# DFS
# 32 {'accuracy': 0.6111111111111112, 'precision': 0.6666666666666666, 'recall': 0.6875, 'f1-score': 0.676923076923077, 'auc': 0.59375}
# DFS
# 33 {'accuracy': 0.5849056603773585, 'precision': 0.5625, 'recall': 0.6923076923076923, 'f1-score': 0.6206896551724138, 'auc': 0.586894586894587}
# DFS
# 34 {'accuracy': 0.6568627450980392, 'precision': 0.6, 'recall': 0.7659574468085106, 'f1-score': 0.6728971962616823, 'auc': 0.6647969052224372}
# DFS
# 35 {'accuracy': 0.5849056603773585, 'precision': 0.559322033898305, 'recall': 0.6470588235294118, 'f1-score': 0.6, 'auc': 0.5871657754010695}
# DFS
# 36 {'accuracy': 0.58, 'precision': 0.6666666666666666, 'recall': 0.6, 'f1-score': 0.631578947368421, 'auc': 0.5750000000000001}
# DFS
# 37 {'accuracy': 0.5533980582524272, 'precision': 0.543859649122807, 'recall': 0.6078431372549019, 'f1-score': 0.5740740740740741, 'auc': 0.553921568627451}
# DFS
# 38 {'accuracy': 0.6339285714285714, 'precision': 0.6666666666666666, 'recall': 0.6557377049180327, 'f1-score': 0.6611570247933883, 'auc': 0.6317904210864673}
# DFS
# 39 {'accuracy': 0.6698113207547169, 'precision': 0.6, 'recall': 0.8125, 'f1-score': 0.6902654867256637, 'auc': 0.6821120689655172}
# DFS
# 40 {'accuracy': 0.6138613861386139, 'precision': 0.5737704918032787, 'recall': 0.7291666666666666, 'f1-score': 0.6422018348623854, 'auc': 0.6193003144654088}
# DFS
# 41 {'accuracy': 0.6633663366336634, 'precision': 0.6779661016949152, 'recall': 0.7272727272727273, 'f1-score': 0.7017543859649122, 'auc': 0.6571146245059288}
# DFS
# 42 {'accuracy': 0.6039603960396039, 'precision': 0.532258064516129, 'recall': 0.75, 'f1-score': 0.6226415094339622, 'auc': 0.6206140350877193}
# DFS
# 43 {'accuracy': 0.6, 'precision': 0.5636363636363636, 'recall': 0.6326530612244898, 'f1-score': 0.5961538461538461, 'auc': 0.6020408163265306}
# DFS
# 44 {'accuracy': 0.6730769230769231, 'precision': 0.6461538461538462, 'recall': 0.7924528301886793, 'f1-score': 0.711864406779661, 'auc': 0.6707362190159083}
# DFS
# 45 {'accuracy': 0.5686274509803921, 'precision': 0.5373134328358209, 'recall': 0.7346938775510204, 'f1-score': 0.6206896551724138, 'auc': 0.574894108586831}
# DFS
# 46 {'accuracy': 0.5588235294117647, 'precision': 0.625, 'recall': 0.6557377049180327, 'f1-score': 0.64, 'auc': 0.5351859256297481}
# DFS
# 47 {'accuracy': 0.7029702970297029, 'precision': 0.6716417910447762, 'recall': 0.8490566037735849, 'f1-score': 0.7500000000000001, 'auc': 0.6953616352201258}
# DFS
# 48 {'accuracy': 0.6470588235294118, 'precision': 0.5846153846153846, 'recall': 0.8085106382978723, 'f1-score': 0.6785714285714286, 'auc': 0.6588007736943906}
# DFS
# 49 {'accuracy': 0.6372549019607843, 'precision': 0.6, 'recall': 0.78, 'f1-score': 0.6782608695652174, 'auc': 0.64}
# DFS
# 50 {'accuracy': 0.6509433962264151, 'precision': 0.6617647058823529, 'recall': 0.7627118644067796, 'f1-score': 0.7086614173228345, 'auc': 0.6366750811395601}
# DFS
# 51 {'accuracy': 0.5980392156862745, 'precision': 0.6, 'recall': 0.6792452830188679, 'f1-score': 0.6371681415929203, 'auc': 0.5947246823257605}
# DFS
# 52 {'accuracy': 0.6190476190476191, 'precision': 0.5645161290322581, 'recall': 0.7291666666666666, 'f1-score': 0.6363636363636364, 'auc': 0.6277412280701755}
# DFS
# 53 {'accuracy': 0.5961538461538461, 'precision': 0.5671641791044776, 'recall': 0.7450980392156863, 'f1-score': 0.6440677966101696, 'auc': 0.5989641139474657}
# DFS
# 54 {'accuracy': 0.5648148148148148, 'precision': 0.5409836065573771, 'recall': 0.6346153846153846, 'f1-score': 0.5840707964601771, 'auc': 0.5673076923076923}
# DFS
# 55 {'accuracy': 0.638095238095238, 'precision': 0.6567164179104478, 'recall': 0.7457627118644068, 'f1-score': 0.6984126984126985, 'auc': 0.6228813559322034}
# DFS
# 56 {'accuracy': 0.6944444444444444, 'precision': 0.6666666666666666, 'recall': 0.7777777777777778, 'f1-score': 0.717948717948718, 'auc': 0.6944444444444444}
# DFS
# 57 {'accuracy': 0.5784313725490197, 'precision': 0.5396825396825397, 'recall': 0.7083333333333334, 'f1-score': 0.6126126126126126, 'auc': 0.5856481481481481}
# DFS
# 58 {'accuracy': 0.6936936936936937, 'precision': 0.6323529411764706, 'recall': 0.8269230769230769, 'f1-score': 0.7166666666666666, 'auc': 0.7015971316818774}
# DFS
# 59 {'accuracy': 0.6019417475728155, 'precision': 0.5692307692307692, 'recall': 0.74, 'f1-score': 0.6434782608695652, 'auc': 0.6058490566037736}
# DFS
# 60 {'accuracy': 0.48514851485148514, 'precision': 0.46551724137931033, 'recall': 0.5625, 'f1-score': 0.5094339622641509, 'auc': 0.48879716981132076}
# DFS
# 61 {'accuracy': 0.6504854368932039, 'precision': 0.6212121212121212, 'recall': 0.7884615384615384, 'f1-score': 0.6949152542372881, 'auc': 0.6491327300150829}
# DFS
# 62 {'accuracy': 0.625, 'precision': 0.5483870967741935, 'recall': 0.7555555555555555, 'f1-score': 0.6355140186915887, 'auc': 0.6404896421845574}
# DFS
# 63 {'accuracy': 0.7075471698113207, 'precision': 0.6571428571428571, 'recall': 0.8679245283018868, 'f1-score': 0.7479674796747967, 'auc': 0.7075471698113207}
# DFS
# 64 {'accuracy': 0.6534653465346535, 'precision': 0.6779661016949152, 'recall': 0.7142857142857143, 'f1-score': 0.6956521739130435, 'auc': 0.6460317460317461}
# DFS
# 65 {'accuracy': 0.5196078431372549, 'precision': 0.49230769230769234, 'recall': 0.6666666666666666, 'f1-score': 0.5663716814159293, 'auc': 0.5277777777777777}
# DFS
# 66 {'accuracy': 0.6792452830188679, 'precision': 0.59375, 'recall': 0.8260869565217391, 'f1-score': 0.6909090909090908, 'auc': 0.696376811594203}
# DFS
# 67 {'accuracy': 0.6634615384615384, 'precision': 0.6545454545454545, 'recall': 0.6923076923076923, 'f1-score': 0.6728971962616823, 'auc': 0.6634615384615383}
# DFS
# 68 {'accuracy': 0.6605504587155964, 'precision': 0.6197183098591549, 'recall': 0.8148148148148148, 'f1-score': 0.704, 'auc': 0.661952861952862}
# DFS
# 69 {'accuracy': 0.6132075471698113, 'precision': 0.6166666666666667, 'recall': 0.6727272727272727, 'f1-score': 0.6434782608695652, 'auc': 0.6108734402852051}
# DFS
# 70 {'accuracy': 0.7281553398058253, 'precision': 0.7358490566037735, 'recall': 0.7358490566037735, 'f1-score': 0.7358490566037735, 'auc': 0.7279245283018868}
# DFS
# 71 {'accuracy': 0.5943396226415094, 'precision': 0.5079365079365079, 'recall': 0.7272727272727273, 'f1-score': 0.5981308411214953, 'auc': 0.6136363636363636}
# DFS
# 72 {'accuracy': 0.6, 'precision': 0.5172413793103449, 'recall': 0.6818181818181818, 'f1-score': 0.5882352941176471, 'auc': 0.6114008941877793}
# DFS
# 73 {'accuracy': 0.6634615384615384, 'precision': 0.6666666666666666, 'recall': 0.7272727272727273, 'f1-score': 0.6956521739130435, 'auc': 0.6595547309833024}
# DFS
# 74 {'accuracy': 0.5643564356435643, 'precision': 0.5625, 'recall': 0.6923076923076923, 'f1-score': 0.6206896551724138, 'auc': 0.5604395604395604}
# DFS
# 75 {'accuracy': 0.6226415094339622, 'precision': 0.6226415094339622, 'recall': 0.6226415094339622, 'f1-score': 0.6226415094339622, 'auc': 0.6226415094339623}
# DFS
# 76 {'accuracy': 0.6407766990291263, 'precision': 0.5789473684210527, 'recall': 0.8979591836734694, 'f1-score': 0.704, 'auc': 0.6526832955404385}
# DFS
# 77 {'accuracy': 0.6990291262135923, 'precision': 0.631578947368421, 'recall': 0.782608695652174, 'f1-score': 0.6990291262135923, 'auc': 0.7070938215102974}
# DFS
# 78 {'accuracy': 0.5247524752475248, 'precision': 0.49230769230769234, 'recall': 0.6808510638297872, 'f1-score': 0.5714285714285714, 'auc': 0.5348699763593381}
# DFS
# 79 {'accuracy': 0.47058823529411764, 'precision': 0.4927536231884058, 'recall': 0.6415094339622641, 'f1-score': 0.5573770491803278, 'auc': 0.4636118598382749}
# DFS
# 80 {'accuracy': 0.6699029126213593, 'precision': 0.6129032258064516, 'recall': 0.7916666666666666, 'f1-score': 0.6909090909090909, 'auc': 0.6776515151515152}
# DFS
# 81 {'accuracy': 0.56, 'precision': 0.4915254237288136, 'recall': 0.6744186046511628, 'f1-score': 0.5686274509803922, 'auc': 0.5740514075887393}
# DFS
# 82 {'accuracy': 0.5544554455445545, 'precision': 0.4852941176470588, 'recall': 0.7674418604651163, 'f1-score': 0.5945945945945945, 'auc': 0.5819967923015237}
# DFS
# 83 {'accuracy': 0.625, 'precision': 0.6724137931034483, 'recall': 0.6610169491525424, 'f1-score': 0.6666666666666666, 'auc': 0.6193973634651601}
# DFS
# 84 {'accuracy': 0.6634615384615384, 'precision': 0.676923076923077, 'recall': 0.7586206896551724, 'f1-score': 0.7154471544715447, 'auc': 0.6510494752623688}
# DFS
# 85 {'accuracy': 0.6666666666666666, 'precision': 0.6461538461538462, 'recall': 0.7777777777777778, 'f1-score': 0.7058823529411764, 'auc': 0.6633986928104575}
# DFS
# 86 {'accuracy': 0.5, 'precision': 0.5285714285714286, 'recall': 0.6727272727272727, 'f1-score': 0.5920000000000001, 'auc': 0.48529980657640237}
# DFS
# 87 {'accuracy': 0.5523809523809524, 'precision': 0.5396825396825397, 'recall': 0.6538461538461539, 'f1-score': 0.5913043478260869, 'auc': 0.5533381712626996}
# DFS
# 88 {'accuracy': 0.6504854368932039, 'precision': 0.5652173913043478, 'recall': 0.8666666666666667, 'f1-score': 0.6842105263157895, 'auc': 0.674712643678161}
# DFS
# 89 {'accuracy': 0.67, 'precision': 0.6417910447761194, 'recall': 0.8269230769230769, 'f1-score': 0.722689075630252, 'auc': 0.6634615384615384}
# DFS
# 90 {'accuracy': 0.6310679611650486, 'precision': 0.6101694915254238, 'recall': 0.7058823529411765, 'f1-score': 0.6545454545454547, 'auc': 0.6317873303167421}
# DFS
# 91 {'accuracy': 0.7211538461538461, 'precision': 0.7230769230769231, 'recall': 0.8103448275862069, 'f1-score': 0.7642276422764227, 'auc': 0.70952023988006}
# DFS
# 92 {'accuracy': 0.5849056603773585, 'precision': 0.5873015873015873, 'recall': 0.6727272727272727, 'f1-score': 0.6271186440677966, 'auc': 0.5814616755793227}
# DFS
# 93 {'accuracy': 0.5882352941176471, 'precision': 0.625, 'recall': 0.625, 'f1-score': 0.625, 'auc': 0.5842391304347826}
# DFS
# 94 {'accuracy': 0.63, 'precision': 0.6779661016949152, 'recall': 0.6896551724137931, 'f1-score': 0.6837606837606838, 'auc': 0.6186371100164204}
# DFS
# 95 {'accuracy': 0.6448598130841121, 'precision': 0.7068965517241379, 'recall': 0.6612903225806451, 'f1-score': 0.6833333333333333, 'auc': 0.6417562724014336}
# DFS
# 96 {'accuracy': 0.6074766355140186, 'precision': 0.5714285714285714, 'recall': 0.5714285714285714, 'f1-score': 0.5714285714285714, 'auc': 0.604679802955665}
# DFS
# 97 {'accuracy': 0.6862745098039216, 'precision': 0.676923076923077, 'recall': 0.8, 'f1-score': 0.7333333333333334, 'auc': 0.6765957446808512}
# DFS
# 98 {'accuracy': 0.6078431372549019, 'precision': 0.5555555555555556, 'recall': 0.7446808510638298, 'f1-score': 0.6363636363636364, 'auc': 0.6177949709864604}
# DFS
# 99 {'accuracy': 0.6176470588235294, 'precision': 0.5735294117647058, 'recall': 0.7959183673469388, 'f1-score': 0.6666666666666666, 'auc': 0.624374278013092}
# DFS
# 100 {'accuracy': 0.5377358490566038, 'precision': 0.5151515151515151, 'recall': 0.6666666666666666, 'f1-score': 0.5811965811965812, 'auc': 0.5424242424242424}

# %%
DATA_NUMBER=7
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_IssamDFS') # DFS
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_issam,d_name) # feature_selection_results
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
      feature_selection=["with_out_feature_evolving",'DFS_feature_selection'], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : Gradual_Drift.csv ======================
# 0it [00:00, ?it/s]
# DFS
# 1 {'accuracy': 0.5454545454545454, 'precision': 0.5423728813559322, 'recall': 0.5818181818181818, 'f1-score': 0.5614035087719298, 'auc': 0.5454545454545454}
# DFS
# 2 {'accuracy': 0.5865384615384616, 'precision': 0.5849056603773585, 'recall': 0.5961538461538461, 'f1-score': 0.5904761904761905, 'auc': 0.5865384615384615}
# DFS
# 3 {'accuracy': 0.5048543689320388, 'precision': 0.5, 'recall': 0.4117647058823529, 'f1-score': 0.45161290322580644, 'auc': 0.5039592760180995}
# DFS
# 4 {'accuracy': 0.5514018691588785, 'precision': 0.5961538461538461, 'recall': 0.5344827586206896, 'f1-score': 0.5636363636363636, 'auc': 0.5529556650246304}
# DFS
# 5 {'accuracy': 0.5882352941176471, 'precision': 0.5909090909090909, 'recall': 0.52, 'f1-score': 0.5531914893617023, 'auc': 0.5869230769230769}
# DFS
# 6 {'accuracy': 0.5377358490566038, 'precision': 0.5116279069767442, 'recall': 0.44, 'f1-score': 0.4731182795698925, 'auc': 0.5325}
# DFS
# 7 {'accuracy': 0.4953271028037383, 'precision': 0.4745762711864407, 'recall': 0.5490196078431373, 'f1-score': 0.5090909090909091, 'auc': 0.49772408963585435}
# DFS
# 8 {'accuracy': 0.5046728971962616, 'precision': 0.5555555555555556, 'recall': 0.43103448275862066, 'f1-score': 0.4854368932038835, 'auc': 0.511435608726249}
# DFS
# 9 {'accuracy': 0.5769230769230769, 'precision': 0.5555555555555556, 'recall': 0.5102040816326531, 'f1-score': 0.5319148936170212, 'auc': 0.5732838589981446}
# DFS
# 10 {'accuracy': 0.5728155339805825, 'precision': 0.5833333333333334, 'recall': 0.5384615384615384, 'f1-score': 0.5599999999999999, 'auc': 0.5731523378582202}
# DFS
# 11 {'accuracy': 0.5882352941176471, 'precision': 0.5319148936170213, 'recall': 0.5555555555555556, 'f1-score': 0.5434782608695652, 'auc': 0.5847953216374269}
# DFS
# 12 {'accuracy': 0.47058823529411764, 'precision': 0.42857142857142855, 'recall': 0.44680851063829785, 'f1-score': 0.4375, 'auc': 0.46885880077369435}
# DFS
# 13 {'accuracy': 0.5533980582524272, 'precision': 0.62, 'recall': 0.5344827586206896, 'f1-score': 0.574074074074074, 'auc': 0.5561302681992336}
# DFS
# 14 {'accuracy': 0.46534653465346537, 'precision': 0.47058823529411764, 'recall': 0.47058823529411764, 'f1-score': 0.47058823529411764, 'auc': 0.46529411764705886}
# DFS
# 15 {'accuracy': 0.49056603773584906, 'precision': 0.603448275862069, 'recall': 0.5303030303030303, 'f1-score': 0.5645161290322581, 'auc': 0.47765151515151516}
# DFS
# 16 {'accuracy': 0.5046728971962616, 'precision': 0.5833333333333334, 'recall': 0.45901639344262296, 'f1-score': 0.5137614678899083, 'auc': 0.5121168923734855}
# DFS
# 17 {'accuracy': 0.5607476635514018, 'precision': 0.5714285714285714, 'recall': 0.4528301886792453, 'f1-score': 0.5052631578947369, 'auc': 0.559748427672956}
# DFS
# 18 {'accuracy': 0.43137254901960786, 'precision': 0.45652173913043476, 'recall': 0.3888888888888889, 'f1-score': 0.42, 'auc': 0.43402777777777773}
# DFS
# 19 {'accuracy': 0.5242718446601942, 'precision': 0.44642857142857145, 'recall': 0.5813953488372093, 'f1-score': 0.5050505050505051, 'auc': 0.5323643410852713}
# DFS
# 20 {'accuracy': 0.47619047619047616, 'precision': 0.391304347826087, 'recall': 0.4, 'f1-score': 0.3956043956043956, 'auc': 0.4666666666666666}
# DFS
# 21 {'accuracy': 0.5555555555555556, 'precision': 0.5333333333333333, 'recall': 0.6153846153846154, 'f1-score': 0.5714285714285715, 'auc': 0.5576923076923077}
# DFS
# 22 {'accuracy': 0.5242718446601942, 'precision': 0.46153846153846156, 'recall': 0.5333333333333333, 'f1-score': 0.4948453608247423, 'auc': 0.525287356321839}
# DFS
# 23 {'accuracy': 0.58, 'precision': 0.6470588235294118, 'recall': 0.4230769230769231, 'f1-score': 0.5116279069767442, 'auc': 0.5865384615384616}
# DFS
# 24 {'accuracy': 0.5148514851485149, 'precision': 0.5454545454545454, 'recall': 0.4528301886792453, 'f1-score': 0.49484536082474223, 'auc': 0.5180817610062892}
# DFS
# 25 {'accuracy': 0.5148514851485149, 'precision': 0.5344827586206896, 'recall': 0.5849056603773585, 'f1-score': 0.5585585585585585, 'auc': 0.5112028301886793}
# DFS
# 26 {'accuracy': 0.580952380952381, 'precision': 0.6078431372549019, 'recall': 0.5636363636363636, 'f1-score': 0.5849056603773585, 'auc': 0.5818181818181818}
# DFS
# 27 {'accuracy': 0.5196078431372549, 'precision': 0.5333333333333333, 'recall': 0.46153846153846156, 'f1-score': 0.4948453608247423, 'auc': 0.5207692307692309}
# DFS
# 28 {'accuracy': 0.5283018867924528, 'precision': 0.5454545454545454, 'recall': 0.5454545454545454, 'f1-score': 0.5454545454545454, 'auc': 0.5276292335115864}
# DFS
# 29 {'accuracy': 0.5, 'precision': 0.5609756097560976, 'recall': 0.4107142857142857, 'f1-score': 0.4742268041237114, 'auc': 0.5097049689440993}
# DFS
# 30 {'accuracy': 0.42574257425742573, 'precision': 0.38095238095238093, 'recall': 0.3333333333333333, 'f1-score': 0.35555555555555557, 'auc': 0.4213836477987421}
# DFS
# 31 {'accuracy': 0.5566037735849056, 'precision': 0.5652173913043478, 'recall': 0.49056603773584906, 'f1-score': 0.5252525252525252, 'auc': 0.5566037735849056}
# DFS
# 32 {'accuracy': 0.580952380952381, 'precision': 0.5952380952380952, 'recall': 0.4807692307692308, 'f1-score': 0.5319148936170213, 'auc': 0.5800072568940494}
# DFS
# 33 {'accuracy': 0.6, 'precision': 0.5483870967741935, 'recall': 0.68, 'f1-score': 0.6071428571428571, 'auc': 0.6066666666666667}
# DFS
# 34 {'accuracy': 0.56, 'precision': 0.5416666666666666, 'recall': 0.5416666666666666, 'f1-score': 0.5416666666666666, 'auc': 0.5592948717948717}
# DFS
# 35 {'accuracy': 0.509090909090909, 'precision': 0.5423728813559322, 'recall': 0.5423728813559322, 'f1-score': 0.5423728813559322, 'auc': 0.5064805583250249}
# DFS
# 36 {'accuracy': 0.5471698113207547, 'precision': 0.6326530612244898, 'recall': 0.5081967213114754, 'f1-score': 0.5636363636363637, 'auc': 0.5540983606557377}
# DFS
# 37 {'accuracy': 0.49504950495049505, 'precision': 0.5238095238095238, 'recall': 0.41509433962264153, 'f1-score': 0.4631578947368421, 'auc': 0.49921383647798734}
# DFS
# 38 {'accuracy': 0.5980392156862745, 'precision': 0.6363636363636364, 'recall': 0.5283018867924528, 'f1-score': 0.5773195876288659, 'auc': 0.6008856372737774}
# DFS
# 39 {'accuracy': 0.5825242718446602, 'precision': 0.5918367346938775, 'recall': 0.5576923076923077, 'f1-score': 0.5742574257425743, 'auc': 0.5827677224736049}
# DFS
# 40 {'accuracy': 0.6074766355140186, 'precision': 0.6666666666666666, 'recall': 0.6, 'f1-score': 0.631578947368421, 'auc': 0.6085106382978724}
# DFS
# 41 {'accuracy': 0.43137254901960786, 'precision': 0.48936170212765956, 'recall': 0.40350877192982454, 'f1-score': 0.4423076923076923, 'auc': 0.4350877192982456}
# DFS
# 42 {'accuracy': 0.5566037735849056, 'precision': 0.5555555555555556, 'recall': 0.6481481481481481, 'f1-score': 0.5982905982905983, 'auc': 0.5548433048433049}
# DFS
# 43 {'accuracy': 0.5686274509803921, 'precision': 0.6470588235294118, 'recall': 0.559322033898305, 'f1-score': 0.6, 'auc': 0.5703586913677571}
# DFS
# 44 {'accuracy': 0.4807692307692308, 'precision': 0.5510204081632653, 'recall': 0.4576271186440678, 'f1-score': 0.4999999999999999, 'auc': 0.4843691148775895}
# DFS
# 45 {'accuracy': 0.5818181818181818, 'precision': 0.5892857142857143, 'recall': 0.5892857142857143, 'f1-score': 0.5892857142857143, 'auc': 0.5816798941798942}
# DFS
# 46 {'accuracy': 0.5392156862745098, 'precision': 0.5348837209302325, 'recall': 0.46, 'f1-score': 0.4946236559139785, 'auc': 0.5376923076923077}
# DFS
# 47 {'accuracy': 0.5145631067961165, 'precision': 0.45614035087719296, 'recall': 0.5777777777777777, 'f1-score': 0.5098039215686275, 'auc': 0.521647509578544}
# DFS
# 48 {'accuracy': 0.5181818181818182, 'precision': 0.5833333333333334, 'recall': 0.45901639344262296, 'f1-score': 0.5137614678899083, 'auc': 0.5254265640682503}
# DFS
# 49 {'accuracy': 0.5098039215686274, 'precision': 0.4666666666666667, 'recall': 0.44680851063829785, 'f1-score': 0.45652173913043476, 'auc': 0.5052224371373307}
# DFS
# 50 {'accuracy': 0.504950495049505, 'precision': 0.5102040816326531, 'recall': 0.49019607843137253, 'f1-score': 0.5, 'auc': 0.5050980392156863}
# DFS
# 51 {'accuracy': 0.5242718446601942, 'precision': 0.5102040816326531, 'recall': 0.5, 'f1-score': 0.5050505050505051, 'auc': 0.5235849056603773}
# DFS
# 52 {'accuracy': 0.5490196078431373, 'precision': 0.5333333333333333, 'recall': 0.4897959183673469, 'f1-score': 0.5106382978723404, 'auc': 0.5467847516365036}
# DFS
# 53 {'accuracy': 0.5096153846153846, 'precision': 0.46153846153846156, 'recall': 0.375, 'f1-score': 0.41379310344827586, 'auc': 0.5}
# DFS
# 54 {'accuracy': 0.5346534653465347, 'precision': 0.575, 'recall': 0.4339622641509434, 'f1-score': 0.49462365591397855, 'auc': 0.5398977987421384}
# DFS
# 55 {'accuracy': 0.4803921568627451, 'precision': 0.38461538461538464, 'recall': 0.4878048780487805, 'f1-score': 0.4301075268817205, 'auc': 0.4816073570571771}
# DFS
# 56 {'accuracy': 0.49056603773584906, 'precision': 0.5, 'recall': 0.5185185185185185, 'f1-score': 0.509090909090909, 'auc': 0.49002849002849}
# DFS
# 57 {'accuracy': 0.5148514851485149, 'precision': 0.5094339622641509, 'recall': 0.54, 'f1-score': 0.5242718446601942, 'auc': 0.5150980392156863}
# DFS
# 58 {'accuracy': 0.4803921568627451, 'precision': 0.5714285714285714, 'recall': 0.4666666666666667, 'f1-score': 0.5137614678899083, 'auc': 0.4833333333333334}
# DFS
# 59 {'accuracy': 0.580952380952381, 'precision': 0.582089552238806, 'recall': 0.7090909090909091, 'f1-score': 0.6393442622950819, 'auc': 0.5745454545454545}
# DFS
# 60 {'accuracy': 0.44660194174757284, 'precision': 0.39473684210526316, 'recall': 0.30612244897959184, 'f1-score': 0.3448275862068966, 'auc': 0.440098261526833}
# DFS
# 61 {'accuracy': 0.43137254901960786, 'precision': 0.37209302325581395, 'recall': 0.3404255319148936, 'f1-score': 0.3555555555555555, 'auc': 0.42475822050290135}
# DFS
# 62 {'accuracy': 0.5922330097087378, 'precision': 0.6086956521739131, 'recall': 0.5384615384615384, 'f1-score': 0.5714285714285715, 'auc': 0.592760180995475}
# DFS
# 63 {'accuracy': 0.5, 'precision': 0.5294117647058824, 'recall': 0.4909090909090909, 'f1-score': 0.5094339622641509, 'auc': 0.500556586270872}
# DFS
# 64 {'accuracy': 0.5, 'precision': 0.5416666666666666, 'recall': 0.4642857142857143, 'f1-score': 0.5, 'auc': 0.5029761904761906}
# DFS
# 65 {'accuracy': 0.5784313725490197, 'precision': 0.5849056603773585, 'recall': 0.5961538461538461, 'f1-score': 0.5904761904761905, 'auc': 0.5780769230769232}
# DFS
# 66 {'accuracy': 0.5673076923076923, 'precision': 0.5357142857142857, 'recall': 0.6122448979591837, 'f1-score': 0.5714285714285714, 'auc': 0.5697588126159555}
# DFS
# 67 {'accuracy': 0.5825242718446602, 'precision': 0.58, 'recall': 0.5686274509803921, 'f1-score': 0.5742574257425743, 'auc': 0.5823906485671192}
# DFS
# 68 {'accuracy': 0.625, 'precision': 0.5932203389830508, 'recall': 0.7, 'f1-score': 0.6422018348623852, 'auc': 0.6277777777777778}
# DFS
# 69 {'accuracy': 0.5588235294117647, 'precision': 0.5952380952380952, 'recall': 0.4716981132075472, 'f1-score': 0.5263157894736842, 'auc': 0.5623796688486716}
# DFS
# 70 {'accuracy': 0.5363636363636364, 'precision': 0.5454545454545454, 'recall': 0.5357142857142857, 'f1-score': 0.5405405405405406, 'auc': 0.5363756613756613}
# DFS
# 71 {'accuracy': 0.4528301886792453, 'precision': 0.36923076923076925, 'recall': 0.5853658536585366, 'f1-score': 0.4528301886792453, 'auc': 0.47729831144465296}
# DFS
# 72 {'accuracy': 0.5514018691588785, 'precision': 0.4444444444444444, 'recall': 0.46511627906976744, 'f1-score': 0.4545454545454546, 'auc': 0.5372456395348837}
# DFS
# 73 {'accuracy': 0.5277777777777778, 'precision': 0.5660377358490566, 'recall': 0.5172413793103449, 'f1-score': 0.5405405405405406, 'auc': 0.5286206896551724}
# DFS
# 74 {'accuracy': 0.4563106796116505, 'precision': 0.42592592592592593, 'recall': 0.4791666666666667, 'f1-score': 0.4509803921568628, 'auc': 0.4577651515151515}
# DFS
# 75 {'accuracy': 0.5740740740740741, 'precision': 0.6363636363636364, 'recall': 0.4827586206896552, 'f1-score': 0.5490196078431373, 'auc': 0.5813793103448276}
# DFS
# 76 {'accuracy': 0.5576923076923077, 'precision': 0.46938775510204084, 'recall': 0.5348837209302325, 'f1-score': 0.5, 'auc': 0.5543271063667556}
# DFS
# 77 {'accuracy': 0.48148148148148145, 'precision': 0.49122807017543857, 'recall': 0.509090909090909, 'f1-score': 0.5, 'auc': 0.48096054888507717}
# DFS
# 78 {'accuracy': 0.5533980582524272, 'precision': 0.5333333333333333, 'recall': 0.4897959183673469, 'f1-score': 0.5106382978723404, 'auc': 0.5504535147392291}
# DFS
# 79 {'accuracy': 0.46601941747572817, 'precision': 0.4745762711864407, 'recall': 0.5384615384615384, 'f1-score': 0.5045045045045046, 'auc': 0.46530920060331826}
# DFS
# 80 {'accuracy': 0.5428571428571428, 'precision': 0.5925925925925926, 'recall': 0.5517241379310345, 'f1-score': 0.5714285714285714, 'auc': 0.5418195157740279}
# DFS
# 81 {'accuracy': 0.48514851485148514, 'precision': 0.5, 'recall': 0.4230769230769231, 'f1-score': 0.4583333333333333, 'auc': 0.4870486656200942}
# DFS
# 82 {'accuracy': 0.6057692307692307, 'precision': 0.5172413793103449, 'recall': 0.6976744186046512, 'f1-score': 0.594059405940594, 'auc': 0.619329012581014}
# DFS
# 83 {'accuracy': 0.5148514851485149, 'precision': 0.4186046511627907, 'recall': 0.42857142857142855, 'f1-score': 0.42352941176470593, 'auc': 0.5024213075060533}
# DFS
# 84 {'accuracy': 0.6095238095238096, 'precision': 0.5476190476190477, 'recall': 0.5111111111111111, 'f1-score': 0.5287356321839081, 'auc': 0.5972222222222222}
# DFS
# 85 {'accuracy': 0.6039603960396039, 'precision': 0.5897435897435898, 'recall': 0.48936170212765956, 'f1-score': 0.5348837209302325, 'auc': 0.5965327029156816}
# DFS
# 86 {'accuracy': 0.4537037037037037, 'precision': 0.4897959183673469, 'recall': 0.41379310344827586, 'f1-score': 0.4485981308411215, 'auc': 0.4568965517241379}
# DFS
# 87 {'accuracy': 0.5339805825242718, 'precision': 0.5306122448979592, 'recall': 0.5098039215686274, 'f1-score': 0.5199999999999999, 'auc': 0.5337481146304676}
# DFS
# 88 {'accuracy': 0.5, 'precision': 0.4375, 'recall': 0.44680851063829785, 'f1-score': 0.4421052631578947, 'auc': 0.494590695997115}
# DFS
# 89 {'accuracy': 0.5742574257425742, 'precision': 0.5208333333333334, 'recall': 0.5555555555555556, 'f1-score': 0.5376344086021506, 'auc': 0.572420634920635}
# DFS
# 90 {'accuracy': 0.44554455445544555, 'precision': 0.4107142857142857, 'recall': 0.5, 'f1-score': 0.45098039215686275, 'auc': 0.45000000000000007}
# DFS
# 91 {'accuracy': 0.6190476190476191, 'precision': 0.6274509803921569, 'recall': 0.6037735849056604, 'f1-score': 0.6153846153846154, 'auc': 0.6191944847605224}
# DFS
# 92 {'accuracy': 0.4909090909090909, 'precision': 0.5098039215686274, 'recall': 0.45614035087719296, 'f1-score': 0.48148148148148145, 'auc': 0.49222111883482295}
# DFS
# 93 {'accuracy': 0.4953271028037383, 'precision': 0.47058823529411764, 'recall': 0.47058823529411764, 'f1-score': 0.47058823529411764, 'auc': 0.4942226890756302}
# DFS
# 94 {'accuracy': 0.5, 'precision': 0.5217391304347826, 'recall': 0.4528301886792453, 'f1-score': 0.4848484848484848, 'auc': 0.5019252984212552}
# DFS
# 95 {'accuracy': 0.5346534653465347, 'precision': 0.6, 'recall': 0.48214285714285715, 'f1-score': 0.5346534653465347, 'auc': 0.5410714285714286}
# DFS
# 96 {'accuracy': 0.5096153846153846, 'precision': 0.4897959183673469, 'recall': 0.48, 'f1-score': 0.48484848484848486, 'auc': 0.5085185185185185}
# DFS
# 97 {'accuracy': 0.5370370370370371, 'precision': 0.5076923076923077, 'recall': 0.6470588235294118, 'f1-score': 0.5689655172413793, 'auc': 0.542827657378741}
# DFS
# 98 {'accuracy': 0.49056603773584906, 'precision': 0.5, 'recall': 0.48148148148148145, 'f1-score': 0.49056603773584906, 'auc': 0.4907407407407407}
# DFS
# 99 {'accuracy': 0.5631067961165048, 'precision': 0.48936170212765956, 'recall': 0.5227272727272727, 'f1-score': 0.5054945054945055, 'auc': 0.5579738058551618}
# DFS
# 100 {'accuracy': 0.52, 'precision': 0.5531914893617021, 'recall': 0.49056603773584906, 'f1-score': 0.52, 'auc': 0.5218787635487756}

# %%
DATA_NUMBER=8
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_IssamDFS') # DFS
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
DFS_results_path = os.path.join(feature_selection_issam,d_name) # feature_selection_results
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
      feature_selection=["with_out_feature_evolving",'DFS_feature_selection'], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : Sudden_Drift.csv ======================
# 0it [00:00, ?it/s]
# DFS
# 1 {'accuracy': 0.9038461538461539, 'precision': 0.9777777777777777, 'recall': 0.8301886792452831, 'f1-score': 0.8979591836734695, 'auc': 0.905290418054014}
# DFS
# 2 {'accuracy': 0.8823529411764706, 'precision': 0.9736842105263158, 'recall': 0.7708333333333334, 'f1-score': 0.8604651162790697, 'auc': 0.8761574074074076}
# DFS
# 3 {'accuracy': 0.8495575221238938, 'precision': 1.0, 'recall': 0.7571428571428571, 'f1-score': 0.8617886178861789, 'auc': 0.8785714285714286}
# DFS
# 4 {'accuracy': 0.9019607843137255, 'precision': 1.0, 'recall': 0.8305084745762712, 'f1-score': 0.9074074074074074, 'auc': 0.9152542372881356}
# DFS
# 5 {'accuracy': 0.8666666666666667, 'precision': 0.9705882352941176, 'recall': 0.717391304347826, 'f1-score': 0.825, 'auc': 0.8502210759027267}
# DFS
# 6 {'accuracy': 0.8921568627450981, 'precision': 0.9565217391304348, 'recall': 0.8301886792452831, 'f1-score': 0.888888888888889, 'auc': 0.8946861763573353}
# DFS
# 7 {'accuracy': 0.9074074074074074, 'precision': 1.0, 'recall': 0.8113207547169812, 'f1-score': 0.8958333333333334, 'auc': 0.9056603773584906}
# DFS
# 8 {'accuracy': 0.8252427184466019, 'precision': 0.9555555555555556, 'recall': 0.7288135593220338, 'f1-score': 0.8269230769230769, 'auc': 0.8416795069337442}
# DFS
# 9 {'accuracy': 0.926605504587156, 'precision': 0.96, 'recall': 0.8888888888888888, 'f1-score': 0.923076923076923, 'auc': 0.9262626262626262}
# DFS
# 10 {'accuracy': 0.9298245614035088, 'precision': 0.9655172413793104, 'recall': 0.9032258064516129, 'f1-score': 0.9333333333333333, 'auc': 0.9323821339950373}
# DFS
# 11 {'accuracy': 0.8773584905660378, 'precision': 0.9767441860465116, 'recall': 0.7777777777777778, 'f1-score': 0.8659793814432991, 'auc': 0.8792735042735041}
# DFS
# 12 {'accuracy': 0.8921568627450981, 'precision': 1.0, 'recall': 0.78, 'f1-score': 0.8764044943820225, 'auc': 0.89}
# DFS
# 13 {'accuracy': 0.8725490196078431, 'precision': 0.975609756097561, 'recall': 0.7692307692307693, 'f1-score': 0.860215053763441, 'auc': 0.8746153846153846}
# DFS
# 14 {'accuracy': 0.8269230769230769, 'precision': 0.975, 'recall': 0.6964285714285714, 'f1-score': 0.8125, 'auc': 0.8377976190476191}
# DFS
# 15 {'accuracy': 0.8857142857142857, 'precision': 0.9523809523809523, 'recall': 0.8, 'f1-score': 0.8695652173913043, 'auc': 0.8818181818181818}
# DFS
# 16 {'accuracy': 0.88, 'precision': 0.9487179487179487, 'recall': 0.7872340425531915, 'f1-score': 0.8604651162790696, 'auc': 0.8747490967482938}
# DFS
# 17 {'accuracy': 0.8921568627450981, 'precision': 0.9782608695652174, 'recall': 0.8181818181818182, 'f1-score': 0.8910891089108911, 'auc': 0.8984526112185688}
# DFS
# 18 {'accuracy': 0.8598130841121495, 'precision': 0.9512195121951219, 'recall': 0.75, 'f1-score': 0.8387096774193549, 'auc': 0.8568181818181818}
# DFS
# 19 {'accuracy': 0.9158878504672897, 'precision': 0.975, 'recall': 0.8297872340425532, 'f1-score': 0.896551724137931, 'auc': 0.9065602836879432}
# DFS
# 20 {'accuracy': 0.8348623853211009, 'precision': 0.9069767441860465, 'recall': 0.7358490566037735, 'f1-score': 0.8124999999999999, 'auc': 0.8322102425876011}
# DFS
# 21 {'accuracy': 0.8932038834951457, 'precision': 0.9534883720930233, 'recall': 0.82, 'f1-score': 0.8817204301075269, 'auc': 0.891132075471698}
# DFS
# 22 {'accuracy': 0.8846153846153846, 'precision': 0.9361702127659575, 'recall': 0.8301886792452831, 'f1-score': 0.88, 'auc': 0.8856825749167591}
# DFS
# 23 {'accuracy': 0.8440366972477065, 'precision': 0.8571428571428571, 'recall': 0.7659574468085106, 'f1-score': 0.8089887640449439, 'auc': 0.8345916266300618}
# DFS
# 24 {'accuracy': 0.883495145631068, 'precision': 0.9761904761904762, 'recall': 0.7884615384615384, 'f1-score': 0.8723404255319148, 'auc': 0.8844268476621416}
# DFS
# 25 {'accuracy': 0.8529411764705882, 'precision': 0.9333333333333333, 'recall': 0.7777777777777778, 'f1-score': 0.8484848484848485, 'auc': 0.8576388888888888}
# DFS
# 26 {'accuracy': 0.8737864077669902, 'precision': 0.9024390243902439, 'recall': 0.8043478260869565, 'f1-score': 0.8505747126436782, 'auc': 0.8670861937452327}
# DFS
# 27 {'accuracy': 0.89, 'precision': 0.9782608695652174, 'recall': 0.8181818181818182, 'f1-score': 0.8910891089108911, 'auc': 0.897979797979798}
# DFS
# 28 {'accuracy': 0.8446601941747572, 'precision': 0.9512195121951219, 'recall': 0.7358490566037735, 'f1-score': 0.8297872340425531, 'auc': 0.8479245283018867}
# DFS
# 29 {'accuracy': 0.8217821782178217, 'precision': 0.875, 'recall': 0.7291666666666666, 'f1-score': 0.7954545454545454, 'auc': 0.8174135220125786}
# DFS
# 30 {'accuracy': 0.8942307692307693, 'precision': 0.9782608695652174, 'recall': 0.8181818181818182, 'f1-score': 0.8910891089108911, 'auc': 0.8988868274582561}
# DFS
# 31 {'accuracy': 0.8490566037735849, 'precision': 0.9111111111111111, 'recall': 0.7735849056603774, 'f1-score': 0.8367346938775511, 'auc': 0.8490566037735849}
# DFS
# 32 {'accuracy': 0.8514851485148515, 'precision': 0.9090909090909091, 'recall': 0.7843137254901961, 'f1-score': 0.8421052631578948, 'auc': 0.852156862745098}
# DFS
# 33 {'accuracy': 0.8529411764705882, 'precision': 0.9487179487179487, 'recall': 0.74, 'f1-score': 0.8314606741573033, 'auc': 0.8507692307692308}
# DFS
# 34 {'accuracy': 0.8666666666666667, 'precision': 0.9772727272727273, 'recall': 0.7678571428571429, 'f1-score': 0.86, 'auc': 0.8737244897959183}
# DFS
# 35 {'accuracy': 0.8461538461538461, 'precision': 0.9523809523809523, 'recall': 0.7407407407407407, 'f1-score': 0.8333333333333334, 'auc': 0.8503703703703703}
# DFS
# 36 {'accuracy': 0.9166666666666666, 'precision': 1.0, 'recall': 0.8448275862068966, 'f1-score': 0.9158878504672897, 'auc': 0.9224137931034483}
# DFS
# 37 {'accuracy': 0.8921568627450981, 'precision': 0.9333333333333333, 'recall': 0.84, 'f1-score': 0.8842105263157894, 'auc': 0.8911538461538461}
# DFS
# 38 {'accuracy': 0.8490566037735849, 'precision': 0.9333333333333333, 'recall': 0.7636363636363637, 'f1-score': 0.84, 'auc': 0.8524064171122995}
# DFS
# 39 {'accuracy': 0.8691588785046729, 'precision': 0.9555555555555556, 'recall': 0.7818181818181819, 'f1-score': 0.86, 'auc': 0.8716783216783217}
# DFS
# 40 {'accuracy': 0.8942307692307693, 'precision': 0.9629629629629629, 'recall': 0.8524590163934426, 'f1-score': 0.9043478260869565, 'auc': 0.902973694243233}
# DFS
# 41 {'accuracy': 0.9065420560747663, 'precision': 0.94, 'recall': 0.8703703703703703, 'f1-score': 0.9038461538461539, 'auc': 0.9068832983927323}
# DFS
# 42 {'accuracy': 0.8846153846153846, 'precision': 0.9782608695652174, 'recall': 0.8035714285714286, 'f1-score': 0.8823529411764706, 'auc': 0.8913690476190476}
# DFS
# 43 {'accuracy': 0.8611111111111112, 'precision': 0.9375, 'recall': 0.7894736842105263, 'f1-score': 0.8571428571428572, 'auc': 0.8653250773993808}
# DFS
# 44 {'accuracy': 0.8365384615384616, 'precision': 0.975609756097561, 'recall': 0.7142857142857143, 'f1-score': 0.8247422680412371, 'auc': 0.8467261904761905}
# DFS
# 45 {'accuracy': 0.8514851485148515, 'precision': 0.8636363636363636, 'recall': 0.8085106382978723, 'f1-score': 0.8351648351648351, 'auc': 0.8486997635933805}
# DFS
# 46 {'accuracy': 0.7843137254901961, 'precision': 0.8823529411764706, 'recall': 0.625, 'f1-score': 0.7317073170731708, 'auc': 0.7754629629629629}
# DFS
# 47 {'accuracy': 0.9142857142857143, 'precision': 1.0, 'recall': 0.8269230769230769, 'f1-score': 0.9052631578947368, 'auc': 0.9134615384615384}
# DFS
# 48 {'accuracy': 0.8828828828828829, 'precision': 0.9285714285714286, 'recall': 0.7959183673469388, 'f1-score': 0.8571428571428572, 'auc': 0.8737656352863727}
# DFS
# 49 {'accuracy': 0.8415841584158416, 'precision': 0.9056603773584906, 'recall': 0.8135593220338984, 'f1-score': 0.8571428571428572, 'auc': 0.8472558514931395}
# DFS
# 50 {'accuracy': 0.8921568627450981, 'precision': 0.9545454545454546, 'recall': 0.8235294117647058, 'f1-score': 0.8842105263157896, 'auc': 0.8921568627450981}
# DFS
# 51 {'accuracy': 0.8712871287128713, 'precision': 1.0, 'recall': 0.7346938775510204, 'f1-score': 0.8470588235294119, 'auc': 0.8673469387755102}
# DFS
# 52 {'accuracy': 0.9134615384615384, 'precision': 0.9183673469387755, 'recall': 0.9, 'f1-score': 0.9090909090909091, 'auc': 0.9129629629629629}
# DFS
# 53 {'accuracy': 0.8285714285714286, 'precision': 0.9230769230769231, 'recall': 0.7058823529411765, 'f1-score': 0.8000000000000002, 'auc': 0.8251633986928105}
# DFS
# 54 {'accuracy': 0.8785046728971962, 'precision': 0.9, 'recall': 0.8490566037735849, 'f1-score': 0.8737864077669903, 'auc': 0.8782320055904963}
# DFS
# 55 {'accuracy': 0.8446601941747572, 'precision': 0.8888888888888888, 'recall': 0.7843137254901961, 'f1-score': 0.8333333333333334, 'auc': 0.8440799396681749}
# DFS
# 56 {'accuracy': 0.8235294117647058, 'precision': 0.926829268292683, 'recall': 0.7169811320754716, 'f1-score': 0.8085106382978724, 'auc': 0.8278783211397767}
# DFS
# 57 {'accuracy': 0.912621359223301, 'precision': 0.9772727272727273, 'recall': 0.8431372549019608, 'f1-score': 0.9052631578947369, 'auc': 0.9119532428355958}
# DFS
# 58 {'accuracy': 0.8640776699029126, 'precision': 0.9583333333333334, 'recall': 0.7931034482758621, 'f1-score': 0.8679245283018867, 'auc': 0.8743295019157088}
# DFS
# 59 {'accuracy': 0.8598130841121495, 'precision': 0.9361702127659575, 'recall': 0.7857142857142857, 'f1-score': 0.854368932038835, 'auc': 0.8634453781512604}
# DFS
# 60 {'accuracy': 0.8796296296296297, 'precision': 0.9142857142857143, 'recall': 0.7619047619047619, 'f1-score': 0.8311688311688312, 'auc': 0.8582251082251082}
# DFS
# 61 {'accuracy': 0.9019607843137255, 'precision': 0.975, 'recall': 0.8125, 'f1-score': 0.8863636363636362, 'auc': 0.8969907407407408}
# DFS
# 62 {'accuracy': 0.8952380952380953, 'precision': 0.9743589743589743, 'recall': 0.7916666666666666, 'f1-score': 0.8735632183908045, 'auc': 0.8870614035087718}
# DFS
# 63 {'accuracy': 0.8529411764705882, 'precision': 0.8958333333333334, 'recall': 0.8113207547169812, 'f1-score': 0.8514851485148515, 'auc': 0.8546399691952252}
# DFS
# 64 {'accuracy': 0.8921568627450981, 'precision': 0.9787234042553191, 'recall': 0.8214285714285714, 'f1-score': 0.8932038834951456, 'auc': 0.8998447204968943}
# DFS
# 65 {'accuracy': 0.8712871287128713, 'precision': 0.9069767441860465, 'recall': 0.8125, 'f1-score': 0.8571428571428572, 'auc': 0.8685141509433962}
# DFS
# 66 {'accuracy': 0.8648648648648649, 'precision': 0.975, 'recall': 0.7358490566037735, 'f1-score': 0.8387096774193549, 'auc': 0.8593038386467144}
# DFS
# 67 {'accuracy': 0.8653846153846154, 'precision': 0.9166666666666666, 'recall': 0.8148148148148148, 'f1-score': 0.8627450980392156, 'auc': 0.8674074074074075}
# DFS
# 68 {'accuracy': 0.8557692307692307, 'precision': 0.9743589743589743, 'recall': 0.7307692307692307, 'f1-score': 0.8351648351648352, 'auc': 0.8557692307692307}
# DFS
# 69 {'accuracy': 0.9345794392523364, 'precision': 0.975, 'recall': 0.8666666666666667, 'f1-score': 0.9176470588235294, 'auc': 0.9252688172043011}
# DFS
# 70 {'accuracy': 0.8446601941747572, 'precision': 0.9534883720930233, 'recall': 0.7454545454545455, 'f1-score': 0.8367346938775511, 'auc': 0.8518939393939394}
# DFS
# 71 {'accuracy': 0.8235294117647058, 'precision': 0.8043478260869565, 'recall': 0.8043478260869565, 'f1-score': 0.8043478260869565, 'auc': 0.8218167701863355}
# DFS
# 72 {'accuracy': 0.900990099009901, 'precision': 0.9772727272727273, 'recall': 0.8269230769230769, 'f1-score': 0.8958333333333334, 'auc': 0.9032574568288854}
# DFS
# 73 {'accuracy': 0.8598130841121495, 'precision': 0.9069767441860465, 'recall': 0.78, 'f1-score': 0.8387096774193548, 'auc': 0.8549122807017544}
# DFS
# 74 {'accuracy': 0.822429906542056, 'precision': 0.8863636363636364, 'recall': 0.7358490566037735, 'f1-score': 0.8041237113402062, 'auc': 0.8216282320055905}
# DFS
# 75 {'accuracy': 0.8543689320388349, 'precision': 0.9565217391304348, 'recall': 0.7719298245614035, 'f1-score': 0.8543689320388349, 'auc': 0.8642257818459191}
# DFS
# 76 {'accuracy': 0.85, 'precision': 0.926829268292683, 'recall': 0.76, 'f1-score': 0.8351648351648352, 'auc': 0.85}
# DFS
# 77 {'accuracy': 0.8611111111111112, 'precision': 0.9166666666666666, 'recall': 0.7333333333333333, 'f1-score': 0.8148148148148148, 'auc': 0.8428571428571429}
# DFS
# 78 {'accuracy': 0.8349514563106796, 'precision': 0.9761904761904762, 'recall': 0.7192982456140351, 'f1-score': 0.8282828282828282, 'auc': 0.8487795575896262}
# DFS
# 79 {'accuracy': 0.8666666666666667, 'precision': 0.8863636363636364, 'recall': 0.8125, 'f1-score': 0.8478260869565218, 'auc': 0.862390350877193}
# DFS
# 80 {'accuracy': 0.9134615384615384, 'precision': 0.9137931034482759, 'recall': 0.9298245614035088, 'f1-score': 0.9217391304347825, 'auc': 0.9117207913400522}
# DFS
# 81 {'accuracy': 0.8725490196078431, 'precision': 0.9024390243902439, 'recall': 0.8043478260869565, 'f1-score': 0.8505747126436782, 'auc': 0.8664596273291926}
# DFS
# 82 {'accuracy': 0.8823529411764706, 'precision': 0.975609756097561, 'recall': 0.7843137254901961, 'f1-score': 0.8695652173913043, 'auc': 0.8823529411764706}
# DFS
# 83 {'accuracy': 0.8514851485148515, 'precision': 0.9, 'recall': 0.7659574468085106, 'f1-score': 0.8275862068965516, 'auc': 0.8459416863672183}
# DFS
# 84 {'accuracy': 0.9056603773584906, 'precision': 0.9333333333333333, 'recall': 0.8571428571428571, 'f1-score': 0.8936170212765957, 'auc': 0.9022556390977445}
# DFS
# 85 {'accuracy': 0.8461538461538461, 'precision': 0.9285714285714286, 'recall': 0.75, 'f1-score': 0.8297872340425532, 'auc': 0.8461538461538461}
# DFS
# 86 {'accuracy': 0.8737864077669902, 'precision': 0.9069767441860465, 'recall': 0.8125, 'f1-score': 0.8571428571428572, 'auc': 0.8698863636363636}
# DFS
# 87 {'accuracy': 0.7941176470588235, 'precision': 0.875, 'recall': 0.6862745098039216, 'f1-score': 0.7692307692307692, 'auc': 0.7941176470588235}
# DFS
# 88 {'accuracy': 0.900990099009901, 'precision': 0.9444444444444444, 'recall': 0.8095238095238095, 'f1-score': 0.8717948717948718, 'auc': 0.8878127522195319}
# DFS
# 89 {'accuracy': 0.81, 'precision': 0.8409090909090909, 'recall': 0.7551020408163265, 'f1-score': 0.7956989247311828, 'auc': 0.8089235694277712}
# DFS
# 90 {'accuracy': 0.8476190476190476, 'precision': 0.9285714285714286, 'recall': 0.75, 'f1-score': 0.8297872340425532, 'auc': 0.8466981132075472}
# DFS
# 91 {'accuracy': 0.8627450980392157, 'precision': 0.9285714285714286, 'recall': 0.78, 'f1-score': 0.8478260869565217, 'auc': 0.8611538461538462}
# DFS
# 92 {'accuracy': 0.9056603773584906, 'precision': 1.0, 'recall': 0.7959183673469388, 'f1-score': 0.8863636363636364, 'auc': 0.8979591836734694}
# DFS
# 93 {'accuracy': 0.8942307692307693, 'precision': 0.8823529411764706, 'recall': 0.9, 'f1-score': 0.8910891089108911, 'auc': 0.8944444444444444}
# DFS
# 94 {'accuracy': 0.883495145631068, 'precision': 0.9285714285714286, 'recall': 0.8125, 'f1-score': 0.8666666666666666, 'auc': 0.8789772727272728}
# DFS
# 95 {'accuracy': 0.8921568627450981, 'precision': 0.8979591836734694, 'recall': 0.88, 'f1-score': 0.888888888888889, 'auc': 0.8919230769230768}
# DFS
# 96 {'accuracy': 0.9313725490196079, 'precision': 0.9523809523809523, 'recall': 0.8888888888888888, 'f1-score': 0.9195402298850575, 'auc': 0.9269005847953217}
# DFS
# 97 {'accuracy': 0.8761904761904762, 'precision': 0.9565217391304348, 'recall': 0.8, 'f1-score': 0.8712871287128713, 'auc': 0.88}
# DFS
# 98 {'accuracy': 0.8543689320388349, 'precision': 0.9772727272727273, 'recall': 0.7543859649122807, 'f1-score': 0.8514851485148516, 'auc': 0.8663234172387492}
# DFS
# 99 {'accuracy': 0.9, 'precision': 0.9523809523809523, 'recall': 0.8333333333333334, 'f1-score': 0.888888888888889, 'auc': 0.8974358974358976}
# DFS
# 100 {'accuracy': 0.875, 'precision': 0.96, 'recall': 0.8135593220338984, 'f1-score': 0.8807339449541285, 'auc': 0.884557438794727}
