# %%
# !pip install -q scikit-multiflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.6/450.6 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-multiflow (setup.py) ... done

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from skmultiflow.drift_detection import ADWIN, DDM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from matplotlib.colors import ListedColormap
from multiprocessing.pool import ThreadPool
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle
from contextlib import suppress
from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from random import shuffle
import seaborn as sns
from time import time
import pandas as pd
import numpy as np
import warnings
import scipy.io
import pickle
import sys
import gc
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/data'
code_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Codes/Shared Codes'
results_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Results'
feature_selection_results = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_results'
sys.path.insert(0,code_path)
from oselm import set_use_know
from SharedFunctions import main,generate_oselm_models

# %%
filenames = ['kddcup99_csv.csv','ISCX2012.csv','CSE-CIC2018.csv','CICIDS2017.csv','7recurrentDrift.csv', 'blip.csv', 'incrementalDrift.csv',
             '7gradualDrift.csv', '7suddenDrift.csv']
filenames = list(map(lambda x: os.path.join(data_path, x), filenames))

# %%
data_name = ['kddcup99','ISCX2012','CSE-CIC2018','CICIDS2017','7recurrentDrift', 'blip', 'incrementalDrift','7gradualDrift', '7suddenDrift']

# %%
# # use_know = True
# # set_use_know(use_know)
# # path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_random_forest')
# # os.makedirs(path, exist_ok=True)
# # for f_name,d_name in zip(filenames,data_name):
# #   main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
# #        feature_selection=["feature_evolving",'random_forest'], result_save_path=path)

# %%
DATA_NUMBER=0
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : kddcup99_csv.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.9897370109044259, 'precision': 0.9975339087546239, 'recall': 0.982989064398542, 'f1-score': 0.9902080783353734, 'auc': 0.9901358365470971}
# Evolving RandomForest
#   0%|          | 0/6265 [00:00<?, ?it/s]
# 2 {'accuracy': 0.9272495213784301, 'precision': 0.8843457943925234, 'recall': 0.9805699481865285, 'f1-score': 0.92997542997543, 'auc': 0.928020823149868}
# Evolving RandomForest
#   0%|          | 0/6268 [00:00<?, ?it/s]
# 3 {'accuracy': 0.9534438775510204, 'precision': 0.9177927927927928, 'recall': 1.0, 'f1-score': 0.9571344685848503, 'auc': 0.9515272244355909}
# Evolving RandomForest
#   0%|          | 0/6300 [00:00<?, ?it/s]
# 4 {'accuracy': 0.9270304568527918, 'precision': 0.8797814207650273, 'recall': 0.9938271604938271, 'f1-score': 0.9333333333333333, 'auc': 0.9251120136672791}
# Evolving RandomForest
#   0%|          | 0/6283 [00:00<?, ?it/s]
# 5 {'accuracy': 0.8535964353914705, 'precision': 1.0, 'recall': 0.7009102730819246, 'f1-score': 0.8241590214067278, 'auc': 0.8504551365409623}
# Evolving RandomForest
#   0%|          | 0/6332 [00:00<?, ?it/s]
# 6 {'accuracy': 0.5505050505050505, 'precision': 0.5204359673024523, 'recall': 0.9896373056994818, 'f1-score': 0.6821428571428572, 'auc': 0.5613211159039281}
# Evolving RandomForest
#   0%|          | 0/6284 [00:00<?, ?it/s]
# 7 {'accuracy': 0.5127226463104325, 'precision': 0.3333333333333333, 'recall': 0.002617801047120419, 'f1-score': 0.005194805194805196, 'auc': 0.4988336529988078}
# Evolving RandomForest
#   0%|          | 0/6316 [00:00<?, ?it/s]
# 8 {'accuracy': 0.9930379746835443, 'precision': 1.0, 'recall': 0.986335403726708, 'f1-score': 0.9931207004377736, 'auc': 0.993167701863354}
# Evolving RandomForest
#   0%|          | 0/6313 [00:00<?, ?it/s]
# 9 {'accuracy': 0.9487017099430018, 'precision': 0.9205069124423964, 'recall': 0.9852034525277436, 'f1-score': 0.9517569982132222, 'auc': 0.9476798512638718}
# Evolving RandomForest
#   0%|          | 0/6232 [00:00<?, ?it/s]
# 10 {'accuracy': 0.9608472400513479, 'precision': 0.96, 'recall': 0.9612403100775194, 'f1-score': 0.960619754680439, 'auc': 0.9608497468754944}

# %%
DATA_NUMBER=1
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : ISCX2012.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.5270354257302673, 'precision': 0.6666666666666666, 'recall': 0.01045751633986928, 'f1-score': 0.02059202059202059, 'auc': 0.502859089923489}
# Evolving RandomForest
#   0%|          | 0/6414 [00:00<?, ?it/s]
# 2 {'accuracy': 0.48815461346633415, 'precision': 0.9166666666666666, 'recall': 0.013237063778580024, 'f1-score': 0.02609727164887307, 'auc': 0.5059717013588889}
# Evolving RandomForest
#   0%|          | 0/6403 [00:00<?, ?it/s]
# 3 {'accuracy': 0.6683322923173017, 'precision': 1.0, 'recall': 0.3252858958068615, 'f1-score': 0.49089165867689355, 'auc': 0.6626429479034308}
# Evolving RandomForest
#   0%|          | 0/6432 [00:00<?, ?it/s]
# 4 {'accuracy': 0.585820895522388, 'precision': 0.972972972972973, 'recall': 0.17866004962779156, 'f1-score': 0.3018867924528302, 'auc': 0.5868362592278609}
# Evolving RandomForest
#   0%|          | 0/6406 [00:00<?, ?it/s]
# 5 {'accuracy': 0.6161048689138576, 'precision': 0.9941520467836257, 'recall': 0.21683673469387754, 'f1-score': 0.356020942408377, 'auc': 0.6078071204031735}
# Evolving RandomForest
#   0%|          | 0/6414 [00:00<?, ?it/s]
# 6 {'accuracy': 0.5031172069825436, 'precision': 1.0, 'recall': 0.008706467661691543, 'f1-score': 0.017262638717632554, 'auc': 0.5043532338308457}
# Evolving RandomForest
#   0%|          | 0/6420 [00:00<?, ?it/s]
# 7 {'accuracy': 0.5149439601494396, 'precision': 1.0, 'recall': 0.007643312101910828, 'f1-score': 0.015170670037926675, 'auc': 0.5038216560509554}
# Evolving RandomForest
#   0%|          | 0/6406 [00:00<?, ?it/s]
# 8 {'accuracy': 0.5081148564294632, 'precision': 1.0, 'recall': 0.00880503144654088, 'f1-score': 0.017456359102244388, 'auc': 0.5044025157232704}
# Evolving RandomForest
#   0%|          | 0/6510 [00:00<?, ?it/s]
# 9 {'accuracy': 0.5018427518427518, 'precision': 1.0, 'recall': 0.012180267965895249, 'f1-score': 0.024067388688327314, 'auc': 0.5060901339829477}
# Evolving RandomForest
#   0%|          | 0/6497 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 10 {'accuracy': 0.4916923076923077, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'auc': 0.5}

# %%
DATA_NUMBER=2
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CSE-CIC2018.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 0.5}
# Evolving RandomForest
#   0%|          | 0/6400 [00:00<?, ?it/s]
# 2 {'accuracy': 0.99875, 'precision': 0.9993746091307066, 'recall': 0.9993746091307066, 'f1-score': 0.9993746091307066, 'auc': 0.4996873045653533}
# Evolving RandomForest
#   0%|          | 0/12777 [00:00<?, ?it/s]
# 3 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving RandomForest
#   0%|          | 0/12776 [00:00<?, ?it/s]
# 4 {'accuracy': 0.6324358171571697, 'precision': 0.5746376811594203, 'recall': 1.0, 'f1-score': 0.7298665439484583, 'auc': 0.6349502487562189}
# Evolving RandomForest
#   0%|          | 0/12771 [00:00<?, ?it/s]
# 5 {'accuracy': 0.9981208894456624, 'precision': 0.9962025316455696, 'recall': 1.0, 'f1-score': 0.9980976537729866, 'auc': 0.9981470043236566}
# Evolving RandomForest
#   0%|          | 0/12785 [00:00<?, ?it/s]
# 6 {'accuracy': 0.8658116984673131, 'precision': 0.7861415752741775, 'recall': 1.0, 'f1-score': 0.880267931900642, 'auc': 0.8675925925925926}
# Evolving RandomForest
#   0%|          | 0/12787 [00:00<?, ?it/s]
# 7 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving RandomForest
#   0%|          | 0/12782 [00:00<?, ?it/s]
# 8 {'accuracy': 0.9274092615769712, 'precision': 1.0, 'recall': 0.85297845373891, 'f1-score': 0.920656634746922, 'auc': 0.926489226869455}
# Evolving RandomForest
#   0%|          | 0/12769 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 9 {'accuracy': 0.508612590040714, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'auc': 0.5}
# Evolving RandomForest
#   0%|          | 0/12788 [00:00<?, ?it/s]
# 10 {'accuracy': 0.8214509068167605, 'precision': 0.733177570093458, 'recall': 1.0, 'f1-score': 0.8460501482879482, 'auc': 0.8247391037446286}

# %%
DATA_NUMBER=3
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CICIDS2017.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.9499174463401211, 'precision': 0.9554513481828839, 'recall': 0.9389400921658986, 'f1-score': 0.94712376525276, 'auc': 0.9494489712673541}
# Evolving RandomForest
#   0%|          | 0/7179 [00:00<?, ?it/s]
# 2 {'accuracy': 0.8629526462395544, 'precision': 0.8336734693877551, 'recall': 0.9077777777777778, 'f1-score': 0.8691489361702127, 'auc': 0.8628274363749224}
# Evolving RandomForest
#   0%|          | 0/7209 [00:00<?, ?it/s]
# 3 {'accuracy': 0.8740987243483084, 'precision': 0.8079646017699115, 'recall': 0.9891657638136512, 'f1-score': 0.8894301022893326, 'auc': 0.8712874273613711}
# Evolving RandomForest
#   0%|          | 0/7230 [00:00<?, ?it/s]
# 4 {'accuracy': 0.519358407079646, 'precision': 0.4990892531876138, 'recall': 0.6320645905420992, 'f1-score': 0.5577608142493639, 'auc': 0.5237899998406563}
# Evolving RandomForest
#   0%|          | 0/7392 [00:00<?, ?it/s]
# 5 {'accuracy': 0.7965367965367965, 'precision': 0.7095274980635167, 'recall': 0.9989094874591058, 'f1-score': 0.8297101449275363, 'auc': 0.7980583957166635}
# Evolving RandomForest
#   0%|          | 0/7169 [00:00<?, ?it/s]
# 6 {'accuracy': 0.8220858895705522, 'precision': 0.9524539877300614, 'recall': 0.6831683168316832, 'f1-score': 0.7956438180653428, 'auc': 0.8240502217642579}
# Evolving RandomForest
#   0%|          | 0/7110 [00:00<?, ?it/s]
# 7 {'accuracy': 0.7581552305961755, 'precision': 0.8522388059701492, 'recall': 0.6330376940133038, 'f1-score': 0.7264631043256997, 'auc': 0.7600119976915833}
# Evolving RandomForest
#   0%|          | 0/7128 [00:00<?, ?it/s]
# 8 {'accuracy': 0.5836139169472503, 'precision': 0.6024258760107817, 'recall': 0.5, 'f1-score': 0.5464547677261614, 'auc': 0.5838963963963965}
# Evolving RandomForest
#   0%|          | 0/7099 [00:00<?, ?it/s]
# 9 {'accuracy': 0.5594366197183098, 'precision': 0.5340236686390533, 'recall': 0.8260869565217391, 'f1-score': 0.6486972147349507, 'auc': 0.5634319355305699}
# Evolving RandomForest
#   0%|          | 0/7118 [00:00<?, ?it/s]
# 10 {'accuracy': 0.5174157303370787, 'precision': 0.511123787792356, 'recall': 0.9977728285077951, 'f1-score': 0.6759713315729914, 'auc': 0.5130587498548046}

# %%
DATA_NUMBER=4
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7recurrentDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.7455108359133127, 'precision': 0.7426900584795322, 'recall': 0.7687651331719129, 'f1-score': 0.7555026769779893, 'auc': 0.744965583062509}
# Evolving RandomForest
#   0%|          | 0/6496 [00:00<?, ?it/s]
# 2 {'accuracy': 0.7475369458128078, 'precision': 0.7525773195876289, 'recall': 0.7720329024676851, 'f1-score': 0.7621809744779583, 'auc': 0.746301056667219}
# Evolving RandomForest
#   0%|          | 0/6456 [00:00<?, ?it/s]
# 3 {'accuracy': 0.7224287484510533, 'precision': 0.7435567010309279, 'recall': 0.698547215496368, 'f1-score': 0.7203495630461924, 'auc': 0.723004572215189}
# Evolving RandomForest
#   0%|          | 0/6516 [00:00<?, ?it/s]
# 4 {'accuracy': 0.7196319018404908, 'precision': 0.7093425605536332, 'recall': 0.75, 'f1-score': 0.7291049199762892, 'auc': 0.7194444444444444}
# Evolving RandomForest
#   0%|          | 0/6427 [00:00<?, ?it/s]
# 5 {'accuracy': 0.7199751088985687, 'precision': 0.7194835680751174, 'recall': 0.7439320388349514, 'f1-score': 0.7315035799522672, 'auc': 0.7193478840407196}
# Evolving RandomForest
#   0%|          | 0/6446 [00:00<?, ?it/s]
# 6 {'accuracy': 0.7369727047146402, 'precision': 0.7426829268292683, 'recall': 0.7408759124087592, 'f1-score': 0.7417783191230207, 'auc': 0.7368936524069112}
# Evolving RandomForest
#   0%|          | 0/6401 [00:00<?, ?it/s]
# 7 {'accuracy': 0.7183010618363522, 'precision': 0.7158018867924528, 'recall': 0.7429620563035496, 'f1-score': 0.7291291291291292, 'auc': 0.717782048559938}
# Evolving RandomForest
#   0%|          | 0/6480 [00:00<?, ?it/s]
# 8 {'accuracy': 0.5666666666666667, 'precision': 0.5615141955835962, 'recall': 0.652014652014652, 'f1-score': 0.6033898305084746, 'auc': 0.5657077005391611}
# Evolving RandomForest
#   0%|          | 0/6540 [00:00<?, ?it/s]
# 9 {'accuracy': 0.5152811735941321, 'precision': 0.5389876880984952, 'recall': 0.46352941176470586, 'f1-score': 0.49841872232764073, 'auc': 0.517388115551564}
# Evolving RandomForest
#   0%|          | 0/6465 [00:00<?, ?it/s]
# 10 {'accuracy': 0.6326530612244898, 'precision': 0.589516129032258, 'recall': 0.8958333333333334, 'f1-score': 0.711089494163424, 'auc': 0.6301888264669164}

# %%
DATA_NUMBER=5
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : blip.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.5153340635268346, 'precision': 0.5367847411444142, 'recall': 0.41959531416400425, 'f1-score': 0.4710101613867304, 'auc': 0.5181403853796346}
# Evolving RandomForest
#   0%|          | 0/7195 [00:00<?, ?it/s]
# 2 {'accuracy': 0.4936075597554197, 'precision': 0.4920541494997057, 'recall': 0.9457013574660633, 'f1-score': 0.6473093302361596, 'auc': 0.5012659792794798}
# Evolving RandomForest
#   0%|          | 0/7267 [00:00<?, ?it/s]
# 3 {'accuracy': 0.4881673087506879, 'precision': 0.4877913429522753, 'recall': 0.9920993227990971, 'f1-score': 0.6540178571428571, 'auc': 0.5003461168238235}
# Evolving RandomForest
#   0%|          | 0/7350 [00:00<?, ?it/s]
# 4 {'accuracy': 0.5108813928182807, 'precision': 0.5144092219020173, 'recall': 0.38846572361262244, 'f1-score': 0.4426534407935524, 'auc': 0.5108813928182807}
# Evolving RandomForest
#   0%|          | 0/7297 [00:00<?, ?it/s]
# 5 {'accuracy': 0.4986301369863014, 'precision': 0.5099337748344371, 'recall': 0.08387799564270153, 'f1-score': 0.14405986903648269, 'auc': 0.5011451720220123}
# Evolving RandomForest
#   0%|          | 0/7363 [00:00<?, ?it/s]
# 6 {'accuracy': 0.4823465507876154, 'precision': 0.48622589531680444, 'recall': 0.3783494105037513, 'f1-score': 0.4255575647980711, 'auc': 0.4837782294809505}
# Evolving RandomForest
#   0%|          | 0/7188 [00:00<?, ?it/s]
# 7 {'accuracy': 0.5050055617352615, 'precision': 0.611764705882353, 'recall': 0.05720572057205721, 'f1-score': 0.1046277665995976, 'auc': 0.5100426803085258}
# Evolving RandomForest
#   0%|          | 0/7363 [00:00<?, ?it/s]
# 8 {'accuracy': 0.5024443237370994, 'precision': 0.524390243902439, 'recall': 0.04673913043478261, 'f1-score': 0.08582834331337326, 'auc': 0.5021969267809092}
# Evolving RandomForest
#   0%|          | 0/7310 [00:00<?, ?it/s]
# 9 {'accuracy': 0.5098468271334792, 'precision': 0.5588235294117647, 'recall': 0.021111111111111112, 'f1-score': 0.04068522483940043, 'auc': 0.5024736590038315}
# Evolving RandomForest
#   0%|          | 0/7224 [00:00<?, ?it/s]
# 10 {'accuracy': 0.48781838316722037, 'precision': 0.47333333333333333, 'recall': 0.3180291153415454, 'f1-score': 0.3804420629604823, 'auc': 0.4859586978679249}

# %%
DATA_NUMBER=6
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : incrementalDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.7349472377405338, 'precision': 0.7547892720306514, 'recall': 0.715496368038741, 'f1-score': 0.7346177750155377, 'auc': 0.7354551903887973}
# Evolving RandomForest
#   0%|          | 0/6457 [00:00<?, ?it/s]
# 2 {'accuracy': 0.7430340557275542, 'precision': 0.7759067357512953, 'recall': 0.7122473246135553, 'f1-score': 0.7427154370737756, 'auc': 0.7443665563636251}
# Evolving RandomForest
#   0%|          | 0/6448 [00:00<?, ?it/s]
# 3 {'accuracy': 0.5700992555831266, 'precision': 0.5395894428152492, 'recall': 0.7131782945736435, 'f1-score': 0.6143572621035058, 'auc': 0.5755628943035282}
# Evolving RandomForest
#   0%|          | 0/6419 [00:00<?, ?it/s]
# 4 {'accuracy': 0.5657320872274143, 'precision': 0.5492385786802031, 'recall': 0.681360201511335, 'f1-score': 0.6082068577852727, 'auc': 0.5669439725189227}
# Evolving RandomForest
#   0%|          | 0/6404 [00:00<?, ?it/s]
# 5 {'accuracy': 0.7109862671660424, 'precision': 0.7063882063882064, 'recall': 0.7196495619524406, 'f1-score': 0.712957222566646, 'auc': 0.7110078444880509}
# Evolving RandomForest
#   0%|          | 0/6409 [00:00<?, ?it/s]
# 6 {'accuracy': 0.5957579538365565, 'precision': 0.5865384615384616, 'recall': 0.6777777777777778, 'f1-score': 0.6288659793814434, 'auc': 0.5948788006165056}
# Evolving RandomForest
#   0%|          | 0/6465 [00:00<?, ?it/s]
# 7 {'accuracy': 0.5825602968460112, 'precision': 0.587027027027027, 'recall': 0.6495215311004785, 'f1-score': 0.616695059625213, 'auc': 0.5802025069074735}
# Evolving RandomForest
#   0%|          | 0/6470 [00:00<?, ?it/s]
# 8 {'accuracy': 0.5599505562422744, 'precision': 0.556923076923077, 'recall': 0.6597812879708383, 'f1-score': 0.6040044493882091, 'auc': 0.558192530777872}
# Evolving RandomForest
#   0%|          | 0/6406 [00:00<?, ?it/s]
# 9 {'accuracy': 0.5599250936329588, 'precision': 0.5449790794979079, 'recall': 0.6586599241466498, 'f1-score': 0.596451058958214, 'auc': 0.5611425391386763}
# Evolving RandomForest
#   0%|          | 0/6473 [00:00<?, ?it/s]
# 10 {'accuracy': 0.6244595429277332, 'precision': 0.5958668197474167, 'recall': 0.6696774193548387, 'f1-score': 0.6306196840826245, 'auc': 0.6263079039902155}

# %%
DATA_NUMBER=7
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7gradualDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.6394891944990176, 'precision': 0.609375, 'recall': 0.7692307692307693, 'f1-score': 0.6800348735832608, 'auc': 0.6399969893120578}
# Evolving RandomForest
#   0%|          | 0/8080 [00:00<?, ?it/s]
# 2 {'accuracy': 0.699009900990099, 'precision': 0.699711260827719, 'recall': 0.7106549364613881, 'f1-score': 0.7051406401551891, 'auc': 0.69885806000602}
# Evolving RandomForest
#   0%|          | 0/8099 [00:00<?, ?it/s]
# 3 {'accuracy': 0.6434567901234568, 'precision': 0.6133333333333333, 'recall': 0.7734915924826904, 'f1-score': 0.68416447944007, 'auc': 0.6436491492985444}
# Evolving RandomForest
#   0%|          | 0/8073 [00:00<?, ?it/s]
# 4 {'accuracy': 0.7057949479940565, 'precision': 0.6984417965169569, 'recall': 0.7419668938656281, 'f1-score': 0.7195467422096318, 'auc': 0.7051568340295882}
# Evolving RandomForest
#   0%|          | 0/8065 [00:00<?, ?it/s]
# 5 {'accuracy': 0.7129400099157164, 'precision': 0.7285291214215203, 'recall': 0.708253358925144, 'f1-score': 0.7182481751824819, 'auc': 0.713101038436931}
# Evolving RandomForest
#   0%|          | 0/8040 [00:00<?, ?it/s]
# 6 {'accuracy': 0.7029850746268657, 'precision': 0.6967294350842418, 'recall': 0.7072434607645876, 'f1-score': 0.7019470793809286, 'auc': 0.7030311792011913}
# Evolving RandomForest
#   0%|          | 0/8220 [00:00<?, ?it/s]
# 7 {'accuracy': 0.7013618677042801, 'precision': 0.6992337164750958, 'recall': 0.7087378640776699, 'f1-score': 0.703953712632594, 'auc': 0.7013474895437082}
# Evolving RandomForest
#   0%|          | 0/8102 [00:00<?, ?it/s]
# 8 {'accuracy': 0.6396841066140178, 'precision': 0.6028075970272502, 'recall': 0.745658835546476, 'f1-score': 0.6666666666666666, 'auc': 0.6431255018229037}
# Evolving RandomForest
#   0%|          | 0/8142 [00:00<?, ?it/s]
# 9 {'accuracy': 0.6429273084479371, 'precision': 0.628, 'recall': 0.7497612225405922, 'f1-score': 0.6835002176752285, 'auc': 0.6397946658709027}
# Evolving RandomForest
#   0%|          | 0/8128 [00:00<?, ?it/s]
# 10 {'accuracy': 0.6515748031496063, 'precision': 0.636, 'recall': 0.7585877862595419, 'f1-score': 0.6919060052219321, 'auc': 0.648094706137901}

# %%
DATA_NUMBER=8
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7suddenDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.6246290801186943, 'precision': 0.5782575173477256, 'recall': 0.7796257796257796, 'f1-score': 0.6640106241699868, 'auc': 0.6317940218883615}
# Evolving RandomForest
#   0%|          | 0/8049 [00:00<?, ?it/s]
# 2 {'accuracy': 0.7059115747640338, 'precision': 0.7190332326283988, 'recall': 0.6952288218111002, 'f1-score': 0.7069306930693069, 'auc': 0.7061336806824263}
# Evolving RandomForest
#   0%|          | 0/8016 [00:00<?, ?it/s]
# 3 {'accuracy': 0.6551896207584831, 'precision': 0.634375, 'recall': 0.7845410628019324, 'f1-score': 0.701511879049676, 'auc': 0.6507844632895111}
# Evolving RandomForest
#   0%|          | 0/8043 [00:00<?, ?it/s]
# 4 {'accuracy': 0.6971655892590751, 'precision': 0.6957364341085271, 'recall': 0.7087857847976308, 'f1-score': 0.7022004889975549, 'auc': 0.6970782631402983}
# Evolving RandomForest
#   0%|          | 0/8148 [00:00<?, ?it/s]
# 5 {'accuracy': 0.6594700686947988, 'precision': 0.622778675282714, 'recall': 0.7725450901803608, 'f1-score': 0.6896243291592129, 'auc': 0.6617533143209496}
# Evolving RandomForest
#   0%|          | 0/8150 [00:00<?, ?it/s]
# 6 {'accuracy': 0.7031403336604515, 'precision': 0.7008797653958945, 'recall': 0.7057086614173228, 'f1-score': 0.7032859244727807, 'auc': 0.7031478727830254}
# Evolving RandomForest
#   0%|          | 0/8105 [00:00<?, ?it/s]
# 7 {'accuracy': 0.7163295510606809, 'precision': 0.7189672293942403, 'recall': 0.7125984251968503, 'f1-score': 0.7157686604053386, 'auc': 0.7163387773857643}
# Evolving RandomForest
#   0%|          | 0/8136 [00:00<?, ?it/s]
# 8 {'accuracy': 0.5196656833824975, 'precision': 0.5125125125125125, 'recall': 0.997078870496592, 'f1-score': 0.6770247933884298, 'auc': 0.5149247381281372}
# Evolving RandomForest
#   0%|          | 0/8172 [00:00<?, ?it/s]
# 9 {'accuracy': 0.6330724070450098, 'precision': 0.5855614973262032, 'recall': 0.8707753479125249, 'f1-score': 0.7002398081534772, 'auc': 0.6367364215477846}
# Evolving RandomForest
#   0%|          | 0/8187 [00:00<?, ?it/s]
# 10 {'accuracy': 0.5065950170981924, 'precision': 0.49825957235206364, 'recall': 0.9990029910269193, 'f1-score': 0.6648971466489715, 'auc': 0.5162639476207393}
