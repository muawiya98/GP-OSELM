# %%
# !pip install -q scikit-multiflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.6/450.6 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-multiflow (setup.py) ... done

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from skmultiflow.drift_detection import ADWIN, DDM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from matplotlib.colors import ListedColormap
from multiprocessing.pool import ThreadPool
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle
from contextlib import suppress
from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from random import shuffle
import seaborn as sns
from time import time
import pandas as pd
import numpy as np
import warnings
import scipy.io
import pickle
import sys
import gc
import os
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/data'
code_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Codes/Shared Codes'
results_path = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/Results'
feature_selection_results = '/content/drive/My Drive/Colab Notebooks/Muawiya/Genetic Programming Combiner with DFS/feature_selection_results'
sys.path.insert(0,code_path)
from oselm import set_use_know
from SharedFunctions import main,generate_oselm_models

# %%
filenames = ['kddcup99_csv.csv','ISCX2012.csv','CSE-CIC2018.csv','CICIDS2017.csv','7recurrentDrift.csv', 'blip.csv', 'incrementalDrift.csv',
             '7gradualDrift.csv', '7suddenDrift.csv']
filenames = list(map(lambda x: os.path.join(data_path, x), filenames))

# %%
data_name = ['kddcup99','ISCX2012','CSE-CIC2018','CICIDS2017','7recurrentDrift', 'blip', 'incrementalDrift','7gradualDrift', '7suddenDrift']

# %%
# # use_know = False
# # set_use_know(use_know)
# # path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving_random_forest')
# # os.makedirs(path, exist_ok=True)
# # for f_name,d_name in zip(filenames,data_name):
# #   main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
# #       feature_selection=["feature_evolving",'random_forest'], result_save_path=path)

# %%
DATA_NUMBER=0
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
    feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : kddcup99_csv.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.9935856318152662, 'precision': 1.0, 'recall': 0.9878493317132442, 'f1-score': 0.9938875305623471, 'auc': 0.9939246658566221}
# Evolving RandomForest
# 2 {'accuracy': 0.9968091895341417, 'precision': 1.0, 'recall': 0.9935233160621761, 'f1-score': 0.9967511371020142, 'auc': 0.9967616580310881}
# Evolving RandomForest
# 3 {'accuracy': 0.9948979591836735, 'precision': 0.9987639060568603, 'recall': 0.9914110429447853, 'f1-score': 0.9950738916256158, 'auc': 0.9950415108482227}
# Evolving RandomForest
# 4 {'accuracy': 0.9974619289340102, 'precision': 1.0, 'recall': 0.9950617283950617, 'f1-score': 0.9975247524752474, 'auc': 0.9975308641975309}
# Evolving RandomForest
# 5 {'accuracy': 0.9980903882877148, 'precision': 1.0, 'recall': 0.9960988296488946, 'f1-score': 0.9980456026058632, 'auc': 0.9980494148244473}
# Evolving RandomForest
# 6 {'accuracy': 0.9968434343434344, 'precision': 1.0, 'recall': 0.9935233160621761, 'f1-score': 0.9967511371020142, 'auc': 0.9967616580310881}
# Evolving RandomForest
# 7 {'accuracy': 0.9942748091603053, 'precision': 1.0, 'recall': 0.9882198952879581, 'f1-score': 0.9940750493745886, 'auc': 0.994109947643979}
# Evolving RandomForest
# 8 {'accuracy': 0.9936708860759493, 'precision': 1.0, 'recall': 0.9875776397515528, 'f1-score': 0.99375, 'auc': 0.9937888198757764}
# Evolving RandomForest
# 9 {'accuracy': 0.9930335655478151, 'precision': 1.0, 'recall': 0.9864364981504316, 'f1-score': 0.9931719428926133, 'auc': 0.9932182490752157}
# Evolving RandomForest
# 10 {'accuracy': 0.9987163029525032, 'precision': 0.9987080103359173, 'recall': 0.9987080103359173, 'f1-score': 0.9987080103359173, 'auc': 0.9987162500659177}

# %%
DATA_NUMBER=1
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
    feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : ISCX2012.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.7122436295835923, 'precision': 0.9415204678362573, 'recall': 0.42091503267973857, 'f1-score': 0.5817524841915086, 'auc': 0.6986091751076418}
# Evolving RandomForest
# 2 {'accuracy': 0.8229426433915212, 'precision': 0.9963702359346642, 'recall': 0.6606498194945848, 'f1-score': 0.7945007235890014, 'auc': 0.8290312486864904}
# Evolving RandomForest
# 3 {'accuracy': 0.8319800124921923, 'precision': 0.9923954372623575, 'recall': 0.6632782719186785, 'f1-score': 0.7951256664127953, 'auc': 0.8291821335023367}
# Evolving RandomForest
# 4 {'accuracy': 0.8700248756218906, 'precision': 0.9950248756218906, 'recall': 0.7444168734491315, 'f1-score': 0.8516678495386799, 'auc': 0.8703381125350395}
# Evolving RandomForest
# 5 {'accuracy': 0.883270911360799, 'precision': 1.0, 'recall': 0.7614795918367347, 'f1-score': 0.8645908761766836, 'auc': 0.8807397959183674}
# Evolving RandomForest
# 6 {'accuracy': 0.8541147132169576, 'precision': 0.9965156794425087, 'recall': 0.7114427860696517, 'f1-score': 0.8301886792452831, 'auc': 0.8544713930348259}
# Evolving RandomForest
# 7 {'accuracy': 0.8735990037359901, 'precision': 0.9965870307167235, 'recall': 0.7439490445859872, 'f1-score': 0.8519328956965717, 'auc': 0.870756495496404}
# Evolving RandomForest
# 8 {'accuracy': 0.869538077403246, 'precision': 0.9916107382550335, 'recall': 0.7433962264150943, 'f1-score': 0.8497483824586628, 'auc': 0.8686002197750813}
# Evolving RandomForest
# 9 {'accuracy': 0.8556511056511057, 'precision': 0.9949324324324325, 'recall': 0.7174177831912302, 'f1-score': 0.8336871903750884, 'auc': 0.8568501555361355}
# Evolving RandomForest
# 10 {'accuracy': 0.8498461538461538, 'precision': 0.9932203389830508, 'recall': 0.7094430992736077, 'f1-score': 0.827683615819209, 'auc': 0.852218420725665}

# %%
DATA_NUMBER=2
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
    feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CSE-CIC2018.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 0.5}
# Evolving RandomForest
# 2 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving RandomForest
# 3 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving RandomForest
# 4 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving RandomForest
# 5 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving RandomForest
# 6 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving RandomForest
# 7 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving RandomForest
# 8 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving RandomForest
# 9 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}
# Evolving RandomForest
# 10 {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'auc': 1.0}

# %%
DATA_NUMBER=3
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
    feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : CICIDS2017.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.9796367638965328, 'precision': 0.9652855543113102, 'recall': 0.9930875576036866, 'f1-score': 0.9789892106757525, 'auc': 0.9802107967154365}
# Evolving RandomForest
# 2 {'accuracy': 0.9877437325905293, 'precision': 0.9792576419213974, 'recall': 0.9966666666666667, 'f1-score': 0.9878854625550662, 'auc': 0.9877188081936685}
# Evolving RandomForest
# 3 {'accuracy': 0.9828064337215752, 'precision': 0.9734607218683652, 'recall': 0.9934994582881906, 'f1-score': 0.983378016085791, 'auc': 0.9825451836895499}
# Evolving RandomForest
# 4 {'accuracy': 0.9856194690265486, 'precision': 0.9772985244040863, 'recall': 0.9930795847750865, 'f1-score': 0.9851258581235698, 'auc': 0.985912799826438}
# Evolving RandomForest
# 5 {'accuracy': 0.9821428571428571, 'precision': 0.9702127659574468, 'recall': 0.9945474372955289, 'f1-score': 0.9822294022617124, 'auc': 0.9822361246628021}
# Evolving RandomForest
# 6 {'accuracy': 0.9871723368655884, 'precision': 0.9804772234273319, 'recall': 0.9944994499449945, 'f1-score': 0.9874385581649372, 'auc': 0.987068729497384}
# Evolving RandomForest
# 7 {'accuracy': 0.9870641169853769, 'precision': 0.980327868852459, 'recall': 0.9944567627494457, 'f1-score': 0.9873417721518988, 'auc': 0.9869544087719833}
# Evolving RandomForest
# 8 {'accuracy': 0.9848484848484849, 'precision': 0.9748083242059146, 'recall': 0.9955257270693513, 'f1-score': 0.9850581073602657, 'auc': 0.9848124130842251}
# Evolving RandomForest
# 9 {'accuracy': 0.9876056338028169, 'precision': 0.9808126410835214, 'recall': 0.994279176201373, 'f1-score': 0.9874999999999999, 'auc': 0.9877056258365355}
# Evolving RandomForest
# 10 {'accuracy': 0.9926966292134831, 'precision': 0.9878721058434399, 'recall': 0.9977728285077951, 'f1-score': 0.992797783933518, 'auc': 0.9926505865894983}

# %%
DATA_NUMBER=4
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
    feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7recurrentDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest

# %%
DATA_NUMBER=5
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
    feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : blip.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.49726177437020813, 'precision': 0.5321100917431193, 'recall': 0.1853035143769968, 'f1-score': 0.27488151658767773, 'auc': 0.5064059849224329}
# Evolving RandomForest
# 2 {'accuracy': 0.5141745414118954, 'precision': 0.5037425149700598, 'recall': 0.7613122171945701, 'f1-score': 0.6063063063063062, 'auc': 0.5183610266300719}
# Evolving RandomForest
# 3 {'accuracy': 0.49036873968079253, 'precision': 0.4626865671641791, 'recall': 0.2799097065462754, 'f1-score': 0.3488045007032349, 'auc': 0.4852824579992387}
# Evolving RandomForest
# 4 {'accuracy': 0.5092491838955386, 'precision': 0.5139573070607554, 'recall': 0.3405875952121872, 'f1-score': 0.4096858638743456, 'auc': 0.5092491838955386}
# Evolving RandomForest
# 5 {'accuracy': 0.49917808219178084, 'precision': 0.5037735849056604, 'recall': 0.2908496732026144, 'f1-score': 0.3687845303867403, 'auc': 0.5004413746387935}
# Evolving RandomForest
# 6 {'accuracy': 0.4975556762629006, 'precision': 0.5129032258064516, 'recall': 0.17041800643086816, 'f1-score': 0.25583266291230894, 'auc': 0.5020592234797513}
# Evolving RandomForest
# 7 {'accuracy': 0.5061179087875417, 'precision': 0.5217391304347826, 'recall': 0.27722772277227725, 'f1-score': 0.3620689655172414, 'auc': 0.508692601543619}
# Evolving RandomForest
# 8 {'accuracy': 0.48777838131450296, 'precision': 0.47306791569086654, 'recall': 0.21956521739130436, 'f1-score': 0.29992576095025986, 'auc': 0.48763277156210166}
# Evolving RandomForest

# %%
DATA_NUMBER=6
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
    feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)

# %%
DATA_NUMBER=7
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
    feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7gradualDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.7003929273084479, 'precision': 0.6961165048543689, 'recall': 0.7071005917159763, 'f1-score': 0.7015655577299412, 'auc': 0.7004191803981056}
# Evolving RandomForest
# 2 {'accuracy': 0.698019801980198, 'precision': 0.7054726368159204, 'recall': 0.6930596285434996, 'f1-score': 0.6992110453648915, 'auc': 0.6980844782637257}
# Evolving RandomForest
# 3 {'accuracy': 0.7180246913580247, 'precision': 0.691304347826087, 'recall': 0.7863501483679525, 'f1-score': 0.7357704766311893, 'auc': 0.718125764519282}
# Evolving RandomForest
# 4 {'accuracy': 0.6968796433878157, 'precision': 0.6919518963922294, 'recall': 0.7283349561830574, 'f1-score': 0.7096774193548389, 'auc': 0.6963247361560448}
# Evolving RandomForest
# 5 {'accuracy': 0.7124442240951909, 'precision': 0.7012195121951219, 'recall': 0.772552783109405, 'f1-score': 0.7351598173515981, 'auc': 0.7103789556572666}
# Evolving RandomForest
# 6 {'accuracy': 0.7034825870646766, 'precision': 0.7022357723577236, 'recall': 0.6951710261569416, 'f1-score': 0.698685540950455, 'auc': 0.7033925996926441}
# Evolving RandomForest
# 7 {'accuracy': 0.708171206225681, 'precision': 0.6882661996497373, 'recall': 0.7631067961165049, 'f1-score': 0.7237569060773481, 'auc': 0.7080641193058158}
# Evolving RandomForest
# 8 {'accuracy': 0.6929911154985192, 'precision': 0.6755162241887905, 'recall': 0.7017364657814096, 'f1-score': 0.6883767535070141, 'auc': 0.6932751096815357}
# Evolving RandomForest
# 9 {'accuracy': 0.7185658153241651, 'precision': 0.7093639575971732, 'recall': 0.766953199617956, 'f1-score': 0.737035337310693, 'auc': 0.717146973924246}
# Evolving RandomForest
# 10 {'accuracy': 0.7091535433070866, 'precision': 0.695132365499573, 'recall': 0.7767175572519084, 'f1-score': 0.7336638125281658, 'auc': 0.7069563396015639}

# %%
DATA_NUMBER=8
ChunkNumber=0
use_know = False
set_use_know(use_know)
path = os.path.join(results_path,'gp_combiner_with_model_replacement_evolving_random_forest')
os.makedirs(path, exist_ok=True)
f_name,d_name = filenames[DATA_NUMBER],data_name[DATA_NUMBER]
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=False,
    feature_selection=["feature_evolving",'random_forest'], result_save_path=path,ChunkNumber=ChunkNumber)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : 7suddenDrift.csv ======================
# 0it [00:00, ?it/s]
# Evolving RandomForest
# 1 {'accuracy': 0.712166172106825, 'precision': 0.6669595782073814, 'recall': 0.7889812889812889, 'f1-score': 0.7228571428571429, 'auc': 0.7157170595849841}
# Evolving RandomForest
# 2 {'accuracy': 0.7098857426726279, 'precision': 0.6838174273858921, 'recall': 0.8023369036027264, 'f1-score': 0.7383512544802868, 'auc': 0.7079635836472049}
# Evolving RandomForest
# 3 {'accuracy': 0.7085828343313373, 'precision': 0.6976336546888694, 'recall': 0.7690821256038647, 'f1-score': 0.7316176470588234, 'auc': 0.7065224869505391}
# Evolving RandomForest
# 4 {'accuracy': 0.69617105917454, 'precision': 0.6741767764298093, 'recall': 0.7680157946692991, 'f1-score': 0.7180433779418552, 'auc': 0.6956311438276356}
# Evolving RandomForest
# 5 {'accuracy': 0.6967615309126595, 'precision': 0.6599326599326599, 'recall': 0.7855711422845691, 'f1-score': 0.7172918572735589, 'auc': 0.6985548019115154}
# Evolving RandomForest
# 6 {'accuracy': 0.6722276741903828, 'precision': 0.64332784184514, 'recall': 0.7687007874015748, 'f1-score': 0.7004484304932735, 'auc': 0.6725108633681064}
# Evolving RandomForest
# 7 {'accuracy': 0.6946225949679329, 'precision': 0.6623058053965658, 'recall': 0.797244094488189, 'f1-score': 0.7235372934345691, 'auc': 0.6943688326051232}
# Evolving RandomForest
# 8 {'accuracy': 0.7123893805309734, 'precision': 0.6959219858156028, 'recall': 0.7643622200584226, 'f1-score': 0.728538283062645, 'auc': 0.7118732649448023}
# Evolving RandomForest
# 9 {'accuracy': 0.7113502935420744, 'precision': 0.6830985915492958, 'recall': 0.7713717693836978, 'f1-score': 0.7245564892623716, 'auc': 0.7122754800675714}
# Evolving RandomForest
# 10 {'accuracy': 0.7024914509037616, 'precision': 0.6669491525423729, 'recall': 0.7846460618145563, 'f1-score': 0.7210261108566193, 'auc': 0.7041046401026805}
